# %% [markdown]
# # Formas de ordenar una Serie
#
# En esta lección veremos las dos maneras que existen de ordenar una serie: con base en sus datos y con base en su índice.
#
# Y veremos que los dos métodos para lograr esto (`sort_values` y `sort_index`) son exactamente iguales a los usados en los *DataFrames* y que vimos anteriormente.

# %% [markdown]
# ## 1. Ordenar una Serie con base en los valores de los datos
#
# En este caso usamos el método `sort_values` que, por defecto, ordena la serie de manera ascendente (del valor más pequeño al más grande, o en orden alfabético en caso de tener *strings*):

# %%
# Importar librerías
import pandas as pd

# Leer dataframe
df = pd.read_csv('peliculas.csv')

# Extraer series
serie_num = df['num_critic_for_reviews']
serie_str = df['director_name']

# %%
# Ordenar Serie numérica de forma ascendente
serie_num.sort_values() # Ascending = True
# Out:
# 4196    1.0
# 4860    1.0
# 3894    1.0
# 3933    1.0
# 4655    1.0
#        ...
# 4880    NaN
# 4889    NaN
# 4893    NaN
# 4903    NaN
# 4909    NaN
# Name: num_critic_for_reviews, Length: 4916, dtype: float64

# %%
# Y ordenarla de forma descendente
serie_num.sort_values(ascending = False)
# Out:
# 3       813.0
# 224     775.0
# 293     765.0
# 30      750.0
# 128     739.0
#         ...
# 4880      NaN
# 4889      NaN
# 4893      NaN
# 4903      NaN
# 4909      NaN
# Name: num_critic_for_reviews, Length: 4916, dtype: float64

# %%
# Ordenar serie de "strings" de forma ascendente
serie_str.sort_values()
# Out:
# 4498      A. Raven Cruz
# 4221         Aaron Hann
# 3430    Aaron Schneider
# 2156      Aaron Seltzer
# 2862       Abel Ferrara
#              ...
# 4683                NaN
# 4688                NaN
# 4704                NaN
# 4752                NaN
# 4912                NaN
# Name: director_name, Length: 4916, dtype: object

# %%
# Y ahora de forma descendente
serie_str.sort_values(ascending = False)
# Out:
# 4731         Étienne Faure
# 4103          Éric Tessier
# 3609      Émile Gaudreault
# 3185    Álex de la Iglesia
# 4769         Zoran Lisinac
#                ...
# 4683                   NaN
# 4688                   NaN
# 4704                   NaN
# 4752                   NaN
# 4912                   NaN
# Name: director_name, Length: 4916, dtype: object

# %% [markdown]
# ## 2. Ordenar una Serie con base en los valores de su índice
#
# Al igual que con los *DataFrames* podemos usar de nuevo `sort_index`:

# %%
serie_num.sort_index(ascending = False)
# Out:
# 4915     43.0
# 4914     14.0
# 4913     13.0
# 4912     43.0
# 4911      1.0
#         ...
# 4         NaN
# 3       813.0
# 2       602.0
# 1       302.0
# 0       723.0
# Name: num_critic_for_reviews, Length: 4916, dtype: float64

# %%
# Fijemos un nuevo índice para el DataFrame
df = df.set_index('director_name')
df
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
# ...                  ...                     ...       ...
# Scott Smith        Color                     1.0      87.0
# NaN                Color                    43.0      43.0
# Benjamin Roberds   Color                    13.0      76.0
# Daniel Hsia        Color                    14.0     100.0
# Jon Gunn           Color                    43.0      90.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Doug Walker                          131.0                     NaN
# ...                                    ...                     ...
# Scott Smith                            2.0                   318.0
# NaN                                    NaN                   319.0
# Benjamin Roberds                       0.0                     0.0
# Daniel Hsia                            0.0                   489.0
# Jon Gunn                              16.0                    16.0
#
#                        actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# James Cameron      Joel David Moore                  1000.0  760505847.0
# Gore Verbinski        Orlando Bloom                 40000.0  309404152.0
# Sam Mendes             Rory Kinnear                 11000.0  200074175.0
# Christopher Nolan    Christian Bale                 27000.0  448130642.0
# Doug Walker              Rob Walker                   131.0          NaN
# ...                             ...                     ...          ...
# Scott Smith           Daphne Zuniga                   637.0          NaN
# NaN                   Valorie Curry                   841.0          NaN
# Benjamin Roberds      Maxwell Moody                     0.0          NaN
# Daniel Hsia           Daniel Henney                   946.0      10443.0
# Jon Gunn           Brian Herzlinger                    86.0      85222.0
#
#                                             genres     actor_1_name  ...  \
# director_name                                                        ...
# James Cameron      Action|Adventure|Fantasy|Sci-Fi      CCH Pounder  ...
# Gore Verbinski            Action|Adventure|Fantasy      Johnny Depp  ...
# Sam Mendes               Action|Adventure|Thriller  Christoph Waltz  ...
# Christopher Nolan                  Action|Thriller        Tom Hardy  ...
# Doug Walker                            Documentary      Doug Walker  ...
# ...                                            ...              ...  ...
# Scott Smith                           Comedy|Drama      Eric Mabius  ...
# NaN                   Crime|Drama|Mystery|Thriller      Natalie Zea  ...
# Benjamin Roberds             Drama|Horror|Thriller      Eva Boehnke  ...
# Daniel Hsia                   Comedy|Drama|Romance        Alan Ruck  ...
# Jon Gunn                               Documentary      John August  ...
#
#                   num_user_for_reviews  language  country content_rating  \
# director_name
# James Cameron                   3054.0   English      USA          PG-13
# Gore Verbinski                  1238.0   English      USA          PG-13
# Sam Mendes                       994.0   English       UK          PG-13
# Christopher Nolan               2701.0   English      USA          PG-13
# Doug Walker                        NaN       NaN      NaN            NaN
# ...                                ...       ...      ...            ...
# Scott Smith                        6.0   English   Canada            NaN
# NaN                              359.0   English      USA          TV-14
# Benjamin Roberds                   3.0   English      USA            NaN
# Daniel Hsia                        9.0   English      USA          PG-13
# Jon Gunn                          84.0   English      USA             PG
#
#                         budget title_year actor_2_facebook_likes  imdb_score  \
# director_name
# James Cameron      237000000.0     2009.0                  936.0         7.9
# Gore Verbinski     300000000.0     2007.0                 5000.0         7.1
# Sam Mendes         245000000.0     2015.0                  393.0         6.8
# Christopher Nolan  250000000.0     2012.0                23000.0         8.5
# Doug Walker                NaN        NaN                   12.0         7.1
# ...                        ...        ...                    ...         ...
# Scott Smith                NaN     2013.0                  470.0         7.7
# NaN                        NaN        NaN                  593.0         7.5
# Benjamin Roberds        1400.0     2013.0                    0.0         6.3
# Daniel Hsia                NaN     2012.0                  719.0         6.3
# Jon Gunn                1100.0     2004.0                   23.0         6.6
#
#                   aspect_ratio movie_facebook_likes
# director_name
# James Cameron             1.78                33000
# Gore Verbinski            2.35                    0
# Sam Mendes                2.35                85000
# Christopher Nolan         2.35               164000
# Doug Walker                NaN                    0
# ...                        ...                  ...
# Scott Smith                NaN                   84
# NaN                      16.00                32000
# Benjamin Roberds           NaN                   16
# Daniel Hsia               2.35                  660
# Jon Gunn                  1.85                  456
#
# [4916 rows x 27 columns]

# %%
# Y extraigamos la columna "movie_title"
serie_movies = df['movie_title']
serie_movies
# Out:
# director_name
# James Cameron                                            Avatar
# Gore Verbinski         Pirates of the Caribbean: At World's End
# Sam Mendes                                              Spectre
# Christopher Nolan                         The Dark Knight Rises
# Doug Walker          Star Wars: Episode VII - The Force Awakens
#                                         ...
# Scott Smith                             Signed Sealed Delivered
# NaN                                               The Following
# Benjamin Roberds                           A Plague So Pleasant
# Daniel Hsia                                    Shanghai Calling
# Jon Gunn                                      My Date with Drew
# Name: movie_title, Length: 4916, dtype: object

# %%
# Y ahora organicemos la Serie alfabéticamente de forma ascendente con base en su índice 
serie_movies.sort_index()
# Out:
# director_name
# A. Raven Cruz      The Helix... Loaded
# Aaron Hann                      Circle
# Aaron Schneider                Get Low
# Aaron Seltzer               Date Movie
# Abel Ferrara               The Funeral
#                           ...
# NaN                             Heroes
# NaN                        Home Movies
# NaN                         Revolution
# NaN                       Happy Valley
# NaN                      The Following
# Name: movie_title, Length: 4916, dtype: object

# %%
# Y ahora la ordenamos alfabéticamente en orden inverso (también con base en su índice)
serie_movies.sort_index(ascending = False)
# Out:
# director_name
# Étienne Faure                    Bizarre
# Éric Tessier                Sur le seuil
# Émile Gaudreault          Mambo Italiano
# Álex de la Iglesia    The Oxford Murders
# Zoran Lisinac         Along the Roadside
#                              ...
# NaN                               Heroes
# NaN                          Home Movies
# NaN                           Revolution
# NaN                         Happy Valley
# NaN                        The Following
# Name: movie_title, Length: 4916, dtype: object

# %% [markdown]
# Y recordemos que, tal como ocurría con los *DataFrames*, estas operaciones **NO persisten** a menos que sobre-escribamos la serie o que usemos el parámetro `inplace = True`:

# %%
serie_movies
# Out:
# director_name
# James Cameron                                            Avatar
# Gore Verbinski         Pirates of the Caribbean: At World's End
# Sam Mendes                                              Spectre
# Christopher Nolan                         The Dark Knight Rises
# Doug Walker          Star Wars: Episode VII - The Force Awakens
#                                         ...
# Scott Smith                             Signed Sealed Delivered
# NaN                                               The Following
# Benjamin Roberds                           A Plague So Pleasant
# Daniel Hsia                                    Shanghai Calling
# Jon Gunn                                      My Date with Drew
# Name: movie_title, Length: 4916, dtype: object

# %%
serie_movies.sort_index(ascending=True, inplace=True)

# %%
serie_movies
# Out:
# director_name
# A. Raven Cruz      The Helix... Loaded
# Aaron Hann                      Circle
# Aaron Schneider                Get Low
# Aaron Seltzer               Date Movie
# Abel Ferrara               The Funeral
#                           ...
# NaN                             Heroes
# NaN                        Home Movies
# NaN                         Revolution
# NaN                       Happy Valley
# NaN                      The Following
# Name: movie_title, Length: 4916, dtype: object

# %% [markdown]
# ## 3. Ejercicio práctico
#
# Usando Series encontrar las peores 5 películas, es decir las que generaron los peores retornos de inversión.

# %%
# Crear columna "net_income"
df['net_income'] = df['gross'] - df['budget']
df
# Out:
#                    color  num_critic_for_reviews  duration  \
# director_name
# James Cameron      Color                   723.0     178.0
# Gore Verbinski     Color                   302.0     169.0
# Sam Mendes         Color                   602.0     148.0
# Christopher Nolan  Color                   813.0     164.0
# Doug Walker          NaN                     NaN       NaN
# ...                  ...                     ...       ...
# Scott Smith        Color                     1.0      87.0
# NaN                Color                    43.0      43.0
# Benjamin Roberds   Color                    13.0      76.0
# Daniel Hsia        Color                    14.0     100.0
# Jon Gunn           Color                    43.0      90.0
#
#                    director_facebook_likes  actor_3_facebook_likes  \
# director_name
# James Cameron                          0.0                   855.0
# Gore Verbinski                       563.0                  1000.0
# Sam Mendes                             0.0                   161.0
# Christopher Nolan                  22000.0                 23000.0
# Doug Walker                          131.0                     NaN
# ...                                    ...                     ...
# Scott Smith                            2.0                   318.0
# NaN                                    NaN                   319.0
# Benjamin Roberds                       0.0                     0.0
# Daniel Hsia                            0.0                   489.0
# Jon Gunn                              16.0                    16.0
#
#                        actor_2_name  actor_1_facebook_likes        gross  \
# director_name
# James Cameron      Joel David Moore                  1000.0  760505847.0
# Gore Verbinski        Orlando Bloom                 40000.0  309404152.0
# Sam Mendes             Rory Kinnear                 11000.0  200074175.0
# Christopher Nolan    Christian Bale                 27000.0  448130642.0
# Doug Walker              Rob Walker                   131.0          NaN
# ...                             ...                     ...          ...
# Scott Smith           Daphne Zuniga                   637.0          NaN
# NaN                   Valorie Curry                   841.0          NaN
# Benjamin Roberds      Maxwell Moody                     0.0          NaN
# Daniel Hsia           Daniel Henney                   946.0      10443.0
# Jon Gunn           Brian Herzlinger                    86.0      85222.0
#
#                                             genres     actor_1_name  ...  \
# director_name                                                        ...
# James Cameron      Action|Adventure|Fantasy|Sci-Fi      CCH Pounder  ...
# Gore Verbinski            Action|Adventure|Fantasy      Johnny Depp  ...
# Sam Mendes               Action|Adventure|Thriller  Christoph Waltz  ...
# Christopher Nolan                  Action|Thriller        Tom Hardy  ...
# Doug Walker                            Documentary      Doug Walker  ...
# ...                                            ...              ...  ...
# Scott Smith                           Comedy|Drama      Eric Mabius  ...
# NaN                   Crime|Drama|Mystery|Thriller      Natalie Zea  ...
# Benjamin Roberds             Drama|Horror|Thriller      Eva Boehnke  ...
# Daniel Hsia                   Comedy|Drama|Romance        Alan Ruck  ...
# Jon Gunn                               Documentary      John August  ...
#
#                   language  country  content_rating       budget  title_year  \
# director_name
# James Cameron      English      USA           PG-13  237000000.0      2009.0
# Gore Verbinski     English      USA           PG-13  300000000.0      2007.0
# Sam Mendes         English       UK           PG-13  245000000.0      2015.0
# Christopher Nolan  English      USA           PG-13  250000000.0      2012.0
# Doug Walker            NaN      NaN             NaN          NaN         NaN
# ...                    ...      ...             ...          ...         ...
# Scott Smith        English   Canada             NaN          NaN      2013.0
# NaN                English      USA           TV-14          NaN         NaN
# Benjamin Roberds   English      USA             NaN       1400.0      2013.0
# Daniel Hsia        English      USA           PG-13          NaN      2012.0
# Jon Gunn           English      USA              PG       1100.0      2004.0
#
#                   actor_2_facebook_likes imdb_score  aspect_ratio  \
# director_name
# James Cameron                      936.0        7.9          1.78
# Gore Verbinski                    5000.0        7.1          2.35
# Sam Mendes                         393.0        6.8          2.35
# Christopher Nolan                23000.0        8.5          2.35
# Doug Walker                         12.0        7.1           NaN
# ...                                  ...        ...           ...
# Scott Smith                        470.0        7.7           NaN
# NaN                                593.0        7.5         16.00
# Benjamin Roberds                     0.0        6.3           NaN
# Daniel Hsia                        719.0        6.3          2.35
# Jon Gunn                            23.0        6.6          1.85
#
#                   movie_facebook_likes   net_income
# director_name
# James Cameron                    33000  523505847.0
# Gore Verbinski                       0    9404152.0
# Sam Mendes                       85000  -44925825.0
# Christopher Nolan               164000  198130642.0
# Doug Walker                          0          NaN
# ...                                ...          ...
# Scott Smith                         84          NaN
# NaN                              32000          NaN
# Benjamin Roberds                    16          NaN
# Daniel Hsia                        660          NaN
# Jon Gunn                           456      84122.0
#
# [4916 rows x 28 columns]

# %%
# Fijar el índice del DataFrame como la columna "movie_title"
df = df.set_index('movie_title')
df
# Out:
#                      color  num_critic_for_reviews  duration  \
# movie_title
# The Helix... Loaded  Color                   723.0     178.0
# Circle               Color                   302.0     169.0
# Get Low              Color                   602.0     148.0
# Date Movie           Color                   813.0     164.0
# The Funeral            NaN                     NaN       NaN
# ...                    ...                     ...       ...
# Heroes               Color                     1.0      87.0
# Home Movies          Color                    43.0      43.0
# Revolution           Color                    13.0      76.0
# Happy Valley         Color                    14.0     100.0
# The Following        Color                    43.0      90.0
#
#                      director_facebook_likes  actor_3_facebook_likes  \
# movie_title
# The Helix... Loaded                      0.0                   855.0
# Circle                                 563.0                  1000.0
# Get Low                                  0.0                   161.0
# Date Movie                           22000.0                 23000.0
# The Funeral                            131.0                     NaN
# ...                                      ...                     ...
# Heroes                                   2.0                   318.0
# Home Movies                              NaN                   319.0
# Revolution                               0.0                     0.0
# Happy Valley                             0.0                   489.0
# The Following                           16.0                    16.0
#
#                          actor_2_name  actor_1_facebook_likes        gross  \
# movie_title
# The Helix... Loaded  Joel David Moore                  1000.0  760505847.0
# Circle                  Orlando Bloom                 40000.0  309404152.0
# Get Low                  Rory Kinnear                 11000.0  200074175.0
# Date Movie             Christian Bale                 27000.0  448130642.0
# The Funeral                Rob Walker                   131.0          NaN
# ...                               ...                     ...          ...
# Heroes                  Daphne Zuniga                   637.0          NaN
# Home Movies             Valorie Curry                   841.0          NaN
# Revolution              Maxwell Moody                     0.0          NaN
# Happy Valley            Daniel Henney                   946.0      10443.0
# The Following        Brian Herzlinger                    86.0      85222.0
#
#                                               genres     actor_1_name  ...  \
# movie_title                                                            ...
# The Helix... Loaded  Action|Adventure|Fantasy|Sci-Fi      CCH Pounder  ...
# Circle                      Action|Adventure|Fantasy      Johnny Depp  ...
# Get Low                    Action|Adventure|Thriller  Christoph Waltz  ...
# Date Movie                           Action|Thriller        Tom Hardy  ...
# The Funeral                              Documentary      Doug Walker  ...
# ...                                              ...              ...  ...
# Heroes                                  Comedy|Drama      Eric Mabius  ...
# Home Movies             Crime|Drama|Mystery|Thriller      Natalie Zea  ...
# Revolution                     Drama|Horror|Thriller      Eva Boehnke  ...
# Happy Valley                    Comedy|Drama|Romance        Alan Ruck  ...
# The Following                            Documentary      John August  ...
#
#                      language  country content_rating       budget title_year  \
# movie_title
# The Helix... Loaded   English      USA          PG-13  237000000.0     2009.0
# Circle                English      USA          PG-13  300000000.0     2007.0
# Get Low               English       UK          PG-13  245000000.0     2015.0
# Date Movie            English      USA          PG-13  250000000.0     2012.0
# The Funeral               NaN      NaN            NaN          NaN        NaN
# ...                       ...      ...            ...          ...        ...
# Heroes                English   Canada            NaN          NaN     2013.0
# Home Movies           English      USA          TV-14          NaN        NaN
# Revolution            English      USA            NaN       1400.0     2013.0
# Happy Valley          English      USA          PG-13          NaN     2012.0
# The Following         English      USA             PG       1100.0     2004.0
#
#                     actor_2_facebook_likes  imdb_score aspect_ratio  \
# movie_title
# The Helix... Loaded                  936.0         7.9         1.78
# Circle                              5000.0         7.1         2.35
# Get Low                              393.0         6.8         2.35
# Date Movie                         23000.0         8.5         2.35
# The Funeral                           12.0         7.1          NaN
# ...                                    ...         ...          ...
# Heroes                               470.0         7.7          NaN
# Home Movies                          593.0         7.5        16.00
# Revolution                             0.0         6.3          NaN
# Happy Valley                         719.0         6.3         2.35
# The Following                         23.0         6.6         1.85
#
#                     movie_facebook_likes   net_income
# movie_title
# The Helix... Loaded                33000  523505847.0
# Circle                                 0    9404152.0
# Get Low                            85000  -44925825.0
# Date Movie                        164000  198130642.0
# The Funeral                            0          NaN
# ...                                  ...          ...
# Heroes                                84          NaN
# Home Movies                        32000          NaN
# Revolution                            16          NaN
# Happy Valley                         660          NaN
# The Following                        456      84122.0
#
# [4916 rows x 27 columns]

# %%
# Extraer la serie proveniente de la columna "net_income"
serie_ni = df['net_income']
serie_ni
# Out:
# movie_title
# The Helix... Loaded    523505847.0
# Circle                   9404152.0
# Get Low                -44925825.0
# Date Movie             198130642.0
# The Funeral                    NaN
#                           ...
# Heroes                         NaN
# Home Movies                    NaN
# Revolution                     NaN
# Happy Valley                   NaN
# The Following              84122.0
# Name: net_income, Length: 4916, dtype: float64

# %% [markdown]
# Podemos encontrar las 5 peores películas de dos maneras.
#
# La primera es ordenando la Serie de manera ascendente y tomando los 5 primeros datos (de forma similar a como lo hicimos en un ejemplo anterior para el caso de los *DataFrames*):

# %%
# Método 1: usar sort_values seguido de indexación
bottom_5 = serie_ni.sort_values()[0:5]
bottom_5
# Out:
# movie_title
# The Ugly Truth         -4.199788e+09
# Amour                  -2.499804e+09
# The Hebrew Hammer      -2.397702e+09
# The Whole Nine Yards   -2.127110e+09
# Black Book             -1.099561e+09
# Name: net_income, dtype: float64

# %% [markdown]
# O podemos usar el método `nsmallest` ("los n más pequeños") para encontrar los 5 niveles de retorno más bajos. **Este método también se puede usar en los *DataFrames***:

# %%
bottom_5 = serie_ni.nsmallest(5)
bottom_5
# Out:
# movie_title
# The Ugly Truth         -4.199788e+09
# Amour                  -2.499804e+09
# The Hebrew Hammer      -2.397702e+09
# The Whole Nine Yards   -2.127110e+09
# Black Book             -1.099561e+09
# Name: net_income, dtype: float64

# %% [markdown]
# Si quisieramos encontrar las top-5 películas por nivel de retorno podemos usar `nlargest` (de nuevo, también funciona para los *DataFrames*):

# %%
top_5 = serie_ni.nlargest(5)
top_5
# Out:
# movie_title
# The Helix... Loaded     523505847.0
# Flashdance              502177271.0
# The Wedding Planner     458672302.0
# The Insider             449935665.0
# The Face of an Angel    424449459.0
# Name: net_income, dtype: float64
