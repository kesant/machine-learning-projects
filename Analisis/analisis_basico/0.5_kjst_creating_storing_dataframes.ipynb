# %% [markdown]
# # Creación y almacenamiento de *DataFrames*
#
# En esta lección veremos diferentes métodos para crear y almacenar *DataFrames* usando formatos adicionales al CSV y que también son de uso común en Ciencia de Datos y Machine Learning.
#
# En particular veremos:
#
# - Cómo crear desde cero un *DataFrame* a partir de un diccionario en Python
# - Cómo crear un *DataFrame* a partir de un archivo JSON y cómo almacenar un *DataFrame* en formato JSON
# - Cómo crear un archivo de Excel a partir de uno o múltiples *DataFrames* y cómo crear *DataFrames* a partir de archivos Excel

# %% [markdown]
# ## 1. Creación de un *DataFrame* a partir de un diccionario
#
# Es muy sencillo crear un *DataFrame* a partir de un diccionario de Python. Recordemos que un diccionario de Python contiene pares *key*-*values*, así que al momento de la creación:
#
# - Cada *key* del diccionario se convertirá en una columna del *DataFrame*
# - Los *values* correspondientes a cada *key* serán precisamente el contenido de cada columna del *DataFrame*
#
# Entendamos esto con un ejemplo:
#
# - El objetivo es crear un *DataFrame* con las columnas "Ciudad", "País" y "Población".
# - La columna "Ciudad" debe contener las ciudades "París", "Milán", "Nueva York" y "Londres"
# - Las columnas "País" y "Población" deben contener el país y la población (en millones de habitantes) de cada una de las ciudades
#
# Es decir, el resultado debería ser algo como esto:
#
# | **Ciudad** | **País**       | **Población** |
# |------------|----------------|---------------|
# | París      | Francia        | 2161000       |
# | Milán      | Italia         | 1352000       |
# | Nueva York | Estados Unidos | 8468000       |
# | Londres    | Inglaterra     | 8982000       |

# %%
# Paso 1:  crear el diccionario
ciudades = {"Ciudad": ['París', 'Milán', 'Nueva York', 'Londres'],
         'País': ['Francia', 'Italia', 'Estados Unidos', 'Inglaterra'],
         'Población': [2161000, 1352000, 8468000, 8982000]}

for key, values in ciudades.items():
    print(f'{key}:{values}')
# Out:
# Ciudad:['París', 'Milán', 'Nueva York', 'Londres']
# País:['Francia', 'Italia', 'Estados Unidos', 'Inglaterra']
# Población:[2161000, 1352000, 8468000, 8982000]

# %%
# Paso 2: crear el *DataFrame* con el método "DataFrame"
import pandas as pd

df_ciudades = pd.DataFrame(ciudades)
df_ciudades
# Out:
#        Ciudad            País  Población
# 0       París         Francia    2161000
# 1       Milán          Italia    1352000
# 2  Nueva York  Estados Unidos    8468000
# 3     Londres      Inglaterra    8982000

# %% [markdown]
# ## 2. Creación de un *DataFrame* a partir de un archivo JSON
#
# El formato de archivos JSON (*JavaScript Object Notation*) es uno de los más comunes en Ciencia de Datos y Machine Learning, y tiene una estructura muy similar a la de un diccionario en Python. De este tipo de archivo hablamos en detalle en el curso "Python Nivel Avanzado".
#
# Dada la similitud con un diccionario podemos leerlo como datos tabulares en Python.
#
# Para entender cómo realizar esta lectura hagamos uso del archivo [stations.json](https://raw.githubusercontent.com/codificandobits/pandas-nivel-basico-data/main/stations.json) que contiene información geo-referenciada del sistema de bicicletas de la ciudad de Nueva York.
#
# Por cada estación de bicicletas se dispone de esta información:
#
# - *id* y *stationName*: número identificador y nombre de cada estación
# - *availableDocks*: número de puestos disponibles para el parqueo de bicicletas
# - *totalDocks*: número total de puestos para el parqueo de bicicletas
# - *latitude*, *longitud*: coordenadas geográficas de la estación
# - *statusValue*, *statusKey*: indican si la estación está funcionando (*In Service*, 1) o no. Para el caso de este archivo **todas** las estaciones están prestando servicio
# - *availableBikes*: cantidad de bicicletas disponibles
# - *stAddress1*, *stAddress2*: dirección donde se encuentra ubicada la estación
# - *testStation*: indica si se trata de una estación de prueba. En todos los casos este valor es *false*
# - *lastCommunicationTime*: fecha y hora en la que se obtuvo la última actualización de la estación
# - *city*, *postalCode*, *location*, *altitude*, *landMark*: campos no usados
#
# Comencemos leyendo el archivo JSON para entender el detalle de su contenido:

# %%
# Importación de librerías
from urllib.request import urlopen
import json

# Lectura del archivo como un diccionario en Python
respuesta = urlopen("https://raw.githubusercontent.com/codificandobits/pandas-nivel-basico-data/main/stations.json")
respuesta = respuesta.read()
json_data = json.loads(respuesta)
type(json_data)
# Out:
# dict

# %%
# El contenido del diccionario
json_data
# Out:
# {'executionTime': '2016-01-22 04:32:49 PM',
#  'stationBeanList': [{'id': 72,
#    'stationName': 'W 52 St & 11 Ave',
#    'availableDocks': 32,
#    'totalDocks': 39,
#    'latitude': 40.76727216,
#    'longitude': -73.99392888,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'W 52 St & 11 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:15 PM',
#    'landMark': ''},
#   {'id': 79,
#    'stationName': 'Franklin St & W Broadway',
#    'availableDocks': 0,
#    'totalDocks': 33,
#    'latitude': 40.71911552,
#    'longitude': -74.00666661,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 33,
#    'stAddress1': 'Franklin St & W Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:41 PM',
#    'landMark': ''},
#   {'id': 82,
#    'stationName': 'St James Pl & Pearl St',
#    'availableDocks': 27,
#    'totalDocks': 27,
#    'latitude': 40.71117416,
#    'longitude': -74.00016545,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'St James Pl & Pearl St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:41 PM',
#    'landMark': ''},
#   {'id': 83,
#    'stationName': 'Atlantic Ave & Fort Greene Pl',
#    'availableDocks': 21,
#    'totalDocks': 62,
#    'latitude': 40.68382604,
#    'longitude': -73.97632328,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 40,
#    'stAddress1': 'Atlantic Ave & Fort Greene Pl',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:33 PM',
#    'landMark': ''},
#   {'id': 116,
#    'stationName': 'W 17 St & 8 Ave',
#    'availableDocks': 19,
#    'totalDocks': 39,
#    'latitude': 40.74177603,
#    'longitude': -74.00149746,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 19,
#    'stAddress1': 'W 17 St & 8 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:32 PM',
#    'landMark': ''},
#   {'id': 119,
#    'stationName': 'Park Ave & St Edwards St',
#    'availableDocks': 15,
#    'totalDocks': 19,
#    'latitude': 40.69608941,
#    'longitude': -73.97803415,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Park Ave & St Edwards St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:29 PM',
#    'landMark': ''},
#   {'id': 120,
#    'stationName': 'Lexington Ave & Classon Ave',
#    'availableDocks': 17,
#    'totalDocks': 19,
#    'latitude': 40.68676793,
#    'longitude': -73.95928168,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Lexington Ave & Classon Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:06 PM',
#    'landMark': ''},
#   {'id': 127,
#    'stationName': 'Barrow St & Hudson St',
#    'availableDocks': 21,
#    'totalDocks': 31,
#    'latitude': 40.73172428,
#    'longitude': -74.00674436,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 9,
#    'stAddress1': 'Barrow St & Hudson St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:14 PM',
#    'landMark': ''},
#   {'id': 128,
#    'stationName': 'MacDougal St & Prince St',
#    'availableDocks': 9,
#    'totalDocks': 30,
#    'latitude': 40.72710258,
#    'longitude': -74.00297088,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 21,
#    'stAddress1': 'MacDougal St & Prince St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:57 PM',
#    'landMark': ''},
#   {'id': 137,
#    'stationName': 'E 56 St & Madison Ave',
#    'availableDocks': 15,
#    'totalDocks': 46,
#    'latitude': 40.761628,
#    'longitude': -73.972924,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 30,
#    'stAddress1': 'E 56 St & Madison Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:12 PM',
#    'landMark': ''},
#   {'id': 143,
#    'stationName': 'Clinton St & Joralemon St',
#    'availableDocks': 20,
#    'totalDocks': 24,
#    'latitude': 40.69239502,
#    'longitude': -73.99337909,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Clinton St & Joralemon St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:28:55 PM',
#    'landMark': ''},
#   {'id': 144,
#    'stationName': 'Nassau St & Navy St',
#    'availableDocks': 5,
#    'totalDocks': 19,
#    'latitude': 40.69839895,
#    'longitude': -73.98068914,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 12,
#    'stAddress1': 'Nassau St & Navy St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:05 PM',
#    'landMark': ''},
#   {'id': 146,
#    'stationName': 'Hudson St & Reade St',
#    'availableDocks': 30,
#    'totalDocks': 39,
#    'latitude': 40.71625008,
#    'longitude': -74.0091059,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Hudson St & Reade St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:37 PM',
#    'landMark': ''},
#   {'id': 147,
#    'stationName': 'Greenwich St & Warren St',
#    'availableDocks': 18,
#    'totalDocks': 33,
#    'latitude': 40.71542197,
#    'longitude': -74.01121978,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 15,
#    'stAddress1': 'Greenwich St & Warren St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:05 PM',
#    'landMark': ''},
#   {'id': 150,
#    'stationName': 'E 2 St & Avenue C',
#    'availableDocks': 29,
#    'totalDocks': 31,
#    'latitude': 40.7208736,
#    'longitude': -73.98085795,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'E 2 St & Avenue C',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:04 PM',
#    'landMark': ''},
#   {'id': 151,
#    'stationName': 'Cleveland Pl & Spring St',
#    'availableDocks': 22,
#    'totalDocks': 33,
#    'latitude': 40.722103786686034,
#    'longitude': -73.99724900722504,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 11,
#    'stAddress1': 'Cleveland Pl & Spring St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:42 PM',
#    'landMark': ''},
#   {'id': 152,
#    'stationName': 'Warren St & Church St',
#    'availableDocks': 3,
#    'totalDocks': 29,
#    'latitude': 40.71473993,
#    'longitude': -74.00910627,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 26,
#    'stAddress1': 'Warren St & Church St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:04 PM',
#    'landMark': ''},
#   {'id': 153,
#    'stationName': 'E 40 St & 5 Ave',
#    'availableDocks': 36,
#    'totalDocks': 55,
#    'latitude': 40.752062307,
#    'longitude': -73.9816324043,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 17,
#    'stAddress1': 'E 40 St & 5 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:08 PM',
#    'landMark': ''},
#   {'id': 157,
#    'stationName': 'Henry St & Atlantic Ave',
#    'availableDocks': 16,
#    'totalDocks': 23,
#    'latitude': 40.69089272,
#    'longitude': -73.99612349,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'Henry St & Atlantic Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:42 PM',
#    'landMark': ''},
#   {'id': 160,
#    'stationName': 'E 37 St & Lexington Ave',
#    'availableDocks': 23,
#    'totalDocks': 26,
#    'latitude': 40.748238,
#    'longitude': -73.978311,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'E 37 St & Lexington Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:48 PM',
#    'landMark': ''},
#   {'id': 161,
#    'stationName': 'LaGuardia Pl & W 3 St',
#    'availableDocks': 8,
#    'totalDocks': 35,
#    'latitude': 40.72917025,
#    'longitude': -73.99810231,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 25,
#    'stAddress1': 'LaGuardia Pl & W 3 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:54 PM',
#    'landMark': ''},
#   {'id': 164,
#    'stationName': 'E 47 St & 2 Ave',
#    'availableDocks': 37,
#    'totalDocks': 47,
#    'latitude': 40.75323098,
#    'longitude': -73.97032517,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'E 47 St & 2 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:29 PM',
#    'landMark': ''},
#   {'id': 167,
#    'stationName': 'E 39 St & 3 Ave',
#    'availableDocks': 22,
#    'totalDocks': 45,
#    'latitude': 40.7489006,
#    'longitude': -73.97604882,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 23,
#    'stAddress1': 'E 39 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:10 PM',
#    'landMark': ''},
#   {'id': 168,
#    'stationName': 'W 18 St & 6 Ave',
#    'availableDocks': 11,
#    'totalDocks': 47,
#    'latitude': 40.73971301,
#    'longitude': -73.99456405,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 34,
#    'stAddress1': 'W 18 St & 6 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:05 PM',
#    'landMark': ''},
#   {'id': 173,
#    'stationName': 'Broadway & W 49 St',
#    'availableDocks': 43,
#    'totalDocks': 51,
#    'latitude': 40.76068327096592,
#    'longitude': -73.9845272898674,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Broadway & W 49 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:12 PM',
#    'landMark': ''},
#   {'id': 174,
#    'stationName': 'E 25 St & 1 Ave',
#    'availableDocks': 21,
#    'totalDocks': 30,
#    'latitude': 40.7381765,
#    'longitude': -73.97738662,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 9,
#    'stAddress1': 'E 25 St & 1 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:15 PM',
#    'landMark': ''},
#   {'id': 195,
#    'stationName': 'Liberty St & Broadway',
#    'availableDocks': 25,
#    'totalDocks': 45,
#    'latitude': 40.70905623,
#    'longitude': -74.01043382,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 20,
#    'stAddress1': 'Liberty St & Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:32 PM',
#    'landMark': ''},
#   {'id': 212,
#    'stationName': 'W 16 St & The High Line',
#    'availableDocks': 24,
#    'totalDocks': 28,
#    'latitude': 40.74334935,
#    'longitude': -74.00681753,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'W 16 St & The High Line',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:33 PM',
#    'landMark': ''},
#   {'id': 216,
#    'stationName': 'Columbia Heights & Cranberry St',
#    'availableDocks': 13,
#    'totalDocks': 23,
#    'latitude': 40.70037867,
#    'longitude': -73.99548059,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Columbia Heights & Cranberry St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:52 PM',
#    'landMark': ''},
#   {'id': 217,
#    'stationName': 'Old Fulton St',
#    'availableDocks': 22,
#    'totalDocks': 39,
#    'latitude': 40.70277159,
#    'longitude': -73.99383605,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 15,
#    'stAddress1': 'Old Fulton St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:06 PM',
#    'landMark': ''},
#   {'id': 223,
#    'stationName': 'W 13 St & 7 Ave',
#    'availableDocks': 21,
#    'totalDocks': 33,
#    'latitude': 40.73781509,
#    'longitude': -73.99994661,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'W 13 St & 7 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:46 PM',
#    'landMark': ''},
#   {'id': 224,
#    'stationName': 'Spruce St & Nassau St',
#    'availableDocks': 27,
#    'totalDocks': 31,
#    'latitude': 40.71146364,
#    'longitude': -74.00552427,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Spruce St & Nassau St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:07 PM',
#    'landMark': ''},
#   {'id': 225,
#    'stationName': 'W 14 St & The High Line',
#    'availableDocks': 19,
#    'totalDocks': 37,
#    'latitude': 40.74195138,
#    'longitude': -74.00803013,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 17,
#    'stAddress1': 'W 14 St & The High Line',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:24 PM',
#    'landMark': ''},
#   {'id': 228,
#    'stationName': 'E 48 St & 3 Ave',
#    'availableDocks': 44,
#    'totalDocks': 55,
#    'latitude': 40.7546011026,
#    'longitude': -73.971878855,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'E 48 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:09 PM',
#    'landMark': ''},
#   {'id': 229,
#    'stationName': 'Great Jones St',
#    'availableDocks': 1,
#    'totalDocks': 23,
#    'latitude': 40.72743423,
#    'longitude': -73.99379025,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 17,
#    'stAddress1': 'Great Jones St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:47 PM',
#    'landMark': ''},
#   {'id': 232,
#    'stationName': 'Cadman Plaza E & Tillary St',
#    'availableDocks': 16,
#    'totalDocks': 23,
#    'latitude': 40.69597683,
#    'longitude': -73.99014892,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Cadman Plaza E & Tillary St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:35 PM',
#    'landMark': ''},
#   {'id': 233,
#    'stationName': 'Cadman Plaza W & Pierrepont St',
#    'availableDocks': 35,
#    'totalDocks': 38,
#    'latitude': 40.69475701363877,
#    'longitude': -73.99052739143372,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Cadman Plaza W & Pierrepont St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:00 PM',
#    'landMark': ''},
#   {'id': 236,
#    'stationName': 'St Marks Pl & 2 Ave',
#    'availableDocks': 33,
#    'totalDocks': 39,
#    'latitude': 40.7284186,
#    'longitude': -73.98713956,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'St Marks Pl & 2 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:45 PM',
#    'landMark': ''},
#   {'id': 237,
#    'stationName': 'E 11 St & 2 Ave',
#    'availableDocks': 37,
#    'totalDocks': 39,
#    'latitude': 40.73047309,
#    'longitude': -73.98672378,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'E 11 St & 2 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:10 PM',
#    'landMark': ''},
#   {'id': 238,
#    'stationName': 'Bank St & Washington St',
#    'availableDocks': 14,
#    'totalDocks': 31,
#    'latitude': 40.7361967,
#    'longitude': -74.00859207,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 16,
#    'stAddress1': 'Bank St & Washington St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:29 PM',
#    'landMark': ''},
#   {'id': 239,
#    'stationName': 'Willoughby St & Fleet St',
#    'availableDocks': 17,
#    'totalDocks': 31,
#    'latitude': 40.69196566,
#    'longitude': -73.9813018,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 13,
#    'stAddress1': 'Willoughby St & Fleet St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:16 PM',
#    'landMark': ''},
#   {'id': 241,
#    'stationName': 'DeKalb Ave & S Portland Ave',
#    'availableDocks': 19,
#    'totalDocks': 23,
#    'latitude': 40.68981035,
#    'longitude': -73.97493121,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'DeKalb Ave & S Portland Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:16 PM',
#    'landMark': ''},
#   {'id': 242,
#    'stationName': 'Carlton Ave & Flushing Ave',
#    'availableDocks': 19,
#    'totalDocks': 23,
#    'latitude': 40.697787,
#    'longitude': -73.973736,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Carlton Ave & Flushing Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:34 PM',
#    'landMark': ''},
#   {'id': 243,
#    'stationName': 'Fulton St & Rockwell Pl',
#    'availableDocks': 4,
#    'totalDocks': 31,
#    'latitude': 40.688226,
#    'longitude': -73.979382,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 26,
#    'stAddress1': 'Fulton St & Rockwell Pl',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:28 PM',
#    'landMark': ''},
#   {'id': 244,
#    'stationName': 'Willoughby Ave & Hall St',
#    'availableDocks': 26,
#    'totalDocks': 31,
#    'latitude': 40.69196035,
#    'longitude': -73.96536851,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Willoughby Ave & Hall St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:36 PM',
#    'landMark': ''},
#   {'id': 245,
#    'stationName': 'Myrtle Ave & St Edwards St',
#    'availableDocks': 16,
#    'totalDocks': 23,
#    'latitude': 40.69327018,
#    'longitude': -73.97703874,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Myrtle Ave & St Edwards St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:56 PM',
#    'landMark': ''},
#   {'id': 247,
#    'stationName': 'Perry St & Bleecker St',
#    'availableDocks': 9,
#    'totalDocks': 20,
#    'latitude': 40.73535398,
#    'longitude': -74.00483091,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 11,
#    'stAddress1': 'Perry St & Bleecker St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:53 PM',
#    'landMark': ''},
#   {'id': 248,
#    'stationName': 'Laight St & Hudson St',
#    'availableDocks': 10,
#    'totalDocks': 23,
#    'latitude': 40.72185379,
#    'longitude': -74.00771779,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 12,
#    'stAddress1': 'Laight St & Hudson St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:38 PM',
#    'landMark': ''},
#   {'id': 249,
#    'stationName': 'Harrison St & Hudson St',
#    'availableDocks': 2,
#    'totalDocks': 27,
#    'latitude': 40.71870987,
#    'longitude': -74.0090009,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 25,
#    'stAddress1': 'Harrison St & Hudson St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:28:57 PM',
#    'landMark': ''},
#   {'id': 250,
#    'stationName': 'Lafayette St & Jersey St',
#    'availableDocks': 2,
#    'totalDocks': 40,
#    'latitude': 40.72456089,
#    'longitude': -73.99565293,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 35,
#    'stAddress1': 'Lafayette St & Jersey St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:11 PM',
#    'landMark': ''},
#   {'id': 251,
#    'stationName': 'Mott St & Prince St',
#    'availableDocks': 23,
#    'totalDocks': 27,
#    'latitude': 40.72317958,
#    'longitude': -73.99480012,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Mott St & Prince St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:19 PM',
#    'landMark': ''},
#   {'id': 252,
#    'stationName': 'MacDougal St & Washington Sq',
#    'availableDocks': 31,
#    'totalDocks': 33,
#    'latitude': 40.73226398,
#    'longitude': -73.99852205,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'MacDougal St & Washington Sq',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:38 PM',
#    'landMark': ''},
#   {'id': 253,
#    'stationName': 'W 13 St & 5 Ave',
#    'availableDocks': 39,
#    'totalDocks': 55,
#    'latitude': 40.73543934,
#    'longitude': -73.99453948,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 13,
#    'stAddress1': 'W 13 St & 5 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:37 PM',
#    'landMark': ''},
#   {'id': 254,
#    'stationName': 'W 11 St & 6 Ave',
#    'availableDocks': 25,
#    'totalDocks': 31,
#    'latitude': 40.73532427,
#    'longitude': -73.99800419,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'W 11 St & 6 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:27 PM',
#    'landMark': ''},
#   {'id': 257,
#    'stationName': 'Lispenard St & Broadway',
#    'availableDocks': 4,
#    'totalDocks': 39,
#    'latitude': 40.71939226,
#    'longitude': -74.00247214,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 33,
#    'stAddress1': 'Lispenard St & Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:12 PM',
#    'landMark': ''},
#   {'id': 258,
#    'stationName': 'DeKalb Ave & Vanderbilt Ave',
#    'availableDocks': 23,
#    'totalDocks': 23,
#    'latitude': 40.68940747,
#    'longitude': -73.96885458,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'DeKalb Ave & Vanderbilt Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:05 PM',
#    'landMark': ''},
#   {'id': 259,
#    'stationName': 'South St & Whitehall St',
#    'availableDocks': 4,
#    'totalDocks': 39,
#    'latitude': 40.70122128,
#    'longitude': -74.01234218,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 35,
#    'stAddress1': 'South St & Whitehall St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:12 PM',
#    'landMark': ''},
#   {'id': 260,
#    'stationName': 'Broad St & Bridge St',
#    'availableDocks': 10,
#    'totalDocks': 35,
#    'latitude': 40.70365182,
#    'longitude': -74.01167797,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 25,
#    'stAddress1': 'Broad St & Bridge St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:24 PM',
#    'landMark': ''},
#   {'id': 261,
#    'stationName': 'Johnson St & Gold St',
#    'availableDocks': 14,
#    'totalDocks': 27,
#    'latitude': 40.69474881,
#    'longitude': -73.98362464,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 13,
#    'stAddress1': 'Johnson St & Gold St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:52 PM',
#    'landMark': ''},
#   {'id': 262,
#    'stationName': 'Washington Park',
#    'availableDocks': 23,
#    'totalDocks': 24,
#    'latitude': 40.6917823,
#    'longitude': -73.9737299,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Washington Park',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:34 PM',
#    'landMark': ''},
#   {'id': 263,
#    'stationName': 'Elizabeth St & Hester St',
#    'availableDocks': 31,
#    'totalDocks': 31,
#    'latitude': 40.71729,
#    'longitude': -73.996375,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Elizabeth St & Hester St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:42 PM',
#    'landMark': ''},
#   {'id': 264,
#    'stationName': 'Maiden Ln & Pearl St',
#    'availableDocks': 3,
#    'totalDocks': 27,
#    'latitude': 40.70706456,
#    'longitude': -74.00731853,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 24,
#    'stAddress1': 'Maiden Ln & Pearl St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:19 PM',
#    'landMark': ''},
#   {'id': 265,
#    'stationName': 'Stanton St & Chrystie St',
#    'availableDocks': 24,
#    'totalDocks': 35,
#    'latitude': 40.72229346,
#    'longitude': -73.99147535,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Stanton St & Chrystie St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:27 PM',
#    'landMark': ''},
#   {'id': 266,
#    'stationName': 'Avenue D & E 8 St',
#    'availableDocks': 22,
#    'totalDocks': 24,
#    'latitude': 40.72368361,
#    'longitude': -73.97574813,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Avenue D & E 8 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:24 PM',
#    'landMark': ''},
#   {'id': 267,
#    'stationName': 'Broadway & W 36 St',
#    'availableDocks': 56,
#    'totalDocks': 57,
#    'latitude': 40.75097711,
#    'longitude': -73.98765428,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Broadway & W 36 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:27 PM',
#    'landMark': ''},
#   {'id': 268,
#    'stationName': 'Howard St & Centre St',
#    'availableDocks': 2,
#    'totalDocks': 27,
#    'latitude': 40.71910537,
#    'longitude': -73.99973337,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 25,
#    'stAddress1': 'Howard St & Centre St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:05 PM',
#    'landMark': ''},
#   {'id': 270,
#    'stationName': 'Adelphi St & Myrtle Ave',
#    'availableDocks': 17,
#    'totalDocks': 23,
#    'latitude': 40.69308257,
#    'longitude': -73.97178913,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Adelphi St & Myrtle Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:18 PM',
#    'landMark': ''},
#   {'id': 274,
#    'stationName': 'Lafayette Ave & Fort Greene Pl',
#    'availableDocks': 11,
#    'totalDocks': 31,
#    'latitude': 40.68691865,
#    'longitude': -73.976682,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 20,
#    'stAddress1': 'Lafayette Ave & Fort Greene Pl',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:25 PM',
#    'landMark': ''},
#   {'id': 275,
#    'stationName': 'Washington Ave & Greene Ave',
#    'availableDocks': 16,
#    'totalDocks': 19,
#    'latitude': 40.68650065,
#    'longitude': -73.96563307,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Washington Ave & Greene Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:51 PM',
#    'landMark': ''},
#   {'id': 276,
#    'stationName': 'Duane St & Greenwich St',
#    'availableDocks': 2,
#    'totalDocks': 25,
#    'latitude': 40.71748752,
#    'longitude': -74.0104554,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 22,
#    'stAddress1': 'Duane St & Greenwich St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:57 PM',
#    'landMark': ''},
#   {'id': 278,
#    'stationName': 'Concord St & Bridge St',
#    'availableDocks': 8,
#    'totalDocks': 19,
#    'latitude': 40.69766564,
#    'longitude': -73.98476437,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Concord St & Bridge St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:17 PM',
#    'landMark': ''},
#   {'id': 279,
#    'stationName': 'Peck Slip & Front St',
#    'availableDocks': 13,
#    'totalDocks': 36,
#    'latitude': 40.707873,
#    'longitude': -74.00167,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 23,
#    'stAddress1': 'Peck Slip & Front St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:22 PM',
#    'landMark': ''},
#   {'id': 280,
#    'stationName': 'E 10 St & 5 Ave',
#    'availableDocks': 10,
#    'totalDocks': 31,
#    'latitude': 40.73331967,
#    'longitude': -73.99510132,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 20,
#    'stAddress1': 'E 10 St & 5 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:37 PM',
#    'landMark': ''},
#   {'id': 281,
#    'stationName': 'Grand Army Plaza & Central Park S',
#    'availableDocks': 33,
#    'totalDocks': 59,
#    'latitude': 40.7643971,
#    'longitude': -73.97371465,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 26,
#    'stAddress1': 'Grand Army Plaza & Central Park S',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:55 PM',
#    'landMark': ''},
#   {'id': 282,
#    'stationName': 'Kent Ave & S 11 St',
#    'availableDocks': 23,
#    'totalDocks': 27,
#    'latitude': 40.70827295,
#    'longitude': -73.96834101,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Kent Ave & S 11 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:08 PM',
#    'landMark': ''},
#   {'id': 284,
#    'stationName': 'Greenwich Ave & 8 Ave',
#    'availableDocks': 16,
#    'totalDocks': 43,
#    'latitude': 40.7390169121,
#    'longitude': -74.0026376103,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 26,
#    'stAddress1': 'Greenwich Ave & 8 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:12 PM',
#    'landMark': ''},
#   {'id': 285,
#    'stationName': 'Broadway & E 14 St',
#    'availableDocks': 36,
#    'totalDocks': 47,
#    'latitude': 40.73454567,
#    'longitude': -73.99074142,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Broadway & E 14 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:31 PM',
#    'landMark': ''},
#   {'id': 289,
#    'stationName': 'Monroe St & Classon Ave',
#    'availableDocks': 13,
#    'totalDocks': 19,
#    'latitude': 40.6845683,
#    'longitude': -73.95881081,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'Monroe St & Classon Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:06 PM',
#    'landMark': ''},
#   {'id': 291,
#    'stationName': 'Madison St & Montgomery St',
#    'availableDocks': 20,
#    'totalDocks': 20,
#    'latitude': 40.713126,
#    'longitude': -73.984844,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Madison St & Montgomery St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:15 PM',
#    'landMark': ''},
#   {'id': 293,
#    'stationName': 'Lafayette St & E 8 St',
#    'availableDocks': 42,
#    'totalDocks': 55,
#    'latitude': 40.73028666,
#    'longitude': -73.9907647,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Lafayette St & E 8 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:19 PM',
#    'landMark': ''},
#   {'id': 295,
#    'stationName': 'Pike St & E Broadway',
#    'availableDocks': 24,
#    'totalDocks': 24,
#    'latitude': 40.71406667,
#    'longitude': -73.99293911,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Pike St & E Broadway',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:05 PM',
#    'landMark': ''},
#   {'id': 296,
#    'stationName': 'Division St & Bowery',
#    'availableDocks': 6,
#    'totalDocks': 35,
#    'latitude': 40.71413089,
#    'longitude': -73.9970468,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 27,
#    'stAddress1': 'Division St & Bowery',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:10 PM',
#    'landMark': ''},
#   {'id': 297,
#    'stationName': 'E 15 St & 3 Ave',
#    'availableDocks': 21,
#    'totalDocks': 27,
#    'latitude': 40.734232,
#    'longitude': -73.986923,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'E 15 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:03 PM',
#    'landMark': ''},
#   {'id': 298,
#    'stationName': '3 Ave & Schermerhorn St',
#    'availableDocks': 14,
#    'totalDocks': 35,
#    'latitude': 40.68683208,
#    'longitude': -73.9796772,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 21,
#    'stAddress1': '3 Ave & Schermerhorn St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:19 PM',
#    'landMark': ''},
#   {'id': 300,
#    'stationName': 'Shevchenko Pl & E 7 St',
#    'availableDocks': 42,
#    'totalDocks': 55,
#    'latitude': 40.728145,
#    'longitude': -73.990214,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 11,
#    'stAddress1': 'Shevchenko Pl & E 7 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:46 PM',
#    'landMark': ''},
#   {'id': 301,
#    'stationName': 'E 2 St & Avenue B',
#    'availableDocks': 35,
#    'totalDocks': 37,
#    'latitude': 40.72217444,
#    'longitude': -73.98368779,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'E 2 St & Avenue B',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:27 PM',
#    'landMark': ''},
#   {'id': 302,
#    'stationName': 'Avenue D & E 3 St',
#    'availableDocks': 23,
#    'totalDocks': 23,
#    'latitude': 40.72082834,
#    'longitude': -73.97793172,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Avenue D & E 3 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:29 PM',
#    'landMark': ''},
#   {'id': 303,
#    'stationName': 'Mercer St & Spring St',
#    'availableDocks': 10,
#    'totalDocks': 31,
#    'latitude': 40.72362738,
#    'longitude': -73.99949601,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 21,
#    'stAddress1': 'Mercer St & Spring St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:02 PM',
#    'landMark': ''},
#   {'id': 304,
#    'stationName': 'Broadway & Battery Pl',
#    'availableDocks': 7,
#    'totalDocks': 36,
#    'latitude': 40.70463334,
#    'longitude': -74.01361706,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 27,
#    'stAddress1': 'Broadway & Battery Pl',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:14 PM',
#    'landMark': ''},
#   {'id': 305,
#    'stationName': 'E 58 St & 3 Ave',
#    'availableDocks': 13,
#    'totalDocks': 33,
#    'latitude': 40.76095756,
#    'longitude': -73.96724467,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 19,
#    'stAddress1': 'E 58 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:28 PM',
#    'landMark': ''},
#   {'id': 306,
#    'stationName': 'Cliff St & Fulton St',
#    'availableDocks': 10,
#    'totalDocks': 37,
#    'latitude': 40.70823502,
#    'longitude': -74.00530063,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 25,
#    'stAddress1': 'Cliff St & Fulton St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:46 PM',
#    'landMark': ''},
#   {'id': 307,
#    'stationName': 'Canal St & Rutgers St',
#    'availableDocks': 27,
#    'totalDocks': 29,
#    'latitude': 40.71427487,
#    'longitude': -73.98990025,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Canal St & Rutgers St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:44 PM',
#    'landMark': ''},
#   {'id': 308,
#    'stationName': 'St James Pl & Oliver St',
#    'availableDocks': 21,
#    'totalDocks': 27,
#    'latitude': 40.71307916,
#    'longitude': -73.99851193,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'St James Pl & Oliver St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:38 PM',
#    'landMark': ''},
#   {'id': 309,
#    'stationName': 'Murray St & West St',
#    'availableDocks': 4,
#    'totalDocks': 41,
#    'latitude': 40.7149787,
#    'longitude': -74.013012,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 37,
#    'stAddress1': 'Murray St & West St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:43 PM',
#    'landMark': ''},
#   {'id': 310,
#    'stationName': 'State St & Smith St',
#    'availableDocks': 22,
#    'totalDocks': 36,
#    'latitude': 40.68926942,
#    'longitude': -73.98912867,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 12,
#    'stAddress1': 'State St & Smith St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:51 PM',
#    'landMark': ''},
#   {'id': 311,
#    'stationName': 'Norfolk St & Broome St',
#    'availableDocks': 26,
#    'totalDocks': 31,
#    'latitude': 40.7172274,
#    'longitude': -73.98802084,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Norfolk St & Broome St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:04 PM',
#    'landMark': ''},
#   {'id': 312,
#    'stationName': 'Allen St & E Houston St',
#    'availableDocks': 26,
#    'totalDocks': 31,
#    'latitude': 40.722055,
#    'longitude': -73.989111,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Allen St & E Houston St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:33 PM',
#    'landMark': ''},
#   {'id': 313,
#    'stationName': 'Washington Ave & Park Ave',
#    'availableDocks': 1,
#    'totalDocks': 23,
#    'latitude': 40.69610226,
#    'longitude': -73.96751037,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 22,
#    'stAddress1': 'Washington Ave & Park Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:20 PM',
#    'landMark': ''},
#   {'id': 314,
#    'stationName': 'Cadman Plaza West & Montague St',
#    'availableDocks': 20,
#    'totalDocks': 39,
#    'latitude': 40.69383,
#    'longitude': -73.990539,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 18,
#    'stAddress1': 'Cadman Plaza West & Montague St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:34 PM',
#    'landMark': ''},
#   {'id': 315,
#    'stationName': 'South St & Gouverneur Ln',
#    'availableDocks': 6,
#    'totalDocks': 29,
#    'latitude': 40.70355377,
#    'longitude': -74.00670227,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 23,
#    'stAddress1': 'South St & Gouverneur Ln',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:34 PM',
#    'landMark': ''},
#   {'id': 316,
#    'stationName': 'Fulton St & William St',
#    'availableDocks': 10,
#    'totalDocks': 43,
#    'latitude': 40.70955958,
#    'longitude': -74.00653609,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 32,
#    'stAddress1': 'Fulton St & William St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:28:58 PM',
#    'landMark': ''},
#   {'id': 317,
#    'stationName': 'E 6 St & Avenue B',
#    'availableDocks': 17,
#    'totalDocks': 27,
#    'latitude': 40.72453734,
#    'longitude': -73.98185424,
#    'statusValue': 'In Service',
# ...
#    'landMark': ''},
#   {'id': 3202,
#    'stationName': 'Newport PATH',
#    'availableDocks': 5,
#    'totalDocks': 18,
#    'latitude': 40.7272235,
#    'longitude': -74.0337589,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'Newport PATH',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:34 PM',
#    'landMark': ''},
#   {'id': 3203,
#    'stationName': 'Hamilton Park',
#    'availableDocks': 14,
#    'totalDocks': 25,
#    'latitude': 40.727595966,
#    'longitude': -74.044247311,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 9,
#    'stAddress1': 'Hamilton Park',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:44 PM',
#    'landMark': ''},
#   {'id': 3205,
#    'stationName': 'JC Medical Center',
#    'availableDocks': 15,
#    'totalDocks': 22,
#    'latitude': 40.7165271,
#    'longitude': -74.049425,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 6,
#    'stAddress1': 'JC Medical Center',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:24 PM',
#    'landMark': ''},
#   {'id': 3206,
#    'stationName': 'Hilltop',
#    'availableDocks': 22,
#    'totalDocks': 26,
#    'latitude': 40.7311689,
#    'longitude': -74.0575736,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Hilltop',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:44 PM',
#    'landMark': ''},
#   {'id': 3207,
#    'stationName': 'Oakland Ave',
#    'availableDocks': 12,
#    'totalDocks': 14,
#    'latitude': 40.7376037,
#    'longitude': -74.0524783,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Oakland Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:29 PM',
#    'landMark': ''},
#   {'id': 3209,
#    'stationName': 'Brunswick St',
#    'availableDocks': 17,
#    'totalDocks': 18,
#    'latitude': 40.7241765,
#    'longitude': -74.0506564,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Brunswick St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:28 PM',
#    'landMark': ''},
#   {'id': 3210,
#    'stationName': 'Pershing Field',
#    'availableDocks': 9,
#    'totalDocks': 18,
#    'latitude': 40.742677141,
#    'longitude': -74.051788633,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Pershing Field',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:09 PM',
#    'landMark': ''},
#   {'id': 3211,
#    'stationName': 'Newark Ave',
#    'availableDocks': 13,
#    'totalDocks': 21,
#    'latitude': 40.72152515,
#    'longitude': -74.046304543,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 8,
#    'stAddress1': 'Newark Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:53 PM',
#    'landMark': ''},
#   {'id': 3212,
#    'stationName': 'Christ Hospital',
#    'availableDocks': 17,
#    'totalDocks': 22,
#    'latitude': 40.734785818,
#    'longitude': -74.050443636,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'Christ Hospital',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:16 PM',
#    'landMark': ''},
#   {'id': 3213,
#    'stationName': 'Van Vorst Park',
#    'availableDocks': 11,
#    'totalDocks': 22,
#    'latitude': 40.71848892,
#    'longitude': -74.047726625,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 9,
#    'stAddress1': 'Van Vorst Park',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:30 PM',
#    'landMark': ''},
#   {'id': 3214,
#    'stationName': 'Essex Light Rail',
#    'availableDocks': 22,
#    'totalDocks': 22,
#    'latitude': 40.7127742,
#    'longitude': -74.0364857,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Essex Light Rail',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:35 PM',
#    'landMark': ''},
#   {'id': 3215,
#    'stationName': 'Central Ave',
#    'availableDocks': 15,
#    'totalDocks': 18,
#    'latitude': 40.7467299,
#    'longitude': -74.0492509,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'Central Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:30 PM',
#    'landMark': ''},
#   {'id': 3216,
#    'stationName': 'Columbia Park',
#    'availableDocks': 11,
#    'totalDocks': 18,
#    'latitude': 40.6970299,
#    'longitude': -74.0969366,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 7,
#    'stAddress1': 'Columbia Park',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:15 PM',
#    'landMark': ''},
#   {'id': 3217,
#    'stationName': 'Bayside Park',
#    'availableDocks': 12,
#    'totalDocks': 18,
#    'latitude': 40.698650544,
#    'longitude': -74.082079678,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'Bayside Park',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:41 PM',
#    'landMark': ''},
#   {'id': 3220,
#    'stationName': '5 Corners Library',
#    'availableDocks': 12,
#    'totalDocks': 18,
#    'latitude': 40.734961020009514,
#    'longitude': -74.0595030784607,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': '5 Corners Library',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:58 PM',
#    'landMark': ''},
#   {'id': 3221,
#    'stationName': '47 Ave & 31 St',
#    'availableDocks': 12,
#    'totalDocks': 27,
#    'latitude': 40.743,
#    'longitude': -73.93561,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 15,
#    'stAddress1': '47 Ave & 31 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:10 PM',
#    'landMark': ''},
#   {'id': 3222,
#    'stationName': 'Hanson Pl & St Felix St',
#    'availableDocks': 21,
#    'totalDocks': 39,
#    'latitude': 40.685159599891776,
#    'longitude': -73.97711366415024,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 18,
#    'stAddress1': 'Hanson Pl & St Felix St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:32:08 PM',
#    'landMark': ''},
#   {'id': 3223,
#    'stationName': 'E 55 St & 3 Ave',
#    'availableDocks': 50,
#    'totalDocks': 55,
#    'latitude': 40.758996559605116,
#    'longitude': -73.96865397691727,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 5,
#    'stAddress1': 'E 55 St & 3 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:29 PM',
#    'landMark': ''},
#   {'id': 3224,
#    'stationName': 'W 13 St & Hudson St',
#    'availableDocks': 29,
#    'totalDocks': 39,
#    'latitude': 40.73997354103409,
#    'longitude': -74.00513872504234,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'W 13 St & Hudson St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:56 PM',
#    'landMark': ''},
#   {'id': 3225,
#    'stationName': 'Baldwin at Montgomery',
#    'availableDocks': 10,
#    'totalDocks': 14,
#    'latitude': 40.7236589,
#    'longitude': -74.0641943,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 3,
#    'stAddress1': 'Baldwin at Montgomery',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:20 PM',
#    'landMark': ''},
#   {'id': 3226,
#    'stationName': 'W 82 St & Central Park West',
#    'availableDocks': 45,
#    'totalDocks': 45,
#    'latitude': 40.78275,
#    'longitude': -73.97137,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'W 82 St & Central Park West',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:32 PM',
#    'landMark': ''},
#   {'id': 3229,
#    'stationName': 'Marcy Ave & MacDonough St',
#    'availableDocks': 19,
#    'totalDocks': 19,
#    'latitude': 40.68061768455451,
#    'longitude': -73.94624948501587,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Marcy Ave & MacDonough St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:29:51 PM',
#    'landMark': ''},
#   {'id': 3230,
#    'stationName': 'Penn Station Valet',
#    'availableDocks': 7,
#    'totalDocks': 7,
#    'latitude': 40.751283596962296,
#    'longitude': -73.99692445993422,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 0,
#    'stAddress1': 'Penn Station Valet',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:28:51 PM',
#    'landMark': ''},
#   {'id': 3231,
#    'stationName': 'E 67 St & Park Ave',
#    'availableDocks': 48,
#    'totalDocks': 59,
#    'latitude': 40.76780080148132,
#    'longitude': -73.96592080593109,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 10,
#    'stAddress1': 'E 67 St & Park Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:03 PM',
#    'landMark': ''},
#   {'id': 3232,
#    'stationName': 'Bond St & Fulton St',
#    'availableDocks': 20,
#    'totalDocks': 31,
#    'latitude': 40.68962188790333,
#    'longitude': -73.98304268717766,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 11,
#    'stAddress1': 'Bond St & Fulton St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:20 PM',
#    'landMark': ''},
#   {'id': 3233,
#    'stationName': 'E 48 St & 5 Ave',
#    'availableDocks': 17,
#    'totalDocks': 39,
#    'latitude': 40.75724567911726,
#    'longitude': -73.97805914282799,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 16,
#    'stAddress1': 'E 48 St & 5 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:56 PM',
#    'landMark': ''},
#   {'id': 3235,
#    'stationName': 'E 41 St & Madison Ave',
#    'availableDocks': 27,
#    'totalDocks': 31,
#    'latitude': 40.752165280621966,
#    'longitude': -73.97992193698882,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'E 41 St & Madison Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:28:53 PM',
#    'landMark': ''},
#   {'id': 3236,
#    'stationName': 'PABT Valet',
#    'availableDocks': 7,
#    'totalDocks': 9,
#    'latitude': 40.75898481399634,
#    'longitude': -73.99379968643188,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'PABT Valet',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:59 PM',
#    'landMark': ''},
#   {'id': 3237,
#    'stationName': '21 St & 41 Ave',
#    'availableDocks': 17,
#    'totalDocks': 25,
#    'latitude': 40.75383343437622,
#    'longitude': -73.94267678260802,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 8,
#    'stAddress1': '21 St & 41 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:45 PM',
#    'landMark': ''},
#   {'id': 3238,
#    'stationName': 'E 80 St & 2 Ave',
#    'availableDocks': 35,
#    'totalDocks': 37,
#    'latitude': 40.77391390238118,
#    'longitude': -73.9543953537941,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 2,
#    'stAddress1': 'E 80 St & 2 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:37 PM',
#    'landMark': ''},
#   {'id': 3241,
#    'stationName': 'Monroe St & Tompkins Ave',
#    'availableDocks': 18,
#    'totalDocks': 19,
#    'latitude': 40.686203,
#    'longitude': -73.944694,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'Monroe St & Tompkins Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:38 PM',
#    'landMark': ''},
#   {'id': 3242,
#    'stationName': 'Schermerhorn St & Court St',
#    'availableDocks': 5,
#    'totalDocks': 39,
#    'latitude': 40.69102925677968,
#    'longitude': -73.99183362722397,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 31,
#    'stAddress1': 'Schermerhorn St & Court St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:33 PM',
#    'landMark': ''},
#   {'id': 3243,
#    'stationName': 'E 58 St & 1 Ave',
#    'availableDocks': 28,
#    'totalDocks': 29,
#    'latitude': 40.75892386377695,
#    'longitude': -73.96226227283478,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 1,
#    'stAddress1': 'E 58 St & 1 Ave',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:30:05 PM',
#    'landMark': ''},
#   {'id': 3244,
#    'stationName': 'University Pl & E 8 St',
#    'availableDocks': 27,
#    'totalDocks': 31,
#    'latitude': 40.73143724085228,
#    'longitude': -73.99490341544151,
#    'statusValue': 'In Service',
#    'statusKey': 1,
#    'availableBikes': 4,
#    'stAddress1': 'University Pl & E 8 St',
#    'stAddress2': '',
#    'city': '',
#    'postalCode': '',
#    'location': '',
#    'altitude': '',
#    'testStation': False,
#    'lastCommunicationTime': '2016-01-22 04:31:18 PM',
#    'landMark': ''}]}

# %%
# Los keys de este diccionario
json_data.keys()
# Out:
# dict_keys(['executionTime', 'stationBeanList'])

# %%
# Nos interesa el key "stationBeanList", donde se encuentra la información de interés
# por cada estación
json_data['stationBeanList']
# Out:
# [{'id': 72,
#   'stationName': 'W 52 St & 11 Ave',
#   'availableDocks': 32,
#   'totalDocks': 39,
#   'latitude': 40.76727216,
#   'longitude': -73.99392888,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'W 52 St & 11 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:15 PM',
#   'landMark': ''},
#  {'id': 79,
#   'stationName': 'Franklin St & W Broadway',
#   'availableDocks': 0,
#   'totalDocks': 33,
#   'latitude': 40.71911552,
#   'longitude': -74.00666661,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 33,
#   'stAddress1': 'Franklin St & W Broadway',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:41 PM',
#   'landMark': ''},
#  {'id': 82,
#   'stationName': 'St James Pl & Pearl St',
#   'availableDocks': 27,
#   'totalDocks': 27,
#   'latitude': 40.71117416,
#   'longitude': -74.00016545,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'St James Pl & Pearl St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:41 PM',
#   'landMark': ''},
#  {'id': 83,
#   'stationName': 'Atlantic Ave & Fort Greene Pl',
#   'availableDocks': 21,
#   'totalDocks': 62,
#   'latitude': 40.68382604,
#   'longitude': -73.97632328,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 40,
#   'stAddress1': 'Atlantic Ave & Fort Greene Pl',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:33 PM',
#   'landMark': ''},
#  {'id': 116,
#   'stationName': 'W 17 St & 8 Ave',
#   'availableDocks': 19,
#   'totalDocks': 39,
#   'latitude': 40.74177603,
#   'longitude': -74.00149746,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 19,
#   'stAddress1': 'W 17 St & 8 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:32 PM',
#   'landMark': ''},
#  {'id': 119,
#   'stationName': 'Park Ave & St Edwards St',
#   'availableDocks': 15,
#   'totalDocks': 19,
#   'latitude': 40.69608941,
#   'longitude': -73.97803415,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'Park Ave & St Edwards St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:29 PM',
#   'landMark': ''},
#  {'id': 120,
#   'stationName': 'Lexington Ave & Classon Ave',
#   'availableDocks': 17,
#   'totalDocks': 19,
#   'latitude': 40.68676793,
#   'longitude': -73.95928168,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'Lexington Ave & Classon Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:06 PM',
#   'landMark': ''},
#  {'id': 127,
#   'stationName': 'Barrow St & Hudson St',
#   'availableDocks': 21,
#   'totalDocks': 31,
#   'latitude': 40.73172428,
#   'longitude': -74.00674436,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 9,
#   'stAddress1': 'Barrow St & Hudson St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:14 PM',
#   'landMark': ''},
#  {'id': 128,
#   'stationName': 'MacDougal St & Prince St',
#   'availableDocks': 9,
#   'totalDocks': 30,
#   'latitude': 40.72710258,
#   'longitude': -74.00297088,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 21,
#   'stAddress1': 'MacDougal St & Prince St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:57 PM',
#   'landMark': ''},
#  {'id': 137,
#   'stationName': 'E 56 St & Madison Ave',
#   'availableDocks': 15,
#   'totalDocks': 46,
#   'latitude': 40.761628,
#   'longitude': -73.972924,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 30,
#   'stAddress1': 'E 56 St & Madison Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:12 PM',
#   'landMark': ''},
#  {'id': 143,
#   'stationName': 'Clinton St & Joralemon St',
#   'availableDocks': 20,
#   'totalDocks': 24,
#   'latitude': 40.69239502,
#   'longitude': -73.99337909,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'Clinton St & Joralemon St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:28:55 PM',
#   'landMark': ''},
#  {'id': 144,
#   'stationName': 'Nassau St & Navy St',
#   'availableDocks': 5,
#   'totalDocks': 19,
#   'latitude': 40.69839895,
#   'longitude': -73.98068914,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 12,
#   'stAddress1': 'Nassau St & Navy St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:05 PM',
#   'landMark': ''},
#  {'id': 146,
#   'stationName': 'Hudson St & Reade St',
#   'availableDocks': 30,
#   'totalDocks': 39,
#   'latitude': 40.71625008,
#   'longitude': -74.0091059,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'Hudson St & Reade St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:37 PM',
#   'landMark': ''},
#  {'id': 147,
#   'stationName': 'Greenwich St & Warren St',
#   'availableDocks': 18,
#   'totalDocks': 33,
#   'latitude': 40.71542197,
#   'longitude': -74.01121978,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 15,
#   'stAddress1': 'Greenwich St & Warren St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:05 PM',
#   'landMark': ''},
#  {'id': 150,
#   'stationName': 'E 2 St & Avenue C',
#   'availableDocks': 29,
#   'totalDocks': 31,
#   'latitude': 40.7208736,
#   'longitude': -73.98085795,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'E 2 St & Avenue C',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:04 PM',
#   'landMark': ''},
#  {'id': 151,
#   'stationName': 'Cleveland Pl & Spring St',
#   'availableDocks': 22,
#   'totalDocks': 33,
#   'latitude': 40.722103786686034,
#   'longitude': -73.99724900722504,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 11,
#   'stAddress1': 'Cleveland Pl & Spring St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:42 PM',
#   'landMark': ''},
#  {'id': 152,
#   'stationName': 'Warren St & Church St',
#   'availableDocks': 3,
#   'totalDocks': 29,
#   'latitude': 40.71473993,
#   'longitude': -74.00910627,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 26,
#   'stAddress1': 'Warren St & Church St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:04 PM',
#   'landMark': ''},
#  {'id': 153,
#   'stationName': 'E 40 St & 5 Ave',
#   'availableDocks': 36,
#   'totalDocks': 55,
#   'latitude': 40.752062307,
#   'longitude': -73.9816324043,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 17,
#   'stAddress1': 'E 40 St & 5 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:08 PM',
#   'landMark': ''},
#  {'id': 157,
#   'stationName': 'Henry St & Atlantic Ave',
#   'availableDocks': 16,
#   'totalDocks': 23,
#   'latitude': 40.69089272,
#   'longitude': -73.99612349,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 6,
#   'stAddress1': 'Henry St & Atlantic Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:42 PM',
#   'landMark': ''},
#  {'id': 160,
#   'stationName': 'E 37 St & Lexington Ave',
#   'availableDocks': 23,
#   'totalDocks': 26,
#   'latitude': 40.748238,
#   'longitude': -73.978311,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'E 37 St & Lexington Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:48 PM',
#   'landMark': ''},
#  {'id': 161,
#   'stationName': 'LaGuardia Pl & W 3 St',
#   'availableDocks': 8,
#   'totalDocks': 35,
#   'latitude': 40.72917025,
#   'longitude': -73.99810231,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 25,
#   'stAddress1': 'LaGuardia Pl & W 3 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:54 PM',
#   'landMark': ''},
#  {'id': 164,
#   'stationName': 'E 47 St & 2 Ave',
#   'availableDocks': 37,
#   'totalDocks': 47,
#   'latitude': 40.75323098,
#   'longitude': -73.97032517,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'E 47 St & 2 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:29 PM',
#   'landMark': ''},
#  {'id': 167,
#   'stationName': 'E 39 St & 3 Ave',
#   'availableDocks': 22,
#   'totalDocks': 45,
#   'latitude': 40.7489006,
#   'longitude': -73.97604882,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 23,
#   'stAddress1': 'E 39 St & 3 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:10 PM',
#   'landMark': ''},
#  {'id': 168,
#   'stationName': 'W 18 St & 6 Ave',
#   'availableDocks': 11,
#   'totalDocks': 47,
#   'latitude': 40.73971301,
#   'longitude': -73.99456405,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 34,
#   'stAddress1': 'W 18 St & 6 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:05 PM',
#   'landMark': ''},
#  {'id': 173,
#   'stationName': 'Broadway & W 49 St',
#   'availableDocks': 43,
#   'totalDocks': 51,
#   'latitude': 40.76068327096592,
#   'longitude': -73.9845272898674,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'Broadway & W 49 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:12 PM',
#   'landMark': ''},
#  {'id': 174,
#   'stationName': 'E 25 St & 1 Ave',
#   'availableDocks': 21,
#   'totalDocks': 30,
#   'latitude': 40.7381765,
#   'longitude': -73.97738662,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 9,
#   'stAddress1': 'E 25 St & 1 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:15 PM',
#   'landMark': ''},
#  {'id': 195,
#   'stationName': 'Liberty St & Broadway',
#   'availableDocks': 25,
#   'totalDocks': 45,
#   'latitude': 40.70905623,
#   'longitude': -74.01043382,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 20,
#   'stAddress1': 'Liberty St & Broadway',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:32 PM',
#   'landMark': ''},
#  {'id': 212,
#   'stationName': 'W 16 St & The High Line',
#   'availableDocks': 24,
#   'totalDocks': 28,
#   'latitude': 40.74334935,
#   'longitude': -74.00681753,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'W 16 St & The High Line',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:33 PM',
#   'landMark': ''},
#  {'id': 216,
#   'stationName': 'Columbia Heights & Cranberry St',
#   'availableDocks': 13,
#   'totalDocks': 23,
#   'latitude': 40.70037867,
#   'longitude': -73.99548059,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'Columbia Heights & Cranberry St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:52 PM',
#   'landMark': ''},
#  {'id': 217,
#   'stationName': 'Old Fulton St',
#   'availableDocks': 22,
#   'totalDocks': 39,
#   'latitude': 40.70277159,
#   'longitude': -73.99383605,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 15,
#   'stAddress1': 'Old Fulton St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:06 PM',
#   'landMark': ''},
#  {'id': 223,
#   'stationName': 'W 13 St & 7 Ave',
#   'availableDocks': 21,
#   'totalDocks': 33,
#   'latitude': 40.73781509,
#   'longitude': -73.99994661,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'W 13 St & 7 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:46 PM',
#   'landMark': ''},
#  {'id': 224,
#   'stationName': 'Spruce St & Nassau St',
#   'availableDocks': 27,
#   'totalDocks': 31,
#   'latitude': 40.71146364,
#   'longitude': -74.00552427,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'Spruce St & Nassau St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:07 PM',
#   'landMark': ''},
#  {'id': 225,
#   'stationName': 'W 14 St & The High Line',
#   'availableDocks': 19,
#   'totalDocks': 37,
#   'latitude': 40.74195138,
#   'longitude': -74.00803013,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 17,
#   'stAddress1': 'W 14 St & The High Line',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:24 PM',
#   'landMark': ''},
#  {'id': 228,
#   'stationName': 'E 48 St & 3 Ave',
#   'availableDocks': 44,
#   'totalDocks': 55,
#   'latitude': 40.7546011026,
#   'longitude': -73.971878855,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'E 48 St & 3 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:09 PM',
#   'landMark': ''},
#  {'id': 229,
#   'stationName': 'Great Jones St',
#   'availableDocks': 1,
#   'totalDocks': 23,
#   'latitude': 40.72743423,
#   'longitude': -73.99379025,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 17,
#   'stAddress1': 'Great Jones St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:47 PM',
#   'landMark': ''},
#  {'id': 232,
#   'stationName': 'Cadman Plaza E & Tillary St',
#   'availableDocks': 16,
#   'totalDocks': 23,
#   'latitude': 40.69597683,
#   'longitude': -73.99014892,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'Cadman Plaza E & Tillary St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:35 PM',
#   'landMark': ''},
#  {'id': 233,
#   'stationName': 'Cadman Plaza W & Pierrepont St',
#   'availableDocks': 35,
#   'totalDocks': 38,
#   'latitude': 40.69475701363877,
#   'longitude': -73.99052739143372,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'Cadman Plaza W & Pierrepont St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:00 PM',
#   'landMark': ''},
#  {'id': 236,
#   'stationName': 'St Marks Pl & 2 Ave',
#   'availableDocks': 33,
#   'totalDocks': 39,
#   'latitude': 40.7284186,
#   'longitude': -73.98713956,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 6,
#   'stAddress1': 'St Marks Pl & 2 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:45 PM',
#   'landMark': ''},
#  {'id': 237,
#   'stationName': 'E 11 St & 2 Ave',
#   'availableDocks': 37,
#   'totalDocks': 39,
#   'latitude': 40.73047309,
#   'longitude': -73.98672378,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'E 11 St & 2 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:10 PM',
#   'landMark': ''},
#  {'id': 238,
#   'stationName': 'Bank St & Washington St',
#   'availableDocks': 14,
#   'totalDocks': 31,
#   'latitude': 40.7361967,
#   'longitude': -74.00859207,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 16,
#   'stAddress1': 'Bank St & Washington St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:29 PM',
#   'landMark': ''},
#  {'id': 239,
#   'stationName': 'Willoughby St & Fleet St',
#   'availableDocks': 17,
#   'totalDocks': 31,
#   'latitude': 40.69196566,
#   'longitude': -73.9813018,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 13,
#   'stAddress1': 'Willoughby St & Fleet St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:16 PM',
#   'landMark': ''},
#  {'id': 241,
#   'stationName': 'DeKalb Ave & S Portland Ave',
#   'availableDocks': 19,
#   'totalDocks': 23,
#   'latitude': 40.68981035,
#   'longitude': -73.97493121,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'DeKalb Ave & S Portland Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:16 PM',
#   'landMark': ''},
#  {'id': 242,
#   'stationName': 'Carlton Ave & Flushing Ave',
#   'availableDocks': 19,
#   'totalDocks': 23,
#   'latitude': 40.697787,
#   'longitude': -73.973736,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'Carlton Ave & Flushing Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:34 PM',
#   'landMark': ''},
#  {'id': 243,
#   'stationName': 'Fulton St & Rockwell Pl',
#   'availableDocks': 4,
#   'totalDocks': 31,
#   'latitude': 40.688226,
#   'longitude': -73.979382,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 26,
#   'stAddress1': 'Fulton St & Rockwell Pl',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:28 PM',
#   'landMark': ''},
#  {'id': 244,
#   'stationName': 'Willoughby Ave & Hall St',
#   'availableDocks': 26,
#   'totalDocks': 31,
#   'latitude': 40.69196035,
#   'longitude': -73.96536851,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 5,
#   'stAddress1': 'Willoughby Ave & Hall St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:36 PM',
#   'landMark': ''},
#  {'id': 245,
#   'stationName': 'Myrtle Ave & St Edwards St',
#   'availableDocks': 16,
#   'totalDocks': 23,
#   'latitude': 40.69327018,
#   'longitude': -73.97703874,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'Myrtle Ave & St Edwards St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:56 PM',
#   'landMark': ''},
#  {'id': 247,
#   'stationName': 'Perry St & Bleecker St',
#   'availableDocks': 9,
#   'totalDocks': 20,
#   'latitude': 40.73535398,
#   'longitude': -74.00483091,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 11,
#   'stAddress1': 'Perry St & Bleecker St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:53 PM',
#   'landMark': ''},
#  {'id': 248,
#   'stationName': 'Laight St & Hudson St',
#   'availableDocks': 10,
#   'totalDocks': 23,
#   'latitude': 40.72185379,
#   'longitude': -74.00771779,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 12,
#   'stAddress1': 'Laight St & Hudson St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:38 PM',
#   'landMark': ''},
#  {'id': 249,
#   'stationName': 'Harrison St & Hudson St',
#   'availableDocks': 2,
#   'totalDocks': 27,
#   'latitude': 40.71870987,
#   'longitude': -74.0090009,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 25,
#   'stAddress1': 'Harrison St & Hudson St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:28:57 PM',
#   'landMark': ''},
#  {'id': 250,
#   'stationName': 'Lafayette St & Jersey St',
#   'availableDocks': 2,
#   'totalDocks': 40,
#   'latitude': 40.72456089,
#   'longitude': -73.99565293,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 35,
#   'stAddress1': 'Lafayette St & Jersey St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:11 PM',
#   'landMark': ''},
#  {'id': 251,
#   'stationName': 'Mott St & Prince St',
#   'availableDocks': 23,
#   'totalDocks': 27,
#   'latitude': 40.72317958,
#   'longitude': -73.99480012,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'Mott St & Prince St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:19 PM',
#   'landMark': ''},
#  {'id': 252,
#   'stationName': 'MacDougal St & Washington Sq',
#   'availableDocks': 31,
#   'totalDocks': 33,
#   'latitude': 40.73226398,
#   'longitude': -73.99852205,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'MacDougal St & Washington Sq',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:38 PM',
#   'landMark': ''},
#  {'id': 253,
#   'stationName': 'W 13 St & 5 Ave',
#   'availableDocks': 39,
#   'totalDocks': 55,
#   'latitude': 40.73543934,
#   'longitude': -73.99453948,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 13,
#   'stAddress1': 'W 13 St & 5 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:37 PM',
#   'landMark': ''},
#  {'id': 254,
#   'stationName': 'W 11 St & 6 Ave',
#   'availableDocks': 25,
#   'totalDocks': 31,
#   'latitude': 40.73532427,
#   'longitude': -73.99800419,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 6,
#   'stAddress1': 'W 11 St & 6 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:27 PM',
#   'landMark': ''},
#  {'id': 257,
#   'stationName': 'Lispenard St & Broadway',
#   'availableDocks': 4,
#   'totalDocks': 39,
#   'latitude': 40.71939226,
#   'longitude': -74.00247214,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 33,
#   'stAddress1': 'Lispenard St & Broadway',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:12 PM',
#   'landMark': ''},
#  {'id': 258,
#   'stationName': 'DeKalb Ave & Vanderbilt Ave',
#   'availableDocks': 23,
#   'totalDocks': 23,
#   'latitude': 40.68940747,
#   'longitude': -73.96885458,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'DeKalb Ave & Vanderbilt Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:05 PM',
#   'landMark': ''},
#  {'id': 259,
#   'stationName': 'South St & Whitehall St',
#   'availableDocks': 4,
#   'totalDocks': 39,
#   'latitude': 40.70122128,
#   'longitude': -74.01234218,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 35,
#   'stAddress1': 'South St & Whitehall St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:12 PM',
#   'landMark': ''},
#  {'id': 260,
#   'stationName': 'Broad St & Bridge St',
#   'availableDocks': 10,
#   'totalDocks': 35,
#   'latitude': 40.70365182,
#   'longitude': -74.01167797,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 25,
#   'stAddress1': 'Broad St & Bridge St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:24 PM',
#   'landMark': ''},
#  {'id': 261,
#   'stationName': 'Johnson St & Gold St',
#   'availableDocks': 14,
#   'totalDocks': 27,
#   'latitude': 40.69474881,
#   'longitude': -73.98362464,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 13,
#   'stAddress1': 'Johnson St & Gold St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:52 PM',
#   'landMark': ''},
#  {'id': 262,
#   'stationName': 'Washington Park',
#   'availableDocks': 23,
#   'totalDocks': 24,
#   'latitude': 40.6917823,
#   'longitude': -73.9737299,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'Washington Park',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:34 PM',
#   'landMark': ''},
#  {'id': 263,
#   'stationName': 'Elizabeth St & Hester St',
#   'availableDocks': 31,
#   'totalDocks': 31,
#   'latitude': 40.71729,
#   'longitude': -73.996375,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Elizabeth St & Hester St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:42 PM',
#   'landMark': ''},
#  {'id': 264,
#   'stationName': 'Maiden Ln & Pearl St',
#   'availableDocks': 3,
#   'totalDocks': 27,
#   'latitude': 40.70706456,
#   'longitude': -74.00731853,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 24,
#   'stAddress1': 'Maiden Ln & Pearl St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:19 PM',
#   'landMark': ''},
#  {'id': 265,
#   'stationName': 'Stanton St & Chrystie St',
#   'availableDocks': 24,
#   'totalDocks': 35,
#   'latitude': 40.72229346,
#   'longitude': -73.99147535,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'Stanton St & Chrystie St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:27 PM',
#   'landMark': ''},
#  {'id': 266,
#   'stationName': 'Avenue D & E 8 St',
#   'availableDocks': 22,
#   'totalDocks': 24,
#   'latitude': 40.72368361,
#   'longitude': -73.97574813,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'Avenue D & E 8 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:24 PM',
#   'landMark': ''},
#  {'id': 267,
#   'stationName': 'Broadway & W 36 St',
#   'availableDocks': 56,
#   'totalDocks': 57,
#   'latitude': 40.75097711,
#   'longitude': -73.98765428,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'Broadway & W 36 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:27 PM',
#   'landMark': ''},
#  {'id': 268,
#   'stationName': 'Howard St & Centre St',
#   'availableDocks': 2,
#   'totalDocks': 27,
#   'latitude': 40.71910537,
#   'longitude': -73.99973337,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 25,
#   'stAddress1': 'Howard St & Centre St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:05 PM',
#   'landMark': ''},
#  {'id': 270,
#   'stationName': 'Adelphi St & Myrtle Ave',
#   'availableDocks': 17,
#   'totalDocks': 23,
#   'latitude': 40.69308257,
#   'longitude': -73.97178913,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 5,
#   'stAddress1': 'Adelphi St & Myrtle Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:18 PM',
#   'landMark': ''},
#  {'id': 274,
#   'stationName': 'Lafayette Ave & Fort Greene Pl',
#   'availableDocks': 11,
#   'totalDocks': 31,
#   'latitude': 40.68691865,
#   'longitude': -73.976682,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 20,
#   'stAddress1': 'Lafayette Ave & Fort Greene Pl',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:25 PM',
#   'landMark': ''},
#  {'id': 275,
#   'stationName': 'Washington Ave & Greene Ave',
#   'availableDocks': 16,
#   'totalDocks': 19,
#   'latitude': 40.68650065,
#   'longitude': -73.96563307,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'Washington Ave & Greene Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:51 PM',
#   'landMark': ''},
#  {'id': 276,
#   'stationName': 'Duane St & Greenwich St',
#   'availableDocks': 2,
#   'totalDocks': 25,
#   'latitude': 40.71748752,
#   'longitude': -74.0104554,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 22,
#   'stAddress1': 'Duane St & Greenwich St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:57 PM',
#   'landMark': ''},
#  {'id': 278,
#   'stationName': 'Concord St & Bridge St',
#   'availableDocks': 8,
#   'totalDocks': 19,
#   'latitude': 40.69766564,
#   'longitude': -73.98476437,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'Concord St & Bridge St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:17 PM',
#   'landMark': ''},
#  {'id': 279,
#   'stationName': 'Peck Slip & Front St',
#   'availableDocks': 13,
#   'totalDocks': 36,
#   'latitude': 40.707873,
#   'longitude': -74.00167,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 23,
#   'stAddress1': 'Peck Slip & Front St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:22 PM',
#   'landMark': ''},
#  {'id': 280,
#   'stationName': 'E 10 St & 5 Ave',
#   'availableDocks': 10,
#   'totalDocks': 31,
#   'latitude': 40.73331967,
#   'longitude': -73.99510132,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 20,
#   'stAddress1': 'E 10 St & 5 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:37 PM',
#   'landMark': ''},
#  {'id': 281,
#   'stationName': 'Grand Army Plaza & Central Park S',
#   'availableDocks': 33,
#   'totalDocks': 59,
#   'latitude': 40.7643971,
#   'longitude': -73.97371465,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 26,
#   'stAddress1': 'Grand Army Plaza & Central Park S',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:55 PM',
#   'landMark': ''},
#  {'id': 282,
#   'stationName': 'Kent Ave & S 11 St',
#   'availableDocks': 23,
#   'totalDocks': 27,
#   'latitude': 40.70827295,
#   'longitude': -73.96834101,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'Kent Ave & S 11 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:08 PM',
#   'landMark': ''},
#  {'id': 284,
#   'stationName': 'Greenwich Ave & 8 Ave',
#   'availableDocks': 16,
#   'totalDocks': 43,
#   'latitude': 40.7390169121,
#   'longitude': -74.0026376103,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 26,
#   'stAddress1': 'Greenwich Ave & 8 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:12 PM',
#   'landMark': ''},
#  {'id': 285,
#   'stationName': 'Broadway & E 14 St',
#   'availableDocks': 36,
#   'totalDocks': 47,
#   'latitude': 40.73454567,
#   'longitude': -73.99074142,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'Broadway & E 14 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:31 PM',
#   'landMark': ''},
#  {'id': 289,
#   'stationName': 'Monroe St & Classon Ave',
#   'availableDocks': 13,
#   'totalDocks': 19,
#   'latitude': 40.6845683,
#   'longitude': -73.95881081,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 6,
#   'stAddress1': 'Monroe St & Classon Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:06 PM',
#   'landMark': ''},
#  {'id': 291,
#   'stationName': 'Madison St & Montgomery St',
#   'availableDocks': 20,
#   'totalDocks': 20,
#   'latitude': 40.713126,
#   'longitude': -73.984844,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Madison St & Montgomery St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:15 PM',
#   'landMark': ''},
#  {'id': 293,
#   'stationName': 'Lafayette St & E 8 St',
#   'availableDocks': 42,
#   'totalDocks': 55,
#   'latitude': 40.73028666,
#   'longitude': -73.9907647,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'Lafayette St & E 8 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:19 PM',
#   'landMark': ''},
#  {'id': 295,
#   'stationName': 'Pike St & E Broadway',
#   'availableDocks': 24,
#   'totalDocks': 24,
#   'latitude': 40.71406667,
#   'longitude': -73.99293911,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Pike St & E Broadway',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:05 PM',
#   'landMark': ''},
#  {'id': 296,
#   'stationName': 'Division St & Bowery',
#   'availableDocks': 6,
#   'totalDocks': 35,
#   'latitude': 40.71413089,
#   'longitude': -73.9970468,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 27,
#   'stAddress1': 'Division St & Bowery',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:10 PM',
#   'landMark': ''},
#  {'id': 297,
#   'stationName': 'E 15 St & 3 Ave',
#   'availableDocks': 21,
#   'totalDocks': 27,
#   'latitude': 40.734232,
#   'longitude': -73.986923,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 6,
#   'stAddress1': 'E 15 St & 3 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:03 PM',
#   'landMark': ''},
#  {'id': 298,
#   'stationName': '3 Ave & Schermerhorn St',
#   'availableDocks': 14,
#   'totalDocks': 35,
#   'latitude': 40.68683208,
#   'longitude': -73.9796772,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 21,
#   'stAddress1': '3 Ave & Schermerhorn St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:19 PM',
#   'landMark': ''},
#  {'id': 300,
#   'stationName': 'Shevchenko Pl & E 7 St',
#   'availableDocks': 42,
#   'totalDocks': 55,
#   'latitude': 40.728145,
#   'longitude': -73.990214,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 11,
#   'stAddress1': 'Shevchenko Pl & E 7 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:46 PM',
#   'landMark': ''},
#  {'id': 301,
#   'stationName': 'E 2 St & Avenue B',
#   'availableDocks': 35,
#   'totalDocks': 37,
#   'latitude': 40.72217444,
#   'longitude': -73.98368779,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'E 2 St & Avenue B',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:27 PM',
#   'landMark': ''},
#  {'id': 302,
#   'stationName': 'Avenue D & E 3 St',
#   'availableDocks': 23,
#   'totalDocks': 23,
#   'latitude': 40.72082834,
#   'longitude': -73.97793172,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Avenue D & E 3 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:29 PM',
#   'landMark': ''},
#  {'id': 303,
#   'stationName': 'Mercer St & Spring St',
#   'availableDocks': 10,
#   'totalDocks': 31,
#   'latitude': 40.72362738,
#   'longitude': -73.99949601,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 21,
#   'stAddress1': 'Mercer St & Spring St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:02 PM',
#   'landMark': ''},
#  {'id': 304,
#   'stationName': 'Broadway & Battery Pl',
#   'availableDocks': 7,
#   'totalDocks': 36,
#   'latitude': 40.70463334,
#   'longitude': -74.01361706,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 27,
#   'stAddress1': 'Broadway & Battery Pl',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:14 PM',
#   'landMark': ''},
#  {'id': 305,
#   'stationName': 'E 58 St & 3 Ave',
#   'availableDocks': 13,
#   'totalDocks': 33,
#   'latitude': 40.76095756,
#   'longitude': -73.96724467,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 19,
#   'stAddress1': 'E 58 St & 3 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:28 PM',
#   'landMark': ''},
#  {'id': 306,
#   'stationName': 'Cliff St & Fulton St',
#   'availableDocks': 10,
#   'totalDocks': 37,
#   'latitude': 40.70823502,
#   'longitude': -74.00530063,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 25,
#   'stAddress1': 'Cliff St & Fulton St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:46 PM',
#   'landMark': ''},
#  {'id': 307,
#   'stationName': 'Canal St & Rutgers St',
#   'availableDocks': 27,
#   'totalDocks': 29,
#   'latitude': 40.71427487,
#   'longitude': -73.98990025,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'Canal St & Rutgers St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:44 PM',
#   'landMark': ''},
#  {'id': 308,
#   'stationName': 'St James Pl & Oliver St',
#   'availableDocks': 21,
#   'totalDocks': 27,
#   'latitude': 40.71307916,
#   'longitude': -73.99851193,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'St James Pl & Oliver St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:38 PM',
#   'landMark': ''},
#  {'id': 309,
#   'stationName': 'Murray St & West St',
#   'availableDocks': 4,
#   'totalDocks': 41,
#   'latitude': 40.7149787,
#   'longitude': -74.013012,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 37,
#   'stAddress1': 'Murray St & West St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:43 PM',
#   'landMark': ''},
#  {'id': 310,
#   'stationName': 'State St & Smith St',
#   'availableDocks': 22,
#   'totalDocks': 36,
#   'latitude': 40.68926942,
#   'longitude': -73.98912867,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 12,
#   'stAddress1': 'State St & Smith St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:51 PM',
#   'landMark': ''},
#  {'id': 311,
#   'stationName': 'Norfolk St & Broome St',
#   'availableDocks': 26,
#   'totalDocks': 31,
#   'latitude': 40.7172274,
#   'longitude': -73.98802084,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 5,
#   'stAddress1': 'Norfolk St & Broome St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:04 PM',
#   'landMark': ''},
#  {'id': 312,
#   'stationName': 'Allen St & E Houston St',
#   'availableDocks': 26,
#   'totalDocks': 31,
#   'latitude': 40.722055,
#   'longitude': -73.989111,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 5,
#   'stAddress1': 'Allen St & E Houston St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:33 PM',
#   'landMark': ''},
#  {'id': 313,
#   'stationName': 'Washington Ave & Park Ave',
#   'availableDocks': 1,
#   'totalDocks': 23,
#   'latitude': 40.69610226,
#   'longitude': -73.96751037,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 22,
#   'stAddress1': 'Washington Ave & Park Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:20 PM',
#   'landMark': ''},
#  {'id': 314,
#   'stationName': 'Cadman Plaza West & Montague St',
#   'availableDocks': 20,
#   'totalDocks': 39,
#   'latitude': 40.69383,
#   'longitude': -73.990539,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 18,
#   'stAddress1': 'Cadman Plaza West & Montague St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:34 PM',
#   'landMark': ''},
#  {'id': 315,
#   'stationName': 'South St & Gouverneur Ln',
#   'availableDocks': 6,
#   'totalDocks': 29,
#   'latitude': 40.70355377,
#   'longitude': -74.00670227,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 23,
#   'stAddress1': 'South St & Gouverneur Ln',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:34 PM',
#   'landMark': ''},
#  {'id': 316,
#   'stationName': 'Fulton St & William St',
#   'availableDocks': 10,
#   'totalDocks': 43,
#   'latitude': 40.70955958,
#   'longitude': -74.00653609,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 32,
#   'stAddress1': 'Fulton St & William St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:28:58 PM',
#   'landMark': ''},
#  {'id': 317,
#   'stationName': 'E 6 St & Avenue B',
#   'availableDocks': 17,
#   'totalDocks': 27,
#   'latitude': 40.72453734,
#   'longitude': -73.98185424,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'E 6 St & Avenue B',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:47 PM',
#   'landMark': ''},
#  {'id': 319,
#   'stationName': 'Fulton St & Broadway',
#   'availableDocks': 9,
#   'totalDocks': 33,
#   'latitude': 40.711066,
#   'longitude': -74.009447,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 23,
#   'stAddress1': 'Fulton St & Broadway',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:28 PM',
#   'landMark': ''},
#  {'id': 320,
#   'stationName': 'Leonard St & Church St',
#   'availableDocks': 4,
#   'totalDocks': 39,
#   'latitude': 40.717571,
#   'longitude': -74.005549,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 35,
#   'stAddress1': 'Leonard St & Church St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:31 PM',
#   'landMark': ''},
#  {'id': 321,
#   'stationName': 'Cadman Plaza E & Red Cross Pl',
#   'availableDocks': 9,
#   'totalDocks': 27,
#   'latitude': 40.69991755,
#   'longitude': -73.98971773,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 17,
#   'stAddress1': 'Cadman Plaza E & Red Cross Pl',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:44 PM',
#   'landMark': ''},
#  {'id': 322,
#   'stationName': 'Clinton St & Tillary St',
#   'availableDocks': 23,
#   'totalDocks': 31,
#   'latitude': 40.696192,
#   'longitude': -73.991218,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
# ...
#   'availableBikes': 7,
#   'stAddress1': 'MLK Light Rail',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:04 PM',
#   'landMark': ''},
#  {'id': 3201,
#   'stationName': 'Dey St',
#   'availableDocks': 18,
#   'totalDocks': 18,
#   'latitude': 40.737711,
#   'longitude': -74.066921,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Dey St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:06 PM',
#   'landMark': ''},
#  {'id': 3202,
#   'stationName': 'Newport PATH',
#   'availableDocks': 5,
#   'totalDocks': 18,
#   'latitude': 40.7272235,
#   'longitude': -74.0337589,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'Newport PATH',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:34 PM',
#   'landMark': ''},
#  {'id': 3203,
#   'stationName': 'Hamilton Park',
#   'availableDocks': 14,
#   'totalDocks': 25,
#   'latitude': 40.727595966,
#   'longitude': -74.044247311,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 9,
#   'stAddress1': 'Hamilton Park',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:44 PM',
#   'landMark': ''},
#  {'id': 3205,
#   'stationName': 'JC Medical Center',
#   'availableDocks': 15,
#   'totalDocks': 22,
#   'latitude': 40.7165271,
#   'longitude': -74.049425,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 6,
#   'stAddress1': 'JC Medical Center',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:24 PM',
#   'landMark': ''},
#  {'id': 3206,
#   'stationName': 'Hilltop',
#   'availableDocks': 22,
#   'totalDocks': 26,
#   'latitude': 40.7311689,
#   'longitude': -74.0575736,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'Hilltop',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:44 PM',
#   'landMark': ''},
#  {'id': 3207,
#   'stationName': 'Oakland Ave',
#   'availableDocks': 12,
#   'totalDocks': 14,
#   'latitude': 40.7376037,
#   'longitude': -74.0524783,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Oakland Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:29 PM',
#   'landMark': ''},
#  {'id': 3209,
#   'stationName': 'Brunswick St',
#   'availableDocks': 17,
#   'totalDocks': 18,
#   'latitude': 40.7241765,
#   'longitude': -74.0506564,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'Brunswick St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:28 PM',
#   'landMark': ''},
#  {'id': 3210,
#   'stationName': 'Pershing Field',
#   'availableDocks': 9,
#   'totalDocks': 18,
#   'latitude': 40.742677141,
#   'longitude': -74.051788633,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'Pershing Field',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:09 PM',
#   'landMark': ''},
#  {'id': 3211,
#   'stationName': 'Newark Ave',
#   'availableDocks': 13,
#   'totalDocks': 21,
#   'latitude': 40.72152515,
#   'longitude': -74.046304543,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 8,
#   'stAddress1': 'Newark Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:53 PM',
#   'landMark': ''},
#  {'id': 3212,
#   'stationName': 'Christ Hospital',
#   'availableDocks': 17,
#   'totalDocks': 22,
#   'latitude': 40.734785818,
#   'longitude': -74.050443636,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 5,
#   'stAddress1': 'Christ Hospital',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:16 PM',
#   'landMark': ''},
#  {'id': 3213,
#   'stationName': 'Van Vorst Park',
#   'availableDocks': 11,
#   'totalDocks': 22,
#   'latitude': 40.71848892,
#   'longitude': -74.047726625,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 9,
#   'stAddress1': 'Van Vorst Park',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:30 PM',
#   'landMark': ''},
#  {'id': 3214,
#   'stationName': 'Essex Light Rail',
#   'availableDocks': 22,
#   'totalDocks': 22,
#   'latitude': 40.7127742,
#   'longitude': -74.0364857,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Essex Light Rail',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:35 PM',
#   'landMark': ''},
#  {'id': 3215,
#   'stationName': 'Central Ave',
#   'availableDocks': 15,
#   'totalDocks': 18,
#   'latitude': 40.7467299,
#   'longitude': -74.0492509,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'Central Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:30 PM',
#   'landMark': ''},
#  {'id': 3216,
#   'stationName': 'Columbia Park',
#   'availableDocks': 11,
#   'totalDocks': 18,
#   'latitude': 40.6970299,
#   'longitude': -74.0969366,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 7,
#   'stAddress1': 'Columbia Park',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:15 PM',
#   'landMark': ''},
#  {'id': 3217,
#   'stationName': 'Bayside Park',
#   'availableDocks': 12,
#   'totalDocks': 18,
#   'latitude': 40.698650544,
#   'longitude': -74.082079678,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'Bayside Park',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:41 PM',
#   'landMark': ''},
#  {'id': 3220,
#   'stationName': '5 Corners Library',
#   'availableDocks': 12,
#   'totalDocks': 18,
#   'latitude': 40.734961020009514,
#   'longitude': -74.0595030784607,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': '5 Corners Library',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:58 PM',
#   'landMark': ''},
#  {'id': 3221,
#   'stationName': '47 Ave & 31 St',
#   'availableDocks': 12,
#   'totalDocks': 27,
#   'latitude': 40.743,
#   'longitude': -73.93561,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 15,
#   'stAddress1': '47 Ave & 31 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:10 PM',
#   'landMark': ''},
#  {'id': 3222,
#   'stationName': 'Hanson Pl & St Felix St',
#   'availableDocks': 21,
#   'totalDocks': 39,
#   'latitude': 40.685159599891776,
#   'longitude': -73.97711366415024,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 18,
#   'stAddress1': 'Hanson Pl & St Felix St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:32:08 PM',
#   'landMark': ''},
#  {'id': 3223,
#   'stationName': 'E 55 St & 3 Ave',
#   'availableDocks': 50,
#   'totalDocks': 55,
#   'latitude': 40.758996559605116,
#   'longitude': -73.96865397691727,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 5,
#   'stAddress1': 'E 55 St & 3 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:29 PM',
#   'landMark': ''},
#  {'id': 3224,
#   'stationName': 'W 13 St & Hudson St',
#   'availableDocks': 29,
#   'totalDocks': 39,
#   'latitude': 40.73997354103409,
#   'longitude': -74.00513872504234,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'W 13 St & Hudson St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:56 PM',
#   'landMark': ''},
#  {'id': 3225,
#   'stationName': 'Baldwin at Montgomery',
#   'availableDocks': 10,
#   'totalDocks': 14,
#   'latitude': 40.7236589,
#   'longitude': -74.0641943,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 3,
#   'stAddress1': 'Baldwin at Montgomery',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:20 PM',
#   'landMark': ''},
#  {'id': 3226,
#   'stationName': 'W 82 St & Central Park West',
#   'availableDocks': 45,
#   'totalDocks': 45,
#   'latitude': 40.78275,
#   'longitude': -73.97137,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'W 82 St & Central Park West',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:32 PM',
#   'landMark': ''},
#  {'id': 3229,
#   'stationName': 'Marcy Ave & MacDonough St',
#   'availableDocks': 19,
#   'totalDocks': 19,
#   'latitude': 40.68061768455451,
#   'longitude': -73.94624948501587,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Marcy Ave & MacDonough St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:29:51 PM',
#   'landMark': ''},
#  {'id': 3230,
#   'stationName': 'Penn Station Valet',
#   'availableDocks': 7,
#   'totalDocks': 7,
#   'latitude': 40.751283596962296,
#   'longitude': -73.99692445993422,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 0,
#   'stAddress1': 'Penn Station Valet',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:28:51 PM',
#   'landMark': ''},
#  {'id': 3231,
#   'stationName': 'E 67 St & Park Ave',
#   'availableDocks': 48,
#   'totalDocks': 59,
#   'latitude': 40.76780080148132,
#   'longitude': -73.96592080593109,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 10,
#   'stAddress1': 'E 67 St & Park Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:03 PM',
#   'landMark': ''},
#  {'id': 3232,
#   'stationName': 'Bond St & Fulton St',
#   'availableDocks': 20,
#   'totalDocks': 31,
#   'latitude': 40.68962188790333,
#   'longitude': -73.98304268717766,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 11,
#   'stAddress1': 'Bond St & Fulton St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:20 PM',
#   'landMark': ''},
#  {'id': 3233,
#   'stationName': 'E 48 St & 5 Ave',
#   'availableDocks': 17,
#   'totalDocks': 39,
#   'latitude': 40.75724567911726,
#   'longitude': -73.97805914282799,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 16,
#   'stAddress1': 'E 48 St & 5 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:56 PM',
#   'landMark': ''},
#  {'id': 3235,
#   'stationName': 'E 41 St & Madison Ave',
#   'availableDocks': 27,
#   'totalDocks': 31,
#   'latitude': 40.752165280621966,
#   'longitude': -73.97992193698882,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'E 41 St & Madison Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:28:53 PM',
#   'landMark': ''},
#  {'id': 3236,
#   'stationName': 'PABT Valet',
#   'availableDocks': 7,
#   'totalDocks': 9,
#   'latitude': 40.75898481399634,
#   'longitude': -73.99379968643188,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'PABT Valet',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:59 PM',
#   'landMark': ''},
#  {'id': 3237,
#   'stationName': '21 St & 41 Ave',
#   'availableDocks': 17,
#   'totalDocks': 25,
#   'latitude': 40.75383343437622,
#   'longitude': -73.94267678260802,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 8,
#   'stAddress1': '21 St & 41 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:45 PM',
#   'landMark': ''},
#  {'id': 3238,
#   'stationName': 'E 80 St & 2 Ave',
#   'availableDocks': 35,
#   'totalDocks': 37,
#   'latitude': 40.77391390238118,
#   'longitude': -73.9543953537941,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 2,
#   'stAddress1': 'E 80 St & 2 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:37 PM',
#   'landMark': ''},
#  {'id': 3241,
#   'stationName': 'Monroe St & Tompkins Ave',
#   'availableDocks': 18,
#   'totalDocks': 19,
#   'latitude': 40.686203,
#   'longitude': -73.944694,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'Monroe St & Tompkins Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:38 PM',
#   'landMark': ''},
#  {'id': 3242,
#   'stationName': 'Schermerhorn St & Court St',
#   'availableDocks': 5,
#   'totalDocks': 39,
#   'latitude': 40.69102925677968,
#   'longitude': -73.99183362722397,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 31,
#   'stAddress1': 'Schermerhorn St & Court St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:33 PM',
#   'landMark': ''},
#  {'id': 3243,
#   'stationName': 'E 58 St & 1 Ave',
#   'availableDocks': 28,
#   'totalDocks': 29,
#   'latitude': 40.75892386377695,
#   'longitude': -73.96226227283478,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 1,
#   'stAddress1': 'E 58 St & 1 Ave',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:30:05 PM',
#   'landMark': ''},
#  {'id': 3244,
#   'stationName': 'University Pl & E 8 St',
#   'availableDocks': 27,
#   'totalDocks': 31,
#   'latitude': 40.73143724085228,
#   'longitude': -73.99490341544151,
#   'statusValue': 'In Service',
#   'statusKey': 1,
#   'availableBikes': 4,
#   'stAddress1': 'University Pl & E 8 St',
#   'stAddress2': '',
#   'city': '',
#   'postalCode': '',
#   'location': '',
#   'altitude': '',
#   'testStation': False,
#   'lastCommunicationTime': '2016-01-22 04:31:18 PM',
#   'landMark': ''}]

# %% [markdown]
# Ya tenemos una idea clara del contenido del archivo JSON y de los campos que nos interesa leer.
#
# Ahora realicemos la lectura. En principio deberíamos poder hacerla usando la función `read_json` de Pandas. Veamos qué sucede:

# %%
# Leer JSON directamente en Pandas
import pandas as pd

df_json = pd.read_json("https://raw.githubusercontent.com/codificandobits/pandas-nivel-basico-data/main/stations.json")
df_json
# Out:
#               executionTime                                    stationBeanList
# 0    2016-01-22 04:32:49 PM  {'id': 72, 'stationName': 'W 52 St & 11 Ave', ...
# 1    2016-01-22 04:32:49 PM  {'id': 79, 'stationName': 'Franklin St & W Bro...
# 2    2016-01-22 04:32:49 PM  {'id': 82, 'stationName': 'St James Pl & Pearl...
# 3    2016-01-22 04:32:49 PM  {'id': 83, 'stationName': 'Atlantic Ave & Fort...
# 4    2016-01-22 04:32:49 PM  {'id': 116, 'stationName': 'W 17 St & 8 Ave', ...
# ..                      ...                                                ...
# 504  2016-01-22 04:32:49 PM  {'id': 3238, 'stationName': 'E 80 St & 2 Ave',...
# 505  2016-01-22 04:32:49 PM  {'id': 3241, 'stationName': 'Monroe St & Tompk...
# 506  2016-01-22 04:32:49 PM  {'id': 3242, 'stationName': 'Schermerhorn St &...
# 507  2016-01-22 04:32:49 PM  {'id': 3243, 'stationName': 'E 58 St & 1 Ave',...
# 508  2016-01-22 04:32:49 PM  {'id': 3244, 'stationName': 'University Pl & E...
#
# [509 rows x 2 columns]

# %% [markdown]
# Cada uno de los campos del archivo JSON ("executionTime" y "stationBeanList") es leído como una columna. Pero realmente lo que nos interesa es únicamente el campo "stationBeanList".
#
# Modifiquemos la lectura especificando únicamente este campo:

# %%
# Leer únicamente el campo "stationBeanList"
df_json = pd.read_json("https://raw.githubusercontent.com/codificandobits/pandas-nivel-basico-data/main/stations.json")['stationBeanList']
df_json
# Out:
# 0      {'id': 72, 'stationName': 'W 52 St & 11 Ave', ...
# 1      {'id': 79, 'stationName': 'Franklin St & W Bro...
# 2      {'id': 82, 'stationName': 'St James Pl & Pearl...
# 3      {'id': 83, 'stationName': 'Atlantic Ave & Fort...
# 4      {'id': 116, 'stationName': 'W 17 St & 8 Ave', ...
#                              ...
# 504    {'id': 3238, 'stationName': 'E 80 St & 2 Ave',...
# 505    {'id': 3241, 'stationName': 'Monroe St & Tompk...
# 506    {'id': 3242, 'stationName': 'Schermerhorn St &...
# 507    {'id': 3243, 'stationName': 'E 58 St & 1 Ave',...
# 508    {'id': 3244, 'stationName': 'University Pl & E...
# Name: stationBeanList, Length: 509, dtype: object

# %% [markdown]
# El problema ahora es que el cada elemento de "stationBeanList" se convierte en una fila de la Serie resultante.
#
# Lo que queremos es tener el *DataFrame* en formato tabular con las columnas "id", "stationName", etc.
#
# Así que, dado el formato del archivo JSON que estamos leyendo, en este caso no resulta útil el uso de `read_json`.
#
# Sin embargo, Pandas nos ofrece otra alternativa usando la función `json_normalize` que permite tomar el resultado arrojado por `read_json` y reorganizarlo de manera tal que los campos comunes ("id", "stationName", etc.) en los registros se conviertan en columnas de un nuevo *DataFrame*:

# %%
df_estaciones = pd.json_normalize(df_json)
df_estaciones
# Out:
#        id                    stationName  availableDocks  totalDocks  \
# 0      72               W 52 St & 11 Ave              32          39
# 1      79       Franklin St & W Broadway               0          33
# 2      82         St James Pl & Pearl St              27          27
# 3      83  Atlantic Ave & Fort Greene Pl              21          62
# 4     116                W 17 St & 8 Ave              19          39
# ..    ...                            ...             ...         ...
# 504  3238                E 80 St & 2 Ave              35          37
# 505  3241       Monroe St & Tompkins Ave              18          19
# 506  3242     Schermerhorn St & Court St               5          39
# 507  3243                E 58 St & 1 Ave              28          29
# 508  3244         University Pl & E 8 St              27          31
#
#       latitude  longitude statusValue  statusKey  availableBikes  \
# 0    40.767272 -73.993929  In Service          1               7
# 1    40.719116 -74.006667  In Service          1              33
# 2    40.711174 -74.000165  In Service          1               0
# 3    40.683826 -73.976323  In Service          1              40
# 4    40.741776 -74.001497  In Service          1              19
# ..         ...        ...         ...        ...             ...
# 504  40.773914 -73.954395  In Service          1               2
# 505  40.686203 -73.944694  In Service          1               1
# 506  40.691029 -73.991834  In Service          1              31
# 507  40.758924 -73.962262  In Service          1               1
# 508  40.731437 -73.994903  In Service          1               4
#
#                         stAddress1 stAddress2 city postalCode location  \
# 0                 W 52 St & 11 Ave
# 1         Franklin St & W Broadway
# 2           St James Pl & Pearl St
# 3    Atlantic Ave & Fort Greene Pl
# 4                  W 17 St & 8 Ave
# ..                             ...        ...  ...        ...      ...
# 504                E 80 St & 2 Ave
# 505       Monroe St & Tompkins Ave
# 506     Schermerhorn St & Court St
# 507                E 58 St & 1 Ave
# 508         University Pl & E 8 St
#
#     altitude  testStation   lastCommunicationTime landMark
# 0                   False  2016-01-22 04:30:15 PM
# 1                   False  2016-01-22 04:32:41 PM
# 2                   False  2016-01-22 04:29:41 PM
# 3                   False  2016-01-22 04:32:33 PM
# 4                   False  2016-01-22 04:32:32 PM
# ..       ...          ...                     ...      ...
# 504                 False  2016-01-22 04:30:37 PM
# 505                 False  2016-01-22 04:30:38 PM
# 506                 False  2016-01-22 04:31:33 PM
# 507                 False  2016-01-22 04:30:05 PM
# 508                 False  2016-01-22 04:31:18 PM
#
# [509 rows x 18 columns]

# %% [markdown]
# ¡Perfecto, hemos logrado leer el archivo JSON con el formato deseado!

# %% [markdown]
# ## 3. Almacenamiento de un *DataFrame* en formato JSON
#
# Si queremos realizar el procedimiento inverso, es decir, tomar el *DataFrame* y almacenarlo como archivo JSON simplemente podemos usar el método `to_json`:

# %%
# Almacenar el *DataFrame* como archivo JSON
df_estaciones.to_json('stations_from_df.json')

# %%
# En este caso, el archivo JSON ha sido almacenado correctamente así que para su lectura
# sólo necesitamos usar "read_json"
df_from_json = pd.read_json('stations_from_df.json')
df_from_json
# Out:
#        id                    stationName  availableDocks  totalDocks  \
# 0      72               W 52 St & 11 Ave              32          39
# 1      79       Franklin St & W Broadway               0          33
# 2      82         St James Pl & Pearl St              27          27
# 3      83  Atlantic Ave & Fort Greene Pl              21          62
# 4     116                W 17 St & 8 Ave              19          39
# ..    ...                            ...             ...         ...
# 504  3238                E 80 St & 2 Ave              35          37
# 505  3241       Monroe St & Tompkins Ave              18          19
# 506  3242     Schermerhorn St & Court St               5          39
# 507  3243                E 58 St & 1 Ave              28          29
# 508  3244         University Pl & E 8 St              27          31
#
#       latitude  longitude statusValue  statusKey  availableBikes  \
# 0    40.767272 -73.993929  In Service          1               7
# 1    40.719116 -74.006667  In Service          1              33
# 2    40.711174 -74.000165  In Service          1               0
# 3    40.683826 -73.976323  In Service          1              40
# 4    40.741776 -74.001497  In Service          1              19
# ..         ...        ...         ...        ...             ...
# 504  40.773914 -73.954395  In Service          1               2
# 505  40.686203 -73.944694  In Service          1               1
# 506  40.691029 -73.991834  In Service          1              31
# 507  40.758924 -73.962262  In Service          1               1
# 508  40.731437 -73.994903  In Service          1               4
#
#                         stAddress1 stAddress2 city postalCode location  \
# 0                 W 52 St & 11 Ave
# 1         Franklin St & W Broadway
# 2           St James Pl & Pearl St
# 3    Atlantic Ave & Fort Greene Pl
# 4                  W 17 St & 8 Ave
# ..                             ...        ...  ...        ...      ...
# 504                E 80 St & 2 Ave
# 505       Monroe St & Tompkins Ave
# 506     Schermerhorn St & Court St
# 507                E 58 St & 1 Ave
# 508         University Pl & E 8 St
#
#     altitude  testStation   lastCommunicationTime landMark
# 0                   False  2016-01-22 04:30:15 PM
# 1                   False  2016-01-22 04:32:41 PM
# 2                   False  2016-01-22 04:29:41 PM
# 3                   False  2016-01-22 04:32:33 PM
# 4                   False  2016-01-22 04:32:32 PM
# ..       ...          ...                     ...      ...
# 504                 False  2016-01-22 04:30:37 PM
# 505                 False  2016-01-22 04:30:38 PM
# 506                 False  2016-01-22 04:31:33 PM
# 507                 False  2016-01-22 04:30:05 PM
# 508                 False  2016-01-22 04:31:18 PM
#
# [509 rows x 18 columns]

# %% [markdown]
# ## 4. Almacenamiento en formato Excel
#
# Excel sigue siendo un formato de archivo muy común en algunos proyectos de Ciencia de Datos y Machine Learning.
#
# Pandas provee 2 funciones para el almacenamiento de este tipo de archivos: `to_excel` y `ExcelWriter`.
#
# Veamos cómo usarlas:

# %%
# Primero debemos instalar la librería "openpyxl"
# !pip install openpyxl
# Out:
# Requirement already satisfied: openpyxl in /Users/miguel/.pyenv/versions/3.11.2/envs/academy/lib/python3.11/site-packages (3.1.2)
# Requirement already satisfied: et-xmlfile in /Users/miguel/.pyenv/versions/3.11.2/envs/academy/lib/python3.11/site-packages (from openpyxl) (1.1.0)
#
# [notice] A new release of pip available: 22.3.1 -> 23.3.1
# [notice] To update, run: python3.11 -m pip install --upgrade pip

# %%
# Uso de "to_excel":
# Almacenemos el DataFrame que acabamos de crear (df_from_json) en la hoja de cálculo
# "estaciones_ciudades.xlsx" y en la hoja "Estaciones"
df_from_json.to_excel('estaciones_ciudades.xlsx', sheet_name='Estaciones')

# %%
# Ahora intentemos almacenar el primer DataFrame (df_ciudades) en el mismo archivo pero
# en una hoja diferente ("Ciudades")
df_ciudades.to_excel('estaciones_ciudades.xlsx', sheet_name='Ciudades')

# %% [markdown]
# Al abrir el archivo en Excel vemos que se ha creado la hoja "Ciudades" pero que ha desaparecido la hoja "Estaciones".
#
# Así que la limitación de la función `to_excel` es que no nos permite almacenar múltiples hojas en un mismo archivo. En este caso debemos usar `ExcelWriter`:

# %%
# Almacenar múltiples DataFrames en un mismo archivo pero en diferentes hojas
with pd.ExcelWriter("stations_cities.xlsx") as writer:
    df_from_json.to_excel(writer, sheet_name = 'Stations')
    df_ciudades.to_excel(writer, sheet_name = 'Cities')

# %% [markdown]
# ## 5. Lectura de archivos en formato Excel
#
# Y la lectura se puede realizar de forma muy similar a como lo hicimos con los archivos JSON y CSV, pero usando el método `read_excel`. En caso de tener múltiples hojas en un mismo archivo, podemos especificar cuál hoja queremos leer usando el parámetro `sheet_name`:

# %%
# Lectura del excel
df_stations = pd.read_excel('stations_cities.xlsx', sheet_name='Stations')
df_stations
# Out:
#      Unnamed: 0    id                    stationName  availableDocks  \
# 0             0    72               W 52 St & 11 Ave              32
# 1             1    79       Franklin St & W Broadway               0
# 2             2    82         St James Pl & Pearl St              27
# 3             3    83  Atlantic Ave & Fort Greene Pl              21
# 4             4   116                W 17 St & 8 Ave              19
# ..          ...   ...                            ...             ...
# 504         504  3238                E 80 St & 2 Ave              35
# 505         505  3241       Monroe St & Tompkins Ave              18
# 506         506  3242     Schermerhorn St & Court St               5
# 507         507  3243                E 58 St & 1 Ave              28
# 508         508  3244         University Pl & E 8 St              27
#
#      totalDocks   latitude  longitude statusValue  statusKey  availableBikes  \
# 0            39  40.767272 -73.993929  In Service          1               7
# 1            33  40.719116 -74.006667  In Service          1              33
# 2            27  40.711174 -74.000165  In Service          1               0
# 3            62  40.683826 -73.976323  In Service          1              40
# 4            39  40.741776 -74.001497  In Service          1              19
# ..          ...        ...        ...         ...        ...             ...
# 504          37  40.773914 -73.954395  In Service          1               2
# 505          19  40.686203 -73.944694  In Service          1               1
# 506          39  40.691029 -73.991834  In Service          1              31
# 507          29  40.758924 -73.962262  In Service          1               1
# 508          31  40.731437 -73.994903  In Service          1               4
#
#                         stAddress1  stAddress2  city  postalCode  location  \
# 0                 W 52 St & 11 Ave         NaN   NaN         NaN       NaN
# 1         Franklin St & W Broadway         NaN   NaN         NaN       NaN
# 2           St James Pl & Pearl St         NaN   NaN         NaN       NaN
# 3    Atlantic Ave & Fort Greene Pl         NaN   NaN         NaN       NaN
# 4                  W 17 St & 8 Ave         NaN   NaN         NaN       NaN
# ..                             ...         ...   ...         ...       ...
# 504                E 80 St & 2 Ave         NaN   NaN         NaN       NaN
# 505       Monroe St & Tompkins Ave         NaN   NaN         NaN       NaN
# 506     Schermerhorn St & Court St         NaN   NaN         NaN       NaN
# 507                E 58 St & 1 Ave         NaN   NaN         NaN       NaN
# 508         University Pl & E 8 St         NaN   NaN         NaN       NaN
#
#      altitude  testStation   lastCommunicationTime  landMark
# 0         NaN        False  2016-01-22 04:30:15 PM       NaN
# 1         NaN        False  2016-01-22 04:32:41 PM       NaN
# 2         NaN        False  2016-01-22 04:29:41 PM       NaN
# 3         NaN        False  2016-01-22 04:32:33 PM       NaN
# 4         NaN        False  2016-01-22 04:32:32 PM       NaN
# ..        ...          ...                     ...       ...
# 504       NaN        False  2016-01-22 04:30:37 PM       NaN
# 505       NaN        False  2016-01-22 04:30:38 PM       NaN
# 506       NaN        False  2016-01-22 04:31:33 PM       NaN
# 507       NaN        False  2016-01-22 04:30:05 PM       NaN
# 508       NaN        False  2016-01-22 04:31:18 PM       NaN
#
# [509 rows x 19 columns]

# %%
# usar index_col = 0 para que no agregue columna "Unnamed"
df_stations = pd.read_excel('stations_cities.xlsx', sheet_name='Stations', index_col=0)
df_stations
# Out:
#        id                    stationName  availableDocks  totalDocks  \
# 0      72               W 52 St & 11 Ave              32          39
# 1      79       Franklin St & W Broadway               0          33
# 2      82         St James Pl & Pearl St              27          27
# 3      83  Atlantic Ave & Fort Greene Pl              21          62
# 4     116                W 17 St & 8 Ave              19          39
# ..    ...                            ...             ...         ...
# 504  3238                E 80 St & 2 Ave              35          37
# 505  3241       Monroe St & Tompkins Ave              18          19
# 506  3242     Schermerhorn St & Court St               5          39
# 507  3243                E 58 St & 1 Ave              28          29
# 508  3244         University Pl & E 8 St              27          31
#
#       latitude  longitude statusValue  statusKey  availableBikes  \
# 0    40.767272 -73.993929  In Service          1               7
# 1    40.719116 -74.006667  In Service          1              33
# 2    40.711174 -74.000165  In Service          1               0
# 3    40.683826 -73.976323  In Service          1              40
# 4    40.741776 -74.001497  In Service          1              19
# ..         ...        ...         ...        ...             ...
# 504  40.773914 -73.954395  In Service          1               2
# 505  40.686203 -73.944694  In Service          1               1
# 506  40.691029 -73.991834  In Service          1              31
# 507  40.758924 -73.962262  In Service          1               1
# 508  40.731437 -73.994903  In Service          1               4
#
#                         stAddress1  stAddress2  city  postalCode  location  \
# 0                 W 52 St & 11 Ave         NaN   NaN         NaN       NaN
# 1         Franklin St & W Broadway         NaN   NaN         NaN       NaN
# 2           St James Pl & Pearl St         NaN   NaN         NaN       NaN
# 3    Atlantic Ave & Fort Greene Pl         NaN   NaN         NaN       NaN
# 4                  W 17 St & 8 Ave         NaN   NaN         NaN       NaN
# ..                             ...         ...   ...         ...       ...
# 504                E 80 St & 2 Ave         NaN   NaN         NaN       NaN
# 505       Monroe St & Tompkins Ave         NaN   NaN         NaN       NaN
# 506     Schermerhorn St & Court St         NaN   NaN         NaN       NaN
# 507                E 58 St & 1 Ave         NaN   NaN         NaN       NaN
# 508         University Pl & E 8 St         NaN   NaN         NaN       NaN
#
#      altitude  testStation   lastCommunicationTime  landMark
# 0         NaN        False  2016-01-22 04:30:15 PM       NaN
# 1         NaN        False  2016-01-22 04:32:41 PM       NaN
# 2         NaN        False  2016-01-22 04:29:41 PM       NaN
# 3         NaN        False  2016-01-22 04:32:33 PM       NaN
# 4         NaN        False  2016-01-22 04:32:32 PM       NaN
# ..        ...          ...                     ...       ...
# 504       NaN        False  2016-01-22 04:30:37 PM       NaN
# 505       NaN        False  2016-01-22 04:30:38 PM       NaN
# 506       NaN        False  2016-01-22 04:31:33 PM       NaN
# 507       NaN        False  2016-01-22 04:30:05 PM       NaN
# 508       NaN        False  2016-01-22 04:31:18 PM       NaN
#
# [509 rows x 18 columns]

# %%
# Lectura de la hoja correspondiente a "Cities"
df_ciudades = pd.read_excel('stations_cities.xlsx', sheet_name='Cities', index_col=0)
df_ciudades
# Out:
#        Ciudad            País  Población
# 0       París         Francia    2161000
# 1       Milán          Italia    1352000
# 2  Nueva York  Estados Unidos    8468000
# 3     Londres      Inglaterra    8982000
