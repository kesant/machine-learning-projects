# %% [markdown]
# # Formas de ordenar *DataFrames*
#
# En la lección anterior vimos diferentes formas de seleccionar y manipular filas y columnas de un *DataFrame*.
#
# Muchas veces, cuando analizamos un set de datos, resulta muy útil tener la opción de organizarlo bien sea con base en valores numéricos o en la información contenida en las columnas categóricas.
#
# Este tipo de operaciones se conocen de manera conjunta como *sorting*. Y en Pandas podemos realizar diferentes tipos de *sorting* dependiendo de la información que queramos extraer del set de datos.
#
# En esta lección veremos las principales formas de ordenar un *DataFrame*. En particular veremos cómo:
#
# 1. Organizar las columnas del *DataFrame*
# 2. Organizar las filas del *DataFrame* con base en la información contenida en una o múltiples columnas
# 3. Organizar las filas con base en el índice del *DataFrame*
#
# Veamos cómo lograr estos objetivos y al final veremos un ejemplo aplicado, combinando ideas vistas en la lección anterior.

# %% [markdown]
# ## 1. Organizar las columnas del *DataFrame*
#
# Muchas veces resulta más fácil interpretar la información contenida en el *DataFrame* si las columnas se encuentran en el orden adecuado.
#
# Volvamos al set de datos *peliculas.csv*:

# %%
# 1. Organizar columnas
import pandas as pd

df = pd.read_csv('peliculas.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %% [markdown]
# Acá vemos que no resulta fácil dar una primera exploración al set de datos, en parte porque las columnas no están organizadas siguiendo un orden lógico. Por ejemplo, hay columnas numéricas seguidas de columnas categóricas.
#
# Sugiero seguir esta lógica al momento de reorganizar las columnas de un dataset:
#
# 1. Determinar si cada columna es categórica o numérica
# 2. Agrupar columnas categóricas aparte de las numéricas
# 3. Definir el nuevo orden de las columnas, ubicando las más importantes primero (generalmente las categóricas)
#
# El nivel de importancia que asignemos a las columnas dependerá del análisis que queramos hacer. Por ejemplo, si volvemos al set de datos *peliculas.csv* por ejemplo lo que nos interesa visualizar primero es precisamente el nombre de la película, posiblemente luego el nombre del director y de los actores principales, y al final ubicar las variables numéricas.
#
# Reorganicemos el *DataFrame* teniendo en cuenta estos criterios:

# %%
# Imprimamos en pantalla el tipo de dato de cada columna (para determinar si son datos
# categóricos o numéricos)
df.dtypes
# Out:
# color                         object
# director_name                 object
# num_critic_for_reviews       float64
# duration                     float64
# director_facebook_likes      float64
# actor_3_facebook_likes       float64
# actor_2_name                  object
# actor_1_facebook_likes       float64
# gross                        float64
# genres                        object
# actor_1_name                  object
# movie_title                   object
# num_voted_users                int64
# cast_total_facebook_likes      int64
# actor_3_name                  object
# facenumber_in_poster         float64
# plot_keywords                 object
# movie_imdb_link               object
# num_user_for_reviews         float64
# language                      object
# country                       object
# content_rating                object
# budget                       float64
# title_year                   float64
# actor_2_facebook_likes       float64
# imdb_score                   float64
# aspect_ratio                 float64
# movie_facebook_likes           int64
# dtype: object

# %%
# Agrupemos las columnas en categóricas y numéricas y definamos un orden basado en su importancia

# Columnas categóricas organizadas
col_cat = ['movie_title', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 
           'genres', 'plot_keywords', 'language', 'country', 'movie_imdb_link', 'color']

# Columnas numéricas organizadas
col_num = ['budget', 'gross', 'imdb_score', 'duration', 'title_year', 'director_facebook_likes', 
           'actor_1_facebook_likes', 'actor_2_facebook_likes', 'actor_3_facebook_likes',
           'movie_facebook_likes', 'cast_total_facebook_likes', 'num_critic_for_reviews', 
           'num_voted_users', 'num_user_for_reviews', 'facenumber_in_poster',
           'content_rating', 'aspect_ratio']

# Combinar columnas categóricas y numéricas organizadas
col_order = col_cat + col_num
print(col_order)
# Out:
# ['movie_title', 'director_name', 'actor_1_name', 'actor_2_name', 'actor_3_name', 'genres', 'plot_keywords', 'language', 'country', 'movie_imdb_link', 'color', 'budget', 'gross', 'imdb_score', 'duration', 'title_year', 'director_facebook_likes', 'actor_1_facebook_likes', 'actor_2_facebook_likes', 'actor_3_facebook_likes', 'movie_facebook_likes', 'cast_total_facebook_likes', 'num_critic_for_reviews', 'num_voted_users', 'num_user_for_reviews', 'facenumber_in_poster', 'content_rating', 'aspect_ratio']

# %% [markdown]
# Y simplemente podemos sobre-escribir el *DataFrame* usando el listado de columnas organizado:

# %%
df = df[col_order]
df
# Out:
#                                      movie_title      director_name  \
# 0                                         Avatar      James Cameron
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                        Spectre         Sam Mendes
# 3                          The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker
# ...                                          ...                ...
# 4911                     Signed Sealed Delivered        Scott Smith
# 4912                               The Following                NaN
# 4913                        A Plague So Pleasant   Benjamin Roberds
# 4914                            Shanghai Calling        Daniel Hsia
# 4915                           My Date with Drew           Jon Gunn
#
#          actor_1_name      actor_2_name          actor_3_name  \
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 4911                     Comedy|Drama
# 4912     Crime|Drama|Mystery|Thriller
# 4913            Drama|Horror|Thriller
# 4914             Comedy|Drama|Romance
# 4915                      Documentary
#
#                                           plot_keywords language country  \
# 0                avatar|future|marine|native|paraplegic  English     USA
# 1     goddess|marriage ceremony|marriage proposal|pi...  English     USA
# 2                   bomb|espionage|sequel|spy|terrorist  English      UK
# 3     deception|imprisonment|lawlessness|police offi...  English     USA
# 4                                                   NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 4911             fraud|postal worker|prison|theft|trial  English  Canada
# 4912       cult|fbi|hideout|prison escape|serial killer  English     USA
# 4913                                                NaN  English     USA
# 4914                                                NaN  English     USA
# 4915  actress name in title|crush|date|four word tit...  English     USA
#
#                                         movie_imdb_link  ...  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  ...
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  ...
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  ...
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  ...
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...  ...
# ...                                                 ...  ...
# 4911  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  ...
# 4912  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  ...
# 4913  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  ...
# 4914  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  ...
# 4915  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  ...
#
#      actor_2_facebook_likes  actor_3_facebook_likes  movie_facebook_likes  \
# 0                     936.0                   855.0                 33000
# 1                    5000.0                  1000.0                     0
# 2                     393.0                   161.0                 85000
# 3                   23000.0                 23000.0                164000
# 4                      12.0                     NaN                     0
# ...                     ...                     ...                   ...
# 4911                  470.0                   318.0                    84
# 4912                  593.0                   319.0                 32000
# 4913                    0.0                     0.0                    16
# 4914                  719.0                   489.0                   660
# 4915                   23.0                    16.0                   456
#
#       cast_total_facebook_likes  num_critic_for_reviews  num_voted_users  \
# 0                          4834                   723.0           886204
# 1                         48350                   302.0           471220
# 2                         11700                   602.0           275868
# 3                        106759                   813.0          1144337
# 4                           143                     NaN                8
# ...                         ...                     ...              ...
# 4911                       2283                     1.0              629
# 4912                       1753                    43.0            73839
# 4913                          0                    13.0               38
# 4914                       2386                    14.0             1255
# 4915                        163                    43.0             4285
#
#       num_user_for_reviews  facenumber_in_poster  content_rating  aspect_ratio
# 0                   3054.0                   0.0           PG-13          1.78
# 1                   1238.0                   0.0           PG-13          2.35
# 2                    994.0                   1.0           PG-13          2.35
# 3                   2701.0                   0.0           PG-13          2.35
# 4                      NaN                   0.0             NaN           NaN
# ...                    ...                   ...             ...           ...
# 4911                   6.0                   2.0             NaN           NaN
# 4912                 359.0                   1.0           TV-14         16.00
# 4913                   3.0                   0.0             NaN           NaN
# 4914                   9.0                   5.0           PG-13          2.35
# 4915                  84.0                   0.0              PG          1.85
#
# [4916 rows x 28 columns]

# %% [markdown]
# Vemos que este nuevo orden hace más fácil la interpretación de nuestro dataset.

# %% [markdown]
# # 2. Ordenar las filas con base en los valores de una o múltiples columnas
#
# En el ejemplo anterior vimos cómo organizar las columnas del dataset. Pero también podemos organizar las filas del dataset, lo cual también la interpretación de estos datos.
#
# En esta sección veremos cómo ordenar las filas del dataset con base en los valores de una o múltiples columnas.
#
# POr ejemplo, supongamos que nos interesa ordenar el dataset con base en el nombre de cada película (columna "movie_title") y siguiendo un orden alfabético.
#
# En este caso podemos usar el método `sort_values`:

# %%
# Ordenar el dataframe con base en la columna "movie_title" alfabéticamente
df_sorted_movie = df.sort_values("movie_title")
df_sorted_movie
# Out:
#                      movie_title        director_name          actor_1_name  \
# 4349                     #Horror         Tara Subkoff        Timothy Hutton
# 3629         10 Cloverfield Lane     Dan Trachtenberg        Bradley Cooper
# 2964       10 Days in a Madhouse        Timothy Hines   Christopher Lambert
# 2799  10 Things I Hate About You           Gil Junger  Joseph Gordon-Levitt
# 276                  10,000 B.C.  Christopher Barnard           Mathew Buck
# ...                          ...                  ...                   ...
# 3597                     [Rec] 2      Jaume Balagueró    Jonathan D. Mellor
# 2127                    eXistenZ     David Cronenberg  Jennifer Jason Leigh
# 579                          xXx            Rob Cohen            Vin Diesel
# 782      xXx: State of the Union         Lee Tamahori          Sunny Mabrey
# 873                     Æon Flux         Karyn Kusama       Charlize Theron
#
#             actor_2_name      actor_3_name  \
# 4349     Balthazar Getty      Lydia Hearst
# 3629  John Gallagher Jr.   Sumalee Montano
# 2964       Kelly LeBrock  Alexandra Callas
# 2799        Heath Ledger     Andrew Keegan
# 276                  NaN               NaN
# ...                  ...               ...
# 3597         Pablo Rosso        Andrea Ros
# 2127        Sarah Polley     Callum Rennie
# 579                  Eve     Leila Arcieri
# 782            Nona Gaye            Xzibit
# 873       Sophie Okonedo   Paterson Joseph
#
#                                     genres  \
# 4349         Drama|Horror|Mystery|Thriller
# 3629  Drama|Horror|Mystery|Sci-Fi|Thriller
# 2964                                 Drama
# 2799                  Comedy|Drama|Romance
# 276                                 Comedy
# ...                                    ...
# 3597                                Horror
# 2127                Horror|Sci-Fi|Thriller
# 579              Action|Adventure|Thriller
# 782        Action|Adventure|Crime|Thriller
# 873                          Action|Sci-Fi
#
#                                           plot_keywords language country  \
# 4349  bullying|cyberbullying|girl|internet|throat sl...  English     USA
# 3629     alien|bunker|car crash|kidnapping|minimal cast  English     USA
# 2964                                                NaN  English     USA
# 2799   dating|protective father|school|shrew|teen movie  English     USA
# 276                                                 NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 3597  apartment|apartment building|blood sample|cruc...  Spanish   Spain
# 2127    assassin|game|game designer|pod|virtual reality  English  Canada
# 579                  agent|nsa|nsa agent|prague|russian  English     USA
# 782   coup d'etat|mutiny|president|u.s. navy|washing...  English     USA
# 873   based on cult favorite|disease|female hero|fem...  English     USA
#
#                                         movie_imdb_link  ...  \
# 4349  http://www.imdb.com/title/tt3526286/?ref_=fn_t...  ...
# 3629  http://www.imdb.com/title/tt1179933/?ref_=fn_t...  ...
# 2964  http://www.imdb.com/title/tt3453052/?ref_=fn_t...  ...
# 2799  http://www.imdb.com/title/tt0147800/?ref_=fn_t...  ...
# 276   http://www.imdb.com/title/tt1869849/?ref_=fn_t...  ...
# ...                                                 ...  ...
# 3597  http://www.imdb.com/title/tt1245112/?ref_=fn_t...  ...
# 2127  http://www.imdb.com/title/tt0120907/?ref_=fn_t...  ...
# 579   http://www.imdb.com/title/tt0295701/?ref_=fn_t...  ...
# 782   http://www.imdb.com/title/tt0329774/?ref_=fn_t...  ...
# 873   http://www.imdb.com/title/tt0402022/?ref_=fn_t...  ...
#
#      actor_2_facebook_likes  actor_3_facebook_likes  movie_facebook_likes  \
# 4349                  418.0                    56.0                   750
# 3629                  338.0                    82.0                 33000
# 2964                  445.0                   247.0                 26000
# 2799                13000.0                   835.0                 10000
# 276                     NaN                     NaN                     0
# ...                     ...                     ...                   ...
# 3597                    9.0                     6.0                  4000
# 2127                  900.0                   716.0                  6000
# 579                   223.0                   212.0                 10000
# 782                   233.0                   218.0                     0
# 873                   460.0                   352.0                     0
#
#       cast_total_facebook_likes  num_critic_for_reviews  num_voted_users  \
# 4349                       1044                    35.0             1547
# 3629                      14504                   411.0           126893
# 2964                       2059                     1.0              314
# 2799                      37907                   133.0           222099
# 276                           5                     NaN                6
# ...                         ...                     ...              ...
# 3597                         73                   222.0            55597
# 2127                       2990                   196.0            77493
# 579                       14790                   191.0           142569
# 782                         993                    77.0            51349
# 873                       10185                   178.0           110614
#
#       num_user_for_reviews  facenumber_in_poster  content_rating  aspect_ratio
# 4349                  42.0                   1.0       Not Rated           NaN
# 3629                 440.0                   0.0           PG-13          2.35
# 2964                  10.0                   1.0               R          1.85
# 2799                 549.0                   6.0           PG-13          1.85
# 276                    NaN                   0.0             NaN           NaN
# ...                    ...                   ...             ...           ...
# 3597                 148.0                   0.0               R          1.85
# 2127                 527.0                   0.0               R          1.85
# 579                  737.0                   0.0           PG-13          2.35
# 782                  213.0                   2.0           PG-13          2.35
# 873                  532.0                   0.0           PG-13          2.35
#
# [4916 rows x 28 columns]

# %%
# O podemos usar "ascending = False" para usar un orden alfabético inverso
df_sorted_movie_reversed = df.sort_values("movie_title", ascending = False)
df_sorted_movie_reversed
# Out:
#                      movie_title        director_name          actor_1_name  \
# 873                     Æon Flux         Karyn Kusama       Charlize Theron
# 782      xXx: State of the Union         Lee Tamahori          Sunny Mabrey
# 579                          xXx            Rob Cohen            Vin Diesel
# 2127                    eXistenZ     David Cronenberg  Jennifer Jason Leigh
# 3597                     [Rec] 2      Jaume Balagueró    Jonathan D. Mellor
# ...                          ...                  ...                   ...
# 276                  10,000 B.C.  Christopher Barnard           Mathew Buck
# 2799  10 Things I Hate About You           Gil Junger  Joseph Gordon-Levitt
# 2964       10 Days in a Madhouse        Timothy Hines   Christopher Lambert
# 3629         10 Cloverfield Lane     Dan Trachtenberg        Bradley Cooper
# 4349                     #Horror         Tara Subkoff        Timothy Hutton
#
#             actor_2_name      actor_3_name  \
# 873       Sophie Okonedo   Paterson Joseph
# 782            Nona Gaye            Xzibit
# 579                  Eve     Leila Arcieri
# 2127        Sarah Polley     Callum Rennie
# 3597         Pablo Rosso        Andrea Ros
# ...                  ...               ...
# 276                  NaN               NaN
# 2799        Heath Ledger     Andrew Keegan
# 2964       Kelly LeBrock  Alexandra Callas
# 3629  John Gallagher Jr.   Sumalee Montano
# 4349     Balthazar Getty      Lydia Hearst
#
#                                     genres  \
# 873                          Action|Sci-Fi
# 782        Action|Adventure|Crime|Thriller
# 579              Action|Adventure|Thriller
# 2127                Horror|Sci-Fi|Thriller
# 3597                                Horror
# ...                                    ...
# 276                                 Comedy
# 2799                  Comedy|Drama|Romance
# 2964                                 Drama
# 3629  Drama|Horror|Mystery|Sci-Fi|Thriller
# 4349         Drama|Horror|Mystery|Thriller
#
#                                           plot_keywords language country  \
# 873   based on cult favorite|disease|female hero|fem...  English     USA
# 782   coup d'etat|mutiny|president|u.s. navy|washing...  English     USA
# 579                  agent|nsa|nsa agent|prague|russian  English     USA
# 2127    assassin|game|game designer|pod|virtual reality  English  Canada
# 3597  apartment|apartment building|blood sample|cruc...  Spanish   Spain
# ...                                                 ...      ...     ...
# 276                                                 NaN      NaN     NaN
# 2799   dating|protective father|school|shrew|teen movie  English     USA
# 2964                                                NaN  English     USA
# 3629     alien|bunker|car crash|kidnapping|minimal cast  English     USA
# 4349  bullying|cyberbullying|girl|internet|throat sl...  English     USA
#
#                                         movie_imdb_link  ...  \
# 873   http://www.imdb.com/title/tt0402022/?ref_=fn_t...  ...
# 782   http://www.imdb.com/title/tt0329774/?ref_=fn_t...  ...
# 579   http://www.imdb.com/title/tt0295701/?ref_=fn_t...  ...
# 2127  http://www.imdb.com/title/tt0120907/?ref_=fn_t...  ...
# 3597  http://www.imdb.com/title/tt1245112/?ref_=fn_t...  ...
# ...                                                 ...  ...
# 276   http://www.imdb.com/title/tt1869849/?ref_=fn_t...  ...
# 2799  http://www.imdb.com/title/tt0147800/?ref_=fn_t...  ...
# 2964  http://www.imdb.com/title/tt3453052/?ref_=fn_t...  ...
# 3629  http://www.imdb.com/title/tt1179933/?ref_=fn_t...  ...
# 4349  http://www.imdb.com/title/tt3526286/?ref_=fn_t...  ...
#
#      actor_2_facebook_likes  actor_3_facebook_likes  movie_facebook_likes  \
# 873                   460.0                   352.0                     0
# 782                   233.0                   218.0                     0
# 579                   223.0                   212.0                 10000
# 2127                  900.0                   716.0                  6000
# 3597                    9.0                     6.0                  4000
# ...                     ...                     ...                   ...
# 276                     NaN                     NaN                     0
# 2799                13000.0                   835.0                 10000
# 2964                  445.0                   247.0                 26000
# 3629                  338.0                    82.0                 33000
# 4349                  418.0                    56.0                   750
#
#       cast_total_facebook_likes  num_critic_for_reviews  num_voted_users  \
# 873                       10185                   178.0           110614
# 782                         993                    77.0            51349
# 579                       14790                   191.0           142569
# 2127                       2990                   196.0            77493
# 3597                         73                   222.0            55597
# ...                         ...                     ...              ...
# 276                           5                     NaN                6
# 2799                      37907                   133.0           222099
# 2964                       2059                     1.0              314
# 3629                      14504                   411.0           126893
# 4349                       1044                    35.0             1547
#
#       num_user_for_reviews  facenumber_in_poster  content_rating  aspect_ratio
# 873                  532.0                   0.0           PG-13          2.35
# 782                  213.0                   2.0           PG-13          2.35
# 579                  737.0                   0.0           PG-13          2.35
# 2127                 527.0                   0.0               R          1.85
# 3597                 148.0                   0.0               R          1.85
# ...                    ...                   ...             ...           ...
# 276                    NaN                   0.0             NaN           NaN
# 2799                 549.0                   6.0           PG-13          1.85
# 2964                  10.0                   1.0               R          1.85
# 3629                 440.0                   0.0           PG-13          2.35
# 4349                  42.0                   1.0       Not Rated           NaN
#
# [4916 rows x 28 columns]

# %% [markdown]
# Podemos usar el mismo método `sort_values` pero usando múltiples columnas como criterio de ordenamiento.
#
# Por ejemplo, organicemos el *DataFrame* ubicando en la parte superior las películas con mayor presupuesto (columna "budget") **Y** con mayores ingresos (columna "gross"):

# %%
# Ordenamiento con base en mayor presupuesto (budget) y mayores ingresos (gross)
df_budget_gross = df.sort_values(['budget', 'gross'], ascending=False)
df_budget_gross
# Out:
#                   movie_title    director_name         actor_1_name  \
# 3787           Lady Vengeance   Chan-wook Park         Min-sik Choi
# 2955                 Fateless     Lajos Koltai         Marcell Nagy
# 2294        Princess Mononoke   Hayao Miyazaki        Minnie Driver
# 2305                 Steamboy  Katsuhiro Ôtomo     William Hootkins
# 3361                    Akira  Katsuhiro Ôtomo         Mitsuo Iwata
# ...                       ...              ...                  ...
# 4892                   Exeter    Marcus Nispel      Ashley Tramonte
# 4903           On the Downlow     Tadeo Garcia  Tatiana Suarez-Pico
# 4905                     Bang  Ash Baron-Cohen         Peter Greene
# 4911  Signed Sealed Delivered      Scott Smith          Eric Mabius
# 4912            The Following              NaN          Natalie Zea
#
#             actor_2_name       actor_3_name  \
# 3787        Yeong-ae Lee     Hye-jeong Kang
# 2955     Péter Fancsikai      Bálint Péntek
# 2294  Jada Pinkett Smith       Billy Crudup
# 2305  Robin Atkin Downes     Rosalind Ayres
# 3361       Takeshi Kusao       Tesshô Genda
# ...                  ...                ...
# 4892     Brittany Curran  Lindsay MacDonald
# 4903      Michael Cortez        Eric Ambriz
# 4905   Stanley B. Herman        James Noble
# 4911       Daphne Zuniga       Crystal Lowe
# 4912       Valorie Curry      Sam Underwood
#
#                                                  genres  \
# 3787                                        Crime|Drama
# 2955                                  Drama|Romance|War
# 2294                        Adventure|Animation|Fantasy
# 2305  Action|Adventure|Animation|Family|Sci-Fi|Thriller
# 3361                            Action|Animation|Sci-Fi
# ...                                                 ...
# 4892                            Horror|Mystery|Thriller
# 4903                                              Drama
# 4905                                        Crime|Drama
# 4911                                       Comedy|Drama
# 4912                       Crime|Drama|Mystery|Thriller
#
#                                           plot_keywords   language  \
# 3787  cake|christian|lesbian sex|oral sex|pregnant s...     Korean
# 2955                   bus|death|gay slur|hatred|jewish  Hungarian
# 2294      anime|cult film|forest|princess|studio ghibli   Japanese
# 2305               19th century|ball|boy|inventor|steam   Japanese
# 3361  based on manga|biker gang|gifted child|post th...   Japanese
# ...                                                 ...        ...
# 4892                 asylum|demon|party|secret|teenager    English
# 4903  gang initiation|gunplay|hazing|latino|shakespe...    English
# 4905  corruption|homeless|homeless man|motorcycle|ur...    English
# 4911             fraud|postal worker|prison|theft|trial    English
# 4912       cult|fbi|hideout|prison escape|serial killer    English
#
#           country                                    movie_imdb_link  ...  \
# 3787  South Korea  http://www.imdb.com/title/tt0451094/?ref_=fn_t...  ...
# 2955      Hungary  http://www.imdb.com/title/tt0367082/?ref_=fn_t...  ...
# 2294        Japan  http://www.imdb.com/title/tt0119698/?ref_=fn_t...  ...
# 2305        Japan  http://www.imdb.com/title/tt0348121/?ref_=fn_t...  ...
# 3361        Japan  http://www.imdb.com/title/tt0094625/?ref_=fn_t...  ...
# ...           ...                                                ...  ...
# 4892          USA  http://www.imdb.com/title/tt1945044/?ref_=fn_t...  ...
# 4903          USA  http://www.imdb.com/title/tt0390323/?ref_=fn_t...  ...
# 4905          USA  http://www.imdb.com/title/tt0109266/?ref_=fn_t...  ...
# 4911       Canada  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  ...
# 4912          USA  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  ...
#
#      actor_2_facebook_likes  actor_3_facebook_likes  movie_facebook_likes  \
# 3787                  126.0                    38.0                  4000
# 2955                    2.0                     0.0                   607
# 2294                  851.0                   745.0                 11000
# 2305                  336.0                   101.0                   973
# 3361                    5.0                     4.0                     0
# ...                     ...                     ...                   ...
# 4892                  512.0                   265.0                     0
# 4903                   20.0                    12.0                    22
# 4905                  194.0                   152.0                    20
# 4911                  470.0                   318.0                    84
# 4912                  593.0                   319.0                 32000
#
#       cast_total_facebook_likes  num_critic_for_reviews  num_voted_users  \
# 3787                        907                   202.0            53508
# 2955                         11                    73.0             5603
# 2294                       2710                   174.0           221552
# 2305                        991                   105.0            13727
# 3361                         28                   150.0           106160
# ...                         ...                     ...              ...
# 4892                       2679                    43.0             3836
# 4903                         62                     NaN              156
# 4905                       1186                    10.0              438
# 4911                       2283                     1.0              629
# 4912                       1753                    43.0            73839
#
#       num_user_for_reviews  facenumber_in_poster  content_rating  aspect_ratio
# 3787                 131.0                   0.0               R          2.35
# 2955                  45.0                   0.0               R          2.35
# 2294                 570.0                   0.0           PG-13          1.85
# 2305                  79.0                   1.0           PG-13          1.85
# 3361                 430.0                   0.0               R          1.85
# ...                    ...                   ...             ...           ...
# 4892                  33.0                   0.0               R          1.85
# 4903                   3.0                   2.0             NaN           NaN
# 4905                  14.0                   1.0             NaN           NaN
# 4911                   6.0                   2.0             NaN           NaN
# 4912                 359.0                   1.0           TV-14         16.00
#
# [4916 rows x 28 columns]

# %%
# Truco: podemos usar pd.options.display.max_columns para imprimir la tabla sin truncar las columnas
pd.options.display.max_columns = 999
df_budget_gross
# Out:
#                   movie_title    director_name         actor_1_name  \
# 3787           Lady Vengeance   Chan-wook Park         Min-sik Choi
# 2955                 Fateless     Lajos Koltai         Marcell Nagy
# 2294        Princess Mononoke   Hayao Miyazaki        Minnie Driver
# 2305                 Steamboy  Katsuhiro Ôtomo     William Hootkins
# 3361                    Akira  Katsuhiro Ôtomo         Mitsuo Iwata
# ...                       ...              ...                  ...
# 4892                   Exeter    Marcus Nispel      Ashley Tramonte
# 4903           On the Downlow     Tadeo Garcia  Tatiana Suarez-Pico
# 4905                     Bang  Ash Baron-Cohen         Peter Greene
# 4911  Signed Sealed Delivered      Scott Smith          Eric Mabius
# 4912            The Following              NaN          Natalie Zea
#
#             actor_2_name       actor_3_name  \
# 3787        Yeong-ae Lee     Hye-jeong Kang
# 2955     Péter Fancsikai      Bálint Péntek
# 2294  Jada Pinkett Smith       Billy Crudup
# 2305  Robin Atkin Downes     Rosalind Ayres
# 3361       Takeshi Kusao       Tesshô Genda
# ...                  ...                ...
# 4892     Brittany Curran  Lindsay MacDonald
# 4903      Michael Cortez        Eric Ambriz
# 4905   Stanley B. Herman        James Noble
# 4911       Daphne Zuniga       Crystal Lowe
# 4912       Valorie Curry      Sam Underwood
#
#                                                  genres  \
# 3787                                        Crime|Drama
# 2955                                  Drama|Romance|War
# 2294                        Adventure|Animation|Fantasy
# 2305  Action|Adventure|Animation|Family|Sci-Fi|Thriller
# 3361                            Action|Animation|Sci-Fi
# ...                                                 ...
# 4892                            Horror|Mystery|Thriller
# 4903                                              Drama
# 4905                                        Crime|Drama
# 4911                                       Comedy|Drama
# 4912                       Crime|Drama|Mystery|Thriller
#
#                                           plot_keywords   language  \
# 3787  cake|christian|lesbian sex|oral sex|pregnant s...     Korean
# 2955                   bus|death|gay slur|hatred|jewish  Hungarian
# 2294      anime|cult film|forest|princess|studio ghibli   Japanese
# 2305               19th century|ball|boy|inventor|steam   Japanese
# 3361  based on manga|biker gang|gifted child|post th...   Japanese
# ...                                                 ...        ...
# 4892                 asylum|demon|party|secret|teenager    English
# 4903  gang initiation|gunplay|hazing|latino|shakespe...    English
# 4905  corruption|homeless|homeless man|motorcycle|ur...    English
# 4911             fraud|postal worker|prison|theft|trial    English
# 4912       cult|fbi|hideout|prison escape|serial killer    English
#
#           country                                    movie_imdb_link  color  \
# 3787  South Korea  http://www.imdb.com/title/tt0451094/?ref_=fn_t...  Color
# 2955      Hungary  http://www.imdb.com/title/tt0367082/?ref_=fn_t...  Color
# 2294        Japan  http://www.imdb.com/title/tt0119698/?ref_=fn_t...  Color
# 2305        Japan  http://www.imdb.com/title/tt0348121/?ref_=fn_t...  Color
# 3361        Japan  http://www.imdb.com/title/tt0094625/?ref_=fn_t...  Color
# ...           ...                                                ...    ...
# 4892          USA  http://www.imdb.com/title/tt1945044/?ref_=fn_t...  Color
# 4903          USA  http://www.imdb.com/title/tt0390323/?ref_=fn_t...  Color
# 4905          USA  http://www.imdb.com/title/tt0109266/?ref_=fn_t...  Color
# 4911       Canada  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  Color
# 4912          USA  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  Color
#
#             budget      gross  imdb_score  duration  title_year  \
# 3787  4.200000e+09   211667.0         7.7     112.0      2005.0
# 2955  2.500000e+09   195888.0         7.1     134.0      2005.0
# 2294  2.400000e+09  2298191.0         8.4     134.0      1997.0
# 2305  2.127520e+09   410388.0         6.9     103.0      2004.0
# 3361  1.100000e+09   439162.0         8.1     124.0      1988.0
# ...            ...        ...         ...       ...         ...
# 4892           NaN        NaN         4.6      91.0      2015.0
# 4903           NaN        NaN         6.1      84.0      2004.0
# 4905           NaN        NaN         6.4      98.0      1995.0
# 4911           NaN        NaN         7.7      87.0      2013.0
# 4912           NaN        NaN         7.5      43.0         NaN
#
#       director_facebook_likes  actor_1_facebook_likes  actor_2_facebook_likes  \
# 3787                      0.0                   717.0                   126.0
# 2955                     45.0                     9.0                     2.0
# 2294                   6000.0                   893.0                   851.0
# 2305                     78.0                   488.0                   336.0
# 3361                     78.0                     6.0                     5.0
# ...                       ...                     ...                     ...
# 4892                    158.0                   630.0                   512.0
# 4903                      5.0                    21.0                    20.0
# 4905                      3.0                   789.0                   194.0
# 4911                      2.0                   637.0                   470.0
# 4912                      NaN                   841.0                   593.0
#
#       actor_3_facebook_likes  movie_facebook_likes  cast_total_facebook_likes  \
# 3787                    38.0                  4000                        907
# 2955                     0.0                   607                         11
# 2294                   745.0                 11000                       2710
# 2305                   101.0                   973                        991
# 3361                     4.0                     0                         28
# ...                      ...                   ...                        ...
# 4892                   265.0                     0                       2679
# 4903                    12.0                    22                         62
# 4905                   152.0                    20                       1186
# 4911                   318.0                    84                       2283
# 4912                   319.0                 32000                       1753
#
#       num_critic_for_reviews  num_voted_users  num_user_for_reviews  \
# 3787                   202.0            53508                 131.0
# 2955                    73.0             5603                  45.0
# 2294                   174.0           221552                 570.0
# 2305                   105.0            13727                  79.0
# 3361                   150.0           106160                 430.0
# ...                      ...              ...                   ...
# 4892                    43.0             3836                  33.0
# 4903                     NaN              156                   3.0
# 4905                    10.0              438                  14.0
# 4911                     1.0              629                   6.0
# 4912                    43.0            73839                 359.0
#
#       facenumber_in_poster content_rating  aspect_ratio
# 3787                   0.0              R          2.35
# 2955                   0.0              R          2.35
# 2294                   0.0          PG-13          1.85
# 2305                   1.0          PG-13          1.85
# 3361                   0.0              R          1.85
# ...                    ...            ...           ...
# 4892                   0.0              R          1.85
# 4903                   2.0            NaN           NaN
# 4905                   1.0            NaN           NaN
# 4911                   2.0            NaN           NaN
# 4912                   1.0          TV-14         16.00
#
# [4916 rows x 28 columns]

# %% [markdown]
# ## 3. Organizar las filas del *DataFrame* con base en el índice
#
# Y podemos también organizar las filas con base en los valores contenidos en el índice. En este caso podemos usar el método `sort_index()`.
#
# Por ejemplo, tomemos el *DataFrame* que acabamos de crear en el ejemplo anterior (`df_budget_gross`) para re-organizarlo con base en los valores de su índice:

# %%
df_sorted_idx = df_budget_gross.sort_index()
df_sorted_idx
# Out:
#                                      movie_title      director_name  \
# 0                                         Avatar      James Cameron
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                        Spectre         Sam Mendes
# 3                          The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker
# ...                                          ...                ...
# 4911                     Signed Sealed Delivered        Scott Smith
# 4912                               The Following                NaN
# 4913                        A Plague So Pleasant   Benjamin Roberds
# 4914                            Shanghai Calling        Daniel Hsia
# 4915                           My Date with Drew           Jon Gunn
#
#          actor_1_name      actor_2_name          actor_3_name  \
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 4911                     Comedy|Drama
# 4912     Crime|Drama|Mystery|Thriller
# 4913            Drama|Horror|Thriller
# 4914             Comedy|Drama|Romance
# 4915                      Documentary
#
#                                           plot_keywords language country  \
# 0                avatar|future|marine|native|paraplegic  English     USA
# 1     goddess|marriage ceremony|marriage proposal|pi...  English     USA
# 2                   bomb|espionage|sequel|spy|terrorist  English      UK
# 3     deception|imprisonment|lawlessness|police offi...  English     USA
# 4                                                   NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 4911             fraud|postal worker|prison|theft|trial  English  Canada
# 4912       cult|fbi|hideout|prison escape|serial killer  English     USA
# 4913                                                NaN  English     USA
# 4914                                                NaN  English     USA
# 4915  actress name in title|crush|date|four word tit...  English     USA
#
#                                         movie_imdb_link  color       budget  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color  237000000.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  Color  300000000.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  Color  245000000.0
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  Color  250000000.0
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...    NaN          NaN
# ...                                                 ...    ...          ...
# 4911  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  Color          NaN
# 4912  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  Color          NaN
# 4913  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  Color       1400.0
# 4914  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  Color          NaN
# 4915  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  Color       1100.0
#
#             gross  imdb_score  duration  title_year  director_facebook_likes  \
# 0     760505847.0         7.9     178.0      2009.0                      0.0
# 1     309404152.0         7.1     169.0      2007.0                    563.0
# 2     200074175.0         6.8     148.0      2015.0                      0.0
# 3     448130642.0         8.5     164.0      2012.0                  22000.0
# 4             NaN         7.1       NaN         NaN                    131.0
# ...           ...         ...       ...         ...                      ...
# 4911          NaN         7.7      87.0      2013.0                      2.0
# 4912          NaN         7.5      43.0         NaN                      NaN
# 4913          NaN         6.3      76.0      2013.0                      0.0
# 4914      10443.0         6.3     100.0      2012.0                      0.0
# 4915      85222.0         6.6      90.0      2004.0                     16.0
#
#       actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                     1000.0                   936.0                   855.0
# 1                    40000.0                  5000.0                  1000.0
# 2                    11000.0                   393.0                   161.0
# 3                    27000.0                 23000.0                 23000.0
# 4                      131.0                    12.0                     NaN
# ...                      ...                     ...                     ...
# 4911                   637.0                   470.0                   318.0
# 4912                   841.0                   593.0                   319.0
# 4913                     0.0                     0.0                     0.0
# 4914                   946.0                   719.0                   489.0
# 4915                    86.0                    23.0                    16.0
#
#       movie_facebook_likes  cast_total_facebook_likes  num_critic_for_reviews  \
# 0                    33000                       4834                   723.0
# 1                        0                      48350                   302.0
# 2                    85000                      11700                   602.0
# 3                   164000                     106759                   813.0
# 4                        0                        143                     NaN
# ...                    ...                        ...                     ...
# 4911                    84                       2283                     1.0
# 4912                 32000                       1753                    43.0
# 4913                    16                          0                    13.0
# 4914                   660                       2386                    14.0
# 4915                   456                        163                    43.0
#
#       num_voted_users  num_user_for_reviews  facenumber_in_poster  \
# 0              886204                3054.0                   0.0
# 1              471220                1238.0                   0.0
# 2              275868                 994.0                   1.0
# 3             1144337                2701.0                   0.0
# 4                   8                   NaN                   0.0
# ...               ...                   ...                   ...
# 4911              629                   6.0                   2.0
# 4912            73839                 359.0                   1.0
# 4913               38                   3.0                   0.0
# 4914             1255                   9.0                   5.0
# 4915             4285                  84.0                   0.0
#
#      content_rating  aspect_ratio
# 0             PG-13          1.78
# 1             PG-13          2.35
# 2             PG-13          2.35
# 3             PG-13          2.35
# 4               NaN           NaN
# ...             ...           ...
# 4911            NaN           NaN
# 4912          TV-14         16.00
# 4913            NaN           NaN
# 4914          PG-13          2.35
# 4915             PG          1.85
#
# [4916 rows x 28 columns]

# %%
# Y como en ejemplos anteriores podemos usar "ascending = False" para definir un orden inverso
df_sorted_idx_reversed = df_budget_gross.sort_index(ascending = False)
df_sorted_idx_reversed
# Out:
#                                      movie_title      director_name  \
# 4915                           My Date with Drew           Jon Gunn
# 4914                            Shanghai Calling        Daniel Hsia
# 4913                        A Plague So Pleasant   Benjamin Roberds
# 4912                               The Following                NaN
# 4911                     Signed Sealed Delivered        Scott Smith
# ...                                          ...                ...
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker
# 3                          The Dark Knight Rises  Christopher Nolan
# 2                                        Spectre         Sam Mendes
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski
# 0                                         Avatar      James Cameron
#
#          actor_1_name      actor_2_name          actor_3_name  \
# 4915      John August  Brian Herzlinger              Jon Gunn
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# ...               ...               ...                   ...
# 4         Doug Walker        Rob Walker                   NaN
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 0         CCH Pounder  Joel David Moore             Wes Studi
#
#                                genres  \
# 4915                      Documentary
# 4914             Comedy|Drama|Romance
# 4913            Drama|Horror|Thriller
# 4912     Crime|Drama|Mystery|Thriller
# 4911                     Comedy|Drama
# ...                               ...
# 4                         Documentary
# 3                     Action|Thriller
# 2           Action|Adventure|Thriller
# 1            Action|Adventure|Fantasy
# 0     Action|Adventure|Fantasy|Sci-Fi
#
#                                           plot_keywords language country  \
# 4915  actress name in title|crush|date|four word tit...  English     USA
# 4914                                                NaN  English     USA
# 4913                                                NaN  English     USA
# 4912       cult|fbi|hideout|prison escape|serial killer  English     USA
# 4911             fraud|postal worker|prison|theft|trial  English  Canada
# ...                                                 ...      ...     ...
# 4                                                   NaN      NaN     NaN
# 3     deception|imprisonment|lawlessness|police offi...  English     USA
# 2                   bomb|espionage|sequel|spy|terrorist  English      UK
# 1     goddess|marriage ceremony|marriage proposal|pi...  English     USA
# 0                avatar|future|marine|native|paraplegic  English     USA
#
#                                         movie_imdb_link  color       budget  \
# 4915  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  Color       1100.0
# 4914  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  Color          NaN
# 4913  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  Color       1400.0
# 4912  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  Color          NaN
# 4911  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  Color          NaN
# ...                                                 ...    ...          ...
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...    NaN          NaN
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  Color  250000000.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  Color  245000000.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  Color  300000000.0
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color  237000000.0
#
#             gross  imdb_score  duration  title_year  director_facebook_likes  \
# 4915      85222.0         6.6      90.0      2004.0                     16.0
# 4914      10443.0         6.3     100.0      2012.0                      0.0
# 4913          NaN         6.3      76.0      2013.0                      0.0
# 4912          NaN         7.5      43.0         NaN                      NaN
# 4911          NaN         7.7      87.0      2013.0                      2.0
# ...           ...         ...       ...         ...                      ...
# 4             NaN         7.1       NaN         NaN                    131.0
# 3     448130642.0         8.5     164.0      2012.0                  22000.0
# 2     200074175.0         6.8     148.0      2015.0                      0.0
# 1     309404152.0         7.1     169.0      2007.0                    563.0
# 0     760505847.0         7.9     178.0      2009.0                      0.0
#
#       actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 4915                    86.0                    23.0                    16.0
# 4914                   946.0                   719.0                   489.0
# 4913                     0.0                     0.0                     0.0
# 4912                   841.0                   593.0                   319.0
# 4911                   637.0                   470.0                   318.0
# ...                      ...                     ...                     ...
# 4                      131.0                    12.0                     NaN
# 3                    27000.0                 23000.0                 23000.0
# 2                    11000.0                   393.0                   161.0
# 1                    40000.0                  5000.0                  1000.0
# 0                     1000.0                   936.0                   855.0
#
#       movie_facebook_likes  cast_total_facebook_likes  num_critic_for_reviews  \
# 4915                   456                        163                    43.0
# 4914                   660                       2386                    14.0
# 4913                    16                          0                    13.0
# 4912                 32000                       1753                    43.0
# 4911                    84                       2283                     1.0
# ...                    ...                        ...                     ...
# 4                        0                        143                     NaN
# 3                   164000                     106759                   813.0
# 2                    85000                      11700                   602.0
# 1                        0                      48350                   302.0
# 0                    33000                       4834                   723.0
#
#       num_voted_users  num_user_for_reviews  facenumber_in_poster  \
# 4915             4285                  84.0                   0.0
# 4914             1255                   9.0                   5.0
# 4913               38                   3.0                   0.0
# 4912            73839                 359.0                   1.0
# 4911              629                   6.0                   2.0
# ...               ...                   ...                   ...
# 4                   8                   NaN                   0.0
# 3             1144337                2701.0                   0.0
# 2              275868                 994.0                   1.0
# 1              471220                1238.0                   0.0
# 0              886204                3054.0                   0.0
#
#      content_rating  aspect_ratio
# 4915             PG          1.85
# 4914          PG-13          2.35
# 4913            NaN           NaN
# 4912          TV-14         16.00
# 4911            NaN           NaN
# ...             ...           ...
# 4               NaN           NaN
# 3             PG-13          2.35
# 2             PG-13          2.35
# 1             PG-13          2.35
# 0             PG-13          1.78
#
# [4916 rows x 28 columns]

# %% [markdown]
# ## 4. Ejemplo práctico
#
# Usemos algunas de las herramientas vistas hasta ahora para responder a esta pregunta: ¿cuáles son las 10 películas más exitosas, midiendo este éxito como aquellas con mejores ingresos netos?

# %%
# Primero calculemos los ingresos netos (ingresos brutos - presupuesto)
# y almacenemos esta información en una nueva columna del DataFrame
df['net_profit'] = df['gross'] - df['budget']
df
# Out:
# /var/folders/1m/9cqrfyd50y187jzs__s4l9b80000gn/T/ipykernel_5863/425922091.py:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df['net_profit'] = df['gross'] - df['budget']
#                                      movie_title      director_name  \
# 0                                         Avatar      James Cameron
# 1       Pirates of the Caribbean: At World's End     Gore Verbinski
# 2                                        Spectre         Sam Mendes
# 3                          The Dark Knight Rises  Christopher Nolan
# 4     Star Wars: Episode VII - The Force Awakens        Doug Walker
# ...                                          ...                ...
# 4911                     Signed Sealed Delivered        Scott Smith
# 4912                               The Following                NaN
# 4913                        A Plague So Pleasant   Benjamin Roberds
# 4914                            Shanghai Calling        Daniel Hsia
# 4915                           My Date with Drew           Jon Gunn
#
#          actor_1_name      actor_2_name          actor_3_name  \
# 0         CCH Pounder  Joel David Moore             Wes Studi
# 1         Johnny Depp     Orlando Bloom        Jack Davenport
# 2     Christoph Waltz      Rory Kinnear      Stephanie Sigman
# 3           Tom Hardy    Christian Bale  Joseph Gordon-Levitt
# 4         Doug Walker        Rob Walker                   NaN
# ...               ...               ...                   ...
# 4911      Eric Mabius     Daphne Zuniga          Crystal Lowe
# 4912      Natalie Zea     Valorie Curry         Sam Underwood
# 4913      Eva Boehnke     Maxwell Moody        David Chandler
# 4914        Alan Ruck     Daniel Henney           Eliza Coupe
# 4915      John August  Brian Herzlinger              Jon Gunn
#
#                                genres  \
# 0     Action|Adventure|Fantasy|Sci-Fi
# 1            Action|Adventure|Fantasy
# 2           Action|Adventure|Thriller
# 3                     Action|Thriller
# 4                         Documentary
# ...                               ...
# 4911                     Comedy|Drama
# 4912     Crime|Drama|Mystery|Thriller
# 4913            Drama|Horror|Thriller
# 4914             Comedy|Drama|Romance
# 4915                      Documentary
#
#                                           plot_keywords language country  \
# 0                avatar|future|marine|native|paraplegic  English     USA
# 1     goddess|marriage ceremony|marriage proposal|pi...  English     USA
# 2                   bomb|espionage|sequel|spy|terrorist  English      UK
# 3     deception|imprisonment|lawlessness|police offi...  English     USA
# 4                                                   NaN      NaN     NaN
# ...                                                 ...      ...     ...
# 4911             fraud|postal worker|prison|theft|trial  English  Canada
# 4912       cult|fbi|hideout|prison escape|serial killer  English     USA
# 4913                                                NaN  English     USA
# 4914                                                NaN  English     USA
# 4915  actress name in title|crush|date|four word tit...  English     USA
#
#                                         movie_imdb_link  color       budget  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color  237000000.0
# 1     http://www.imdb.com/title/tt0449088/?ref_=fn_t...  Color  300000000.0
# 2     http://www.imdb.com/title/tt2379713/?ref_=fn_t...  Color  245000000.0
# 3     http://www.imdb.com/title/tt1345836/?ref_=fn_t...  Color  250000000.0
# 4     http://www.imdb.com/title/tt5289954/?ref_=fn_t...    NaN          NaN
# ...                                                 ...    ...          ...
# 4911  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  Color          NaN
# 4912  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  Color          NaN
# 4913  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  Color       1400.0
# 4914  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  Color          NaN
# 4915  http://www.imdb.com/title/tt0378407/?ref_=fn_t...  Color       1100.0
#
#             gross  imdb_score  duration  title_year  director_facebook_likes  \
# 0     760505847.0         7.9     178.0      2009.0                      0.0
# 1     309404152.0         7.1     169.0      2007.0                    563.0
# 2     200074175.0         6.8     148.0      2015.0                      0.0
# 3     448130642.0         8.5     164.0      2012.0                  22000.0
# 4             NaN         7.1       NaN         NaN                    131.0
# ...           ...         ...       ...         ...                      ...
# 4911          NaN         7.7      87.0      2013.0                      2.0
# 4912          NaN         7.5      43.0         NaN                      NaN
# 4913          NaN         6.3      76.0      2013.0                      0.0
# 4914      10443.0         6.3     100.0      2012.0                      0.0
# 4915      85222.0         6.6      90.0      2004.0                     16.0
#
#       actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                     1000.0                   936.0                   855.0
# 1                    40000.0                  5000.0                  1000.0
# 2                    11000.0                   393.0                   161.0
# 3                    27000.0                 23000.0                 23000.0
# 4                      131.0                    12.0                     NaN
# ...                      ...                     ...                     ...
# 4911                   637.0                   470.0                   318.0
# 4912                   841.0                   593.0                   319.0
# 4913                     0.0                     0.0                     0.0
# 4914                   946.0                   719.0                   489.0
# 4915                    86.0                    23.0                    16.0
#
#       movie_facebook_likes  cast_total_facebook_likes  num_critic_for_reviews  \
# 0                    33000                       4834                   723.0
# 1                        0                      48350                   302.0
# 2                    85000                      11700                   602.0
# 3                   164000                     106759                   813.0
# 4                        0                        143                     NaN
# ...                    ...                        ...                     ...
# 4911                    84                       2283                     1.0
# 4912                 32000                       1753                    43.0
# 4913                    16                          0                    13.0
# 4914                   660                       2386                    14.0
# 4915                   456                        163                    43.0
#
#       num_voted_users  num_user_for_reviews  facenumber_in_poster  \
# 0              886204                3054.0                   0.0
# 1              471220                1238.0                   0.0
# 2              275868                 994.0                   1.0
# 3             1144337                2701.0                   0.0
# 4                   8                   NaN                   0.0
# ...               ...                   ...                   ...
# 4911              629                   6.0                   2.0
# 4912            73839                 359.0                   1.0
# 4913               38                   3.0                   0.0
# 4914             1255                   9.0                   5.0
# 4915             4285                  84.0                   0.0
#
#      content_rating  aspect_ratio   net_profit
# 0             PG-13          1.78  523505847.0
# 1             PG-13          2.35    9404152.0
# 2             PG-13          2.35  -44925825.0
# 3             PG-13          2.35  198130642.0
# 4               NaN           NaN          NaN
# ...             ...           ...          ...
# 4911            NaN           NaN          NaN
# 4912          TV-14         16.00          NaN
# 4913            NaN           NaN          NaN
# 4914          PG-13          2.35          NaN
# 4915             PG          1.85      84122.0
#
# [4916 rows x 29 columns]

# %%
# Organizacemos el DataFrame de manera DESCENDENTE con base en "net_profit"
df = df.sort_values("net_profit", ascending = False)
df
# Out:
#                              movie_title     director_name  \
# 0                                 Avatar     James Cameron
# 29                        Jurassic World   Colin Trevorrow
# 26                               Titanic     James Cameron
# 2973  Star Wars: Episode IV - A New Hope      George Lucas
# 3028          E.T. the Extra-Terrestrial  Steven Spielberg
# ...                                  ...               ...
# 4909                     The Mongol King   Anthony Vallone
# 4911             Signed Sealed Delivered       Scott Smith
# 4912                       The Following               NaN
# 4913                A Plague So Pleasant  Benjamin Roberds
# 4914                    Shanghai Calling       Daniel Hsia
#
#              actor_1_name      actor_2_name    actor_3_name  \
# 0             CCH Pounder  Joel David Moore       Wes Studi
# 29    Bryce Dallas Howard        Judy Greer         Omar Sy
# 26      Leonardo DiCaprio      Kate Winslet   Gloria Stuart
# 2973        Harrison Ford     Peter Cushing     Kenny Baker
# 3028         Henry Thomas       Dee Wallace    Peter Coyote
# ...                   ...               ...             ...
# 4909       Richard Jewell    John Considine  Sara Stepnicka
# 4911          Eric Mabius     Daphne Zuniga    Crystal Lowe
# 4912          Natalie Zea     Valorie Curry   Sam Underwood
# 4913          Eva Boehnke     Maxwell Moody  David Chandler
# 4914            Alan Ruck     Daniel Henney     Eliza Coupe
#
#                                 genres  \
# 0      Action|Adventure|Fantasy|Sci-Fi
# 29    Action|Adventure|Sci-Fi|Thriller
# 26                       Drama|Romance
# 2973   Action|Adventure|Fantasy|Sci-Fi
# 3028                     Family|Sci-Fi
# ...                                ...
# 4909                       Crime|Drama
# 4911                      Comedy|Drama
# 4912      Crime|Drama|Mystery|Thriller
# 4913             Drama|Horror|Thriller
# 4914              Comedy|Drama|Romance
#
#                                           plot_keywords language country  \
# 0                avatar|future|marine|native|paraplegic  English     USA
# 29    dinosaur|disaster film|experiment gone wrong|j...  English     USA
# 26                         artist|love|ship|titanic|wet  English     USA
# 2973  death star|empire|galactic war|princess|rebellion  English     USA
# 3028  bicyclist|boy|doll|star wars reference|voice i...  English     USA
# ...                                                 ...      ...     ...
# 4909        jewell|mongol|nostradamus|stepnicka|vallone  English     USA
# 4911             fraud|postal worker|prison|theft|trial  English  Canada
# 4912       cult|fbi|hideout|prison escape|serial killer  English     USA
# 4913                                                NaN  English     USA
# 4914                                                NaN  English     USA
#
#                                         movie_imdb_link  color       budget  \
# 0     http://www.imdb.com/title/tt0499549/?ref_=fn_t...  Color  237000000.0
# 29    http://www.imdb.com/title/tt0369610/?ref_=fn_t...  Color  150000000.0
# 26    http://www.imdb.com/title/tt0120338/?ref_=fn_t...  Color  200000000.0
# 2973  http://www.imdb.com/title/tt0076759/?ref_=fn_t...  Color   11000000.0
# 3028  http://www.imdb.com/title/tt0083866/?ref_=fn_t...  Color   10500000.0
# ...                                                 ...    ...          ...
# 4909  http://www.imdb.com/title/tt0430371/?ref_=fn_t...  Color       3250.0
# 4911  http://www.imdb.com/title/tt3000844/?ref_=fn_t...  Color          NaN
# 4912  http://www.imdb.com/title/tt2071645/?ref_=fn_t...  Color          NaN
# 4913  http://www.imdb.com/title/tt2107644/?ref_=fn_t...  Color       1400.0
# 4914  http://www.imdb.com/title/tt2070597/?ref_=fn_t...  Color          NaN
#
#             gross  imdb_score  duration  title_year  director_facebook_likes  \
# 0     760505847.0         7.9     178.0      2009.0                      0.0
# 29    652177271.0         7.0     124.0      2015.0                    365.0
# 26    658672302.0         7.7     194.0      1997.0                      0.0
# 2973  460935665.0         8.7     125.0      1977.0                      0.0
# 3028  434949459.0         7.9     120.0      1982.0                  14000.0
# ...           ...         ...       ...         ...                      ...
# 4909          NaN         7.8      84.0      2005.0                      2.0
# 4911          NaN         7.7      87.0      2013.0                      2.0
# 4912          NaN         7.5      43.0         NaN                      NaN
# 4913          NaN         6.3      76.0      2013.0                      0.0
# 4914      10443.0         6.3     100.0      2012.0                      0.0
#
#       actor_1_facebook_likes  actor_2_facebook_likes  actor_3_facebook_likes  \
# 0                     1000.0                   936.0                   855.0
# 29                    3000.0                  2000.0                  1000.0
# 26                   29000.0                 14000.0                   794.0
# 2973                 11000.0                  1000.0                   504.0
# 3028                   861.0                   725.0                   548.0
# ...                      ...                     ...                     ...
# 4909                    45.0                    44.0                     2.0
# 4911                   637.0                   470.0                   318.0
# 4912                   841.0                   593.0                   319.0
# 4913                     0.0                     0.0                     0.0
# 4914                   946.0                   719.0                   489.0
#
#       movie_facebook_likes  cast_total_facebook_likes  num_critic_for_reviews  \
# 0                    33000                       4834                   723.0
# 29                  150000                       8458                   644.0
# 26                   26000                      45223                   315.0
# 2973                 33000                      13485                   282.0
# 3028                 34000                       2811                   215.0
# ...                    ...                        ...                     ...
# 4909                     4                         93                     NaN
# 4911                    84                       2283                     1.0
# 4912                 32000                       1753                    43.0
# 4913                    16                          0                    13.0
# 4914                   660                       2386                    14.0
#
#       num_voted_users  num_user_for_reviews  facenumber_in_poster  \
# 0              886204                3054.0                   0.0
# 29             418214                1290.0                   0.0
# 26             793059                2528.0                   0.0
# 2973           911097                1470.0                   1.0
# 3028           281842                 515.0                   0.0
# ...               ...                   ...                   ...
# 4909               36                   1.0                   0.0
# 4911              629                   6.0                   2.0
# 4912            73839                 359.0                   1.0
# 4913               38                   3.0                   0.0
# 4914             1255                   9.0                   5.0
#
#      content_rating  aspect_ratio   net_profit
# 0             PG-13          1.78  523505847.0
# 29            PG-13          2.00  502177271.0
# 26            PG-13          2.35  458672302.0
# 2973             PG          2.35  449935665.0
# 3028             PG          1.85  424449459.0
# ...             ...           ...          ...
# 4909          PG-13           NaN          NaN
# 4911            NaN           NaN          NaN
# 4912          TV-14         16.00          NaN
# 4913            NaN           NaN          NaN
# 4914          PG-13          2.35          NaN
#
# [4916 rows x 29 columns]

# %%
# Extraer las top-10
top10_movies = df['movie_title'][0:10]

# %%
# Y finalmente imprimamos el resultado en pantalla
print('Top-10 películas más exitosas: ')
for i, movie in enumerate(top10_movies):
    print(f'{i+1} - {movie}')
# Out:
# Top-10 películas más exitosas:
# 1 - Avatar
# 2 - Jurassic World
# 3 - Titanic
# 4 - Star Wars: Episode IV - A New Hope
# 5 - E.T. the Extra-Terrestrial
# 6 - The Avengers
# 7 - The Lion King
# 8 - Star Wars: Episode I - The Phantom Menace
# 9 - The Dark Knight
# 10 - The Hunger Games
