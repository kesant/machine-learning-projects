# %% [markdown]
# # Modificando el índice de un DataFrame
#
# En la lección anterior vimos diferentes formas de ordenar un *DataFrame*.
#
# En esta lección veremos cómo modificar el índice de un *DataFrame*. En particular veremos cómo:
#
# - Definir el índice de un *DataFrame* al momento de su lectura
# - Fijar el índice de un *DataFrame* después de realizar la lectura
# - Reiniciar el índice de un *DataFrame*

# %% [markdown]
# ## 1. Definir el índice de un *DataFrame* al momento de su lectura
#
# La lectura de datos realizada hasta este momento con `read_csv` asigna un índice por defecto, es decir que los valores del índice realmente **NO** están almacenados en el archivo CSV original:

# %%
# Lectura del dataset original
import pandas as pd

df = pd.read_csv('peliculas.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %% [markdown]
# Sin embargo, en ocasiones el índice asignado por defecto por Pandas no contiene información relevante para el análisis de los datos.
#
# Muchas veces resulta relevante fijar el índice a partir de una de las columnas del set de datos original. Esto se puede hacer durante la lectura usando el parámetro `index_col`:

# %%
# Leer el dataset original y fijar index_col = 'movie_title'

df = pd.read_csv('peliculas.csv', index_col = 'movie_title')
df
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
# ...                                                            ...       ...
# Signed Sealed Delivered                                        1.0      87.0
# The Following                                                 43.0      43.0
# A Plague So Pleasant                                          13.0      76.0
# Shanghai Calling                                              14.0     100.0
# My Date with Drew                                             43.0      90.0
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
# ...                                                             ...
# Signed Sealed Delivered                                         2.0
# The Following                                                   NaN
# A Plague So Pleasant                                            0.0
# Shanghai Calling                                                0.0
# My Date with Drew                                              16.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
# ...                                                            ...
# Signed Sealed Delivered                                      318.0
# The Following                                                319.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             489.0
# My Date with Drew                                             16.0
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
# ...                                                      ...
# Signed Sealed Delivered                        Daphne Zuniga
# The Following                                  Valorie Curry
# A Plague So Pleasant                           Maxwell Moody
# Shanghai Calling                               Daniel Henney
# My Date with Drew                           Brian Herzlinger
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# ...                                                            ...
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             946.0
# My Date with Drew                                             86.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
# ...                                                 ...
# Signed Sealed Delivered                             NaN
# The Following                                       NaN
# A Plague So Pleasant                                NaN
# Shanghai Calling                                10443.0
# My Date with Drew                               85222.0
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
# ...                                                                     ...
# Signed Sealed Delivered                                        Comedy|Drama
# The Following                                  Crime|Drama|Mystery|Thriller
# A Plague So Pleasant                                  Drama|Horror|Thriller
# Shanghai Calling                                       Comedy|Drama|Romance
# My Date with Drew                                               Documentary
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                994.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
# ...                                         ...                  ...
# Signed Sealed Delivered                     ...                  6.0
# The Following                               ...                359.0
# A Plague So Pleasant                        ...                  3.0
# Shanghai Calling                            ...                  9.0
# My Date with Drew                           ...                 84.0
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                      English       UK          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
# ...                                              ...      ...            ...
# Signed Sealed Delivered                      English   Canada            NaN
# The Following                                English      USA          TV-14
# A Plague So Pleasant                         English      USA            NaN
# Shanghai Calling                             English      USA          PG-13
# My Date with Drew                            English      USA             PG
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
# ...                                                 ...        ...
# Signed Sealed Delivered                             NaN     2013.0
# The Following                                       NaN        NaN
# A Plague So Pleasant                             1400.0     2013.0
# Shanghai Calling                                    NaN     2012.0
# My Date with Drew                                1100.0     2004.0
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
# ...                                                           ...         ...
# Signed Sealed Delivered                                     470.0         7.7
# The Following                                               593.0         7.5
# A Plague So Pleasant                                          0.0         6.3
# Shanghai Calling                                            719.0         6.3
# My Date with Drew                                            23.0         6.6
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
# ...                                                 ...                  ...
# Signed Sealed Delivered                             NaN                   84
# The Following                                     16.00                32000
# A Plague So Pleasant                                NaN                   16
# Shanghai Calling                                   2.35                  660
# My Date with Drew                                  1.85                  456
#
# [4916 rows x 27 columns]

# %% [markdown]
# ## 2. Definir el índice de un *DataFrame* después de realizada la lectura
#
# Si no conocemos el dataset y hasta ahora lo estamos explorando puede ser que no sepamos con antelación cuál será la columna que tomaremos como referencia.
#
# En estos casos podemos definir el índice **DESPUÉS** de realizada la lectura:

# %%
# Leer el dataset original
df = pd.read_csv('peliculas.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %%
# Y ahora fijar el índice con el método set_index
df = df.set_index('movie_title')
df
# Out:
#                                             color      director_name  \
# movie_title
# Avatar                                      Color      James Cameron
# Pirates of the Caribbean: At World's End    Color     Gore Verbinski
# Spectre                                     Color         Sam Mendes
# The Dark Knight Rises                       Color  Christopher Nolan
# Star Wars: Episode VII - The Force Awakens    NaN        Doug Walker
# ...                                           ...                ...
# Signed Sealed Delivered                     Color        Scott Smith
# The Following                               Color                NaN
# A Plague So Pleasant                        Color   Benjamin Roberds
# Shanghai Calling                            Color        Daniel Hsia
# My Date with Drew                           Color           Jon Gunn
#
#                                             num_critic_for_reviews  duration  \
# movie_title
# Avatar                                                       723.0     178.0
# Pirates of the Caribbean: At World's End                     302.0     169.0
# Spectre                                                      602.0     148.0
# The Dark Knight Rises                                        813.0     164.0
# Star Wars: Episode VII - The Force Awakens                     NaN       NaN
# ...                                                            ...       ...
# Signed Sealed Delivered                                        1.0      87.0
# The Following                                                 43.0      43.0
# A Plague So Pleasant                                          13.0      76.0
# Shanghai Calling                                              14.0     100.0
# My Date with Drew                                             43.0      90.0
#
#                                             director_facebook_likes  \
# movie_title
# Avatar                                                          0.0
# Pirates of the Caribbean: At World's End                      563.0
# Spectre                                                         0.0
# The Dark Knight Rises                                       22000.0
# Star Wars: Episode VII - The Force Awakens                    131.0
# ...                                                             ...
# Signed Sealed Delivered                                         2.0
# The Following                                                   NaN
# A Plague So Pleasant                                            0.0
# Shanghai Calling                                                0.0
# My Date with Drew                                              16.0
#
#                                             actor_3_facebook_likes  \
# movie_title
# Avatar                                                       855.0
# Pirates of the Caribbean: At World's End                    1000.0
# Spectre                                                      161.0
# The Dark Knight Rises                                      23000.0
# Star Wars: Episode VII - The Force Awakens                     NaN
# ...                                                            ...
# Signed Sealed Delivered                                      318.0
# The Following                                                319.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             489.0
# My Date with Drew                                             16.0
#
#                                                 actor_2_name  \
# movie_title
# Avatar                                      Joel David Moore
# Pirates of the Caribbean: At World's End       Orlando Bloom
# Spectre                                         Rory Kinnear
# The Dark Knight Rises                         Christian Bale
# Star Wars: Episode VII - The Force Awakens        Rob Walker
# ...                                                      ...
# Signed Sealed Delivered                        Daphne Zuniga
# The Following                                  Valorie Curry
# A Plague So Pleasant                           Maxwell Moody
# Shanghai Calling                               Daniel Henney
# My Date with Drew                           Brian Herzlinger
#
#                                             actor_1_facebook_likes  \
# movie_title
# Avatar                                                      1000.0
# Pirates of the Caribbean: At World's End                   40000.0
# Spectre                                                    11000.0
# The Dark Knight Rises                                      27000.0
# Star Wars: Episode VII - The Force Awakens                   131.0
# ...                                                            ...
# Signed Sealed Delivered                                      637.0
# The Following                                                841.0
# A Plague So Pleasant                                           0.0
# Shanghai Calling                                             946.0
# My Date with Drew                                             86.0
#
#                                                   gross  \
# movie_title
# Avatar                                      760505847.0
# Pirates of the Caribbean: At World's End    309404152.0
# Spectre                                     200074175.0
# The Dark Knight Rises                       448130642.0
# Star Wars: Episode VII - The Force Awakens          NaN
# ...                                                 ...
# Signed Sealed Delivered                             NaN
# The Following                                       NaN
# A Plague So Pleasant                                NaN
# Shanghai Calling                                10443.0
# My Date with Drew                               85222.0
#
#                                                                      genres  \
# movie_title
# Avatar                                      Action|Adventure|Fantasy|Sci-Fi
# Pirates of the Caribbean: At World's End           Action|Adventure|Fantasy
# Spectre                                           Action|Adventure|Thriller
# The Dark Knight Rises                                       Action|Thriller
# Star Wars: Episode VII - The Force Awakens                      Documentary
# ...                                                                     ...
# Signed Sealed Delivered                                        Comedy|Drama
# The Following                                  Crime|Drama|Mystery|Thriller
# A Plague So Pleasant                                  Drama|Horror|Thriller
# Shanghai Calling                                       Comedy|Drama|Romance
# My Date with Drew                                               Documentary
#
#                                             ... num_user_for_reviews  \
# movie_title                                 ...
# Avatar                                      ...               3054.0
# Pirates of the Caribbean: At World's End    ...               1238.0
# Spectre                                     ...                994.0
# The Dark Knight Rises                       ...               2701.0
# Star Wars: Episode VII - The Force Awakens  ...                  NaN
# ...                                         ...                  ...
# Signed Sealed Delivered                     ...                  6.0
# The Following                               ...                359.0
# A Plague So Pleasant                        ...                  3.0
# Shanghai Calling                            ...                  9.0
# My Date with Drew                           ...                 84.0
#
#                                             language  country content_rating  \
# movie_title
# Avatar                                       English      USA          PG-13
# Pirates of the Caribbean: At World's End     English      USA          PG-13
# Spectre                                      English       UK          PG-13
# The Dark Knight Rises                        English      USA          PG-13
# Star Wars: Episode VII - The Force Awakens       NaN      NaN            NaN
# ...                                              ...      ...            ...
# Signed Sealed Delivered                      English   Canada            NaN
# The Following                                English      USA          TV-14
# A Plague So Pleasant                         English      USA            NaN
# Shanghai Calling                             English      USA          PG-13
# My Date with Drew                            English      USA             PG
#
#                                                  budget title_year  \
# movie_title
# Avatar                                      237000000.0     2009.0
# Pirates of the Caribbean: At World's End    300000000.0     2007.0
# Spectre                                     245000000.0     2015.0
# The Dark Knight Rises                       250000000.0     2012.0
# Star Wars: Episode VII - The Force Awakens          NaN        NaN
# ...                                                 ...        ...
# Signed Sealed Delivered                             NaN     2013.0
# The Following                                       NaN        NaN
# A Plague So Pleasant                             1400.0     2013.0
# Shanghai Calling                                    NaN     2012.0
# My Date with Drew                                1100.0     2004.0
#
#                                            actor_2_facebook_likes  imdb_score  \
# movie_title
# Avatar                                                      936.0         7.9
# Pirates of the Caribbean: At World's End                   5000.0         7.1
# Spectre                                                     393.0         6.8
# The Dark Knight Rises                                     23000.0         8.5
# Star Wars: Episode VII - The Force Awakens                   12.0         7.1
# ...                                                           ...         ...
# Signed Sealed Delivered                                     470.0         7.7
# The Following                                               593.0         7.5
# A Plague So Pleasant                                          0.0         6.3
# Shanghai Calling                                            719.0         6.3
# My Date with Drew                                            23.0         6.6
#
#                                            aspect_ratio movie_facebook_likes
# movie_title
# Avatar                                             1.78                33000
# Pirates of the Caribbean: At World's End           2.35                    0
# Spectre                                            2.35                85000
# The Dark Knight Rises                              2.35               164000
# Star Wars: Episode VII - The Force Awakens          NaN                    0
# ...                                                 ...                  ...
# Signed Sealed Delivered                             NaN                   84
# The Following                                     16.00                32000
# A Plague So Pleasant                                NaN                   16
# Shanghai Calling                                   2.35                  660
# My Date with Drew                                  1.85                  456
#
# [4916 rows x 27 columns]

# %% [markdown]
# ## 3. Reiniciar el índice
#
# En ocasiones, cuando encadenamos varias operaciones sobre un *DataFrame* el índice sufre modificaciones consecutivas y al final de dichas operaciones resulta "inservible".
#
# En estos casos lo mejor es reiniciar el índice al final de todas estas operaciones, usando el método `reset_index`:

# %%
# Leamos el dataset original con el índice asignado por defecto por Pandas
df = pd.read_csv('peliculas.csv')
df
# Out:
#       color      director_name  num_critic_for_reviews  duration  \
# 0     Color      James Cameron                   723.0     178.0
# 1     Color     Gore Verbinski                   302.0     169.0
# 2     Color         Sam Mendes                   602.0     148.0
# 3     Color  Christopher Nolan                   813.0     164.0
# 4       NaN        Doug Walker                     NaN       NaN
# ...     ...                ...                     ...       ...
# 4911  Color        Scott Smith                     1.0      87.0
# 4912  Color                NaN                    43.0      43.0
# 4913  Color   Benjamin Roberds                    13.0      76.0
# 4914  Color        Daniel Hsia                    14.0     100.0
# 4915  Color           Jon Gunn                    43.0      90.0
#
#       director_facebook_likes  actor_3_facebook_likes      actor_2_name  \
# 0                         0.0                   855.0  Joel David Moore
# 1                       563.0                  1000.0     Orlando Bloom
# 2                         0.0                   161.0      Rory Kinnear
# 3                     22000.0                 23000.0    Christian Bale
# 4                       131.0                     NaN        Rob Walker
# ...                       ...                     ...               ...
# 4911                      2.0                   318.0     Daphne Zuniga
# 4912                      NaN                   319.0     Valorie Curry
# 4913                      0.0                     0.0     Maxwell Moody
# 4914                      0.0                   489.0     Daniel Henney
# 4915                     16.0                    16.0  Brian Herzlinger
#
#       actor_1_facebook_likes        gross                           genres  \
# 0                     1000.0  760505847.0  Action|Adventure|Fantasy|Sci-Fi
# 1                    40000.0  309404152.0         Action|Adventure|Fantasy
# 2                    11000.0  200074175.0        Action|Adventure|Thriller
# 3                    27000.0  448130642.0                  Action|Thriller
# 4                      131.0          NaN                      Documentary
# ...                      ...          ...                              ...
# 4911                   637.0          NaN                     Comedy|Drama
# 4912                   841.0          NaN     Crime|Drama|Mystery|Thriller
# 4913                     0.0          NaN            Drama|Horror|Thriller
# 4914                   946.0      10443.0             Comedy|Drama|Romance
# 4915                    86.0      85222.0                      Documentary
#
#       ... num_user_for_reviews language  country  content_rating       budget  \
# 0     ...               3054.0  English      USA           PG-13  237000000.0
# 1     ...               1238.0  English      USA           PG-13  300000000.0
# 2     ...                994.0  English       UK           PG-13  245000000.0
# 3     ...               2701.0  English      USA           PG-13  250000000.0
# 4     ...                  NaN      NaN      NaN             NaN          NaN
# ...   ...                  ...      ...      ...             ...          ...
# 4911  ...                  6.0  English   Canada             NaN          NaN
# 4912  ...                359.0  English      USA           TV-14          NaN
# 4913  ...                  3.0  English      USA             NaN       1400.0
# 4914  ...                  9.0  English      USA           PG-13          NaN
# 4915  ...                 84.0  English      USA              PG       1100.0
#
#       title_year actor_2_facebook_likes imdb_score  aspect_ratio  \
# 0         2009.0                  936.0        7.9          1.78
# 1         2007.0                 5000.0        7.1          2.35
# 2         2015.0                  393.0        6.8          2.35
# 3         2012.0                23000.0        8.5          2.35
# 4            NaN                   12.0        7.1           NaN
# ...          ...                    ...        ...           ...
# 4911      2013.0                  470.0        7.7           NaN
# 4912         NaN                  593.0        7.5         16.00
# 4913      2013.0                    0.0        6.3           NaN
# 4914      2012.0                  719.0        6.3          2.35
# 4915      2004.0                   23.0        6.6          1.85
#
#      movie_facebook_likes
# 0                   33000
# 1                       0
# 2                   85000
# 3                  164000
# 4                       0
# ...                   ...
# 4911                   84
# 4912                32000
# 4913                   16
# 4914                  660
# 4915                  456
#
# [4916 rows x 28 columns]

# %%
# Ahora organicemos las filas del *DataFrame* usando las columnas "gross" y 
# "budget" como referencia. Observemos lo que ocurre con el índice
df = df.sort_values(['gross', 'budget'])
df
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 3272  Color    Ekachai Uekrongtham                    66.0      96.0
# 4500  Color           Frank Whaley                     9.0      96.0
# 4499  Color  Brian Trenchard-Smith                     8.0      88.0
# 3485  Color         Ian Fitzgibbon                    54.0      88.0
# 4795  Color            Ricki Stern                    11.0     106.0
# ...     ...                    ...                     ...       ...
# 4892  Color          Marcus Nispel                    43.0      91.0
# 4903  Color           Tadeo Garcia                     NaN      84.0
# 4905  Color        Ash Baron-Cohen                    10.0      98.0
# 4911  Color            Scott Smith                     1.0      87.0
# 4912  Color                    NaN                    43.0      43.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 3272                      3.0                   305.0         Mike Dopud
# 4500                    436.0                     4.0       Frank Whaley
# 4499                     53.0                   176.0   Mariel Hemingway
# 3485                     11.0                   415.0      Brendan Coyle
# 4795                     15.0                     0.0   Evelyn Jefferson
# ...                       ...                     ...                ...
# 4892                    158.0                   265.0    Brittany Curran
# 4903                      5.0                    12.0     Michael Cortez
# 4905                      3.0                   152.0  Stanley B. Herman
# 4911                      2.0                   318.0      Daphne Zuniga
# 4912                      NaN                   319.0      Valorie Curry
#
#       actor_1_facebook_likes   gross  \
# 3272                  2000.0   162.0
# 4500                   474.0   703.0
# 4499                   563.0   721.0
# 3485                  1000.0   828.0
# 4795                     2.0  1111.0
# ...                      ...     ...
# 4892                   630.0     NaN
# 4903                    21.0     NaN
# 4905                   789.0     NaN
# 4911                   637.0     NaN
# 4912                   841.0     NaN
#
#                                           genres  ... num_user_for_reviews  \
# 3272                       Action|Crime|Thriller  ...                 38.0
# 4500                                Comedy|Drama  ...                 21.0
# 4499                                Action|Drama  ...                 12.0
# 3485  Action|Comedy|Crime|Drama|Romance|Thriller  ...                 31.0
# 4795                           Crime|Documentary  ...                 10.0
# ...                                          ...  ...                  ...
# 4892                     Horror|Mystery|Thriller  ...                 33.0
# 4903                                       Drama  ...                  3.0
# 4905                                 Crime|Drama  ...                 14.0
# 4911                                Comedy|Drama  ...                  6.0
# 4912                Crime|Drama|Mystery|Thriller  ...                359.0
#
#      language   country  content_rating     budget  title_year  \
# 3272  English  Thailand               R  9000000.0      2014.0
# 4500  English       USA               R  1500000.0      2001.0
# 4499  English   Germany               R  1000000.0      2006.0
# 3485  English   Ireland               R        NaN      2009.0
# 4795  English       USA           PG-13   200000.0      2006.0
# ...       ...       ...             ...        ...         ...
# 4892  English       USA               R        NaN      2015.0
# 4903  English       USA             NaN        NaN      2004.0
# 4905  English       USA             NaN        NaN      1995.0
# 4911  English    Canada             NaN        NaN      2013.0
# 4912  English       USA           TV-14        NaN         NaN
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 3272                  368.0        5.7          2.35                    0
# 4500                  436.0        5.4          1.85                   47
# 4499                  288.0        4.1          1.85                   42
# 3485                  418.0        6.4          2.35                  663
# 4795                    0.0        7.7          1.66                  246
# ...                     ...        ...           ...                  ...
# 4892                  512.0        4.6          1.85                    0
# 4903                   20.0        6.1           NaN                   22
# 4905                  194.0        6.4           NaN                   20
# 4911                  470.0        7.7           NaN                   84
# 4912                  593.0        7.5         16.00                32000
#
# [4916 rows x 28 columns]

# %%
# En este punto podemos reiniciar el índice para que los valores sean consecutivos, comenzando en 0:
df = df.reset_index()
df
# Out:
#       index  color          director_name  num_critic_for_reviews  duration  \
# 0      3272  Color    Ekachai Uekrongtham                    66.0      96.0
# 1      4500  Color           Frank Whaley                     9.0      96.0
# 2      4499  Color  Brian Trenchard-Smith                     8.0      88.0
# 3      3485  Color         Ian Fitzgibbon                    54.0      88.0
# 4      4795  Color            Ricki Stern                    11.0     106.0
# ...     ...    ...                    ...                     ...       ...
# 4911   4892  Color          Marcus Nispel                    43.0      91.0
# 4912   4903  Color           Tadeo Garcia                     NaN      84.0
# 4913   4905  Color        Ash Baron-Cohen                    10.0      98.0
# 4914   4911  Color            Scott Smith                     1.0      87.0
# 4915   4912  Color                    NaN                    43.0      43.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         3.0                   305.0         Mike Dopud
# 1                       436.0                     4.0       Frank Whaley
# 2                        53.0                   176.0   Mariel Hemingway
# 3                        11.0                   415.0      Brendan Coyle
# 4                        15.0                     0.0   Evelyn Jefferson
# ...                       ...                     ...                ...
# 4911                    158.0                   265.0    Brittany Curran
# 4912                      5.0                    12.0     Michael Cortez
# 4913                      3.0                   152.0  Stanley B. Herman
# 4914                      2.0                   318.0      Daphne Zuniga
# 4915                      NaN                   319.0      Valorie Curry
#
#       actor_1_facebook_likes   gross  ... num_user_for_reviews language  \
# 0                     2000.0   162.0  ...                 38.0  English
# 1                      474.0   703.0  ...                 21.0  English
# 2                      563.0   721.0  ...                 12.0  English
# 3                     1000.0   828.0  ...                 31.0  English
# 4                        2.0  1111.0  ...                 10.0  English
# ...                      ...     ...  ...                  ...      ...
# 4911                   630.0     NaN  ...                 33.0  English
# 4912                    21.0     NaN  ...                  3.0  English
# 4913                   789.0     NaN  ...                 14.0  English
# 4914                   637.0     NaN  ...                  6.0  English
# 4915                   841.0     NaN  ...                359.0  English
#
#        country  content_rating     budget title_year  actor_2_facebook_likes  \
# 0     Thailand               R  9000000.0     2014.0                   368.0
# 1          USA               R  1500000.0     2001.0                   436.0
# 2      Germany               R  1000000.0     2006.0                   288.0
# 3      Ireland               R        NaN     2009.0                   418.0
# 4          USA           PG-13   200000.0     2006.0                     0.0
# ...        ...             ...        ...        ...                     ...
# 4911       USA               R        NaN     2015.0                   512.0
# 4912       USA             NaN        NaN     2004.0                    20.0
# 4913       USA             NaN        NaN     1995.0                   194.0
# 4914    Canada             NaN        NaN     2013.0                   470.0
# 4915       USA           TV-14        NaN        NaN                   593.0
#
#      imdb_score aspect_ratio  movie_facebook_likes
# 0           5.7         2.35                     0
# 1           5.4         1.85                    47
# 2           4.1         1.85                    42
# 3           6.4         2.35                   663
# 4           7.7         1.66                   246
# ...         ...          ...                   ...
# 4911        4.6         1.85                     0
# 4912        6.1          NaN                    22
# 4913        6.4          NaN                    20
# 4914        7.7          NaN                    84
# 4915        7.5        16.00                 32000
#
# [4916 rows x 29 columns]

# %% [markdown]
# Lo anterior funciona pero sólo en parte, pues el uso de `reset_index` ha convertido el índice anterior en una nueva columna del *DataFrame* (la columna "index").
#
# Para evitar esto debemos usar el parámetro `drop = True` al momento de llamar `reset_index`:

# %%
# Lectura del dataset original
df = pd.read_csv('peliculas.csv')

# Ordenar usando "gross" y "budget" como referencia
df = df.sort_values(['gross', 'budget'])

# Reiniciar índice usando drop = True
df = df.reset_index(drop=True)

df
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 0     Color    Ekachai Uekrongtham                    66.0      96.0
# 1     Color           Frank Whaley                     9.0      96.0
# 2     Color  Brian Trenchard-Smith                     8.0      88.0
# 3     Color         Ian Fitzgibbon                    54.0      88.0
# 4     Color            Ricki Stern                    11.0     106.0
# ...     ...                    ...                     ...       ...
# 4911  Color          Marcus Nispel                    43.0      91.0
# 4912  Color           Tadeo Garcia                     NaN      84.0
# 4913  Color        Ash Baron-Cohen                    10.0      98.0
# 4914  Color            Scott Smith                     1.0      87.0
# 4915  Color                    NaN                    43.0      43.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         3.0                   305.0         Mike Dopud
# 1                       436.0                     4.0       Frank Whaley
# 2                        53.0                   176.0   Mariel Hemingway
# 3                        11.0                   415.0      Brendan Coyle
# 4                        15.0                     0.0   Evelyn Jefferson
# ...                       ...                     ...                ...
# 4911                    158.0                   265.0    Brittany Curran
# 4912                      5.0                    12.0     Michael Cortez
# 4913                      3.0                   152.0  Stanley B. Herman
# 4914                      2.0                   318.0      Daphne Zuniga
# 4915                      NaN                   319.0      Valorie Curry
#
#       actor_1_facebook_likes   gross  \
# 0                     2000.0   162.0
# 1                      474.0   703.0
# 2                      563.0   721.0
# 3                     1000.0   828.0
# 4                        2.0  1111.0
# ...                      ...     ...
# 4911                   630.0     NaN
# 4912                    21.0     NaN
# 4913                   789.0     NaN
# 4914                   637.0     NaN
# 4915                   841.0     NaN
#
#                                           genres  ... num_user_for_reviews  \
# 0                          Action|Crime|Thriller  ...                 38.0
# 1                                   Comedy|Drama  ...                 21.0
# 2                                   Action|Drama  ...                 12.0
# 3     Action|Comedy|Crime|Drama|Romance|Thriller  ...                 31.0
# 4                              Crime|Documentary  ...                 10.0
# ...                                          ...  ...                  ...
# 4911                     Horror|Mystery|Thriller  ...                 33.0
# 4912                                       Drama  ...                  3.0
# 4913                                 Crime|Drama  ...                 14.0
# 4914                                Comedy|Drama  ...                  6.0
# 4915                Crime|Drama|Mystery|Thriller  ...                359.0
#
#      language   country  content_rating     budget  title_year  \
# 0     English  Thailand               R  9000000.0      2014.0
# 1     English       USA               R  1500000.0      2001.0
# 2     English   Germany               R  1000000.0      2006.0
# 3     English   Ireland               R        NaN      2009.0
# 4     English       USA           PG-13   200000.0      2006.0
# ...       ...       ...             ...        ...         ...
# 4911  English       USA               R        NaN      2015.0
# 4912  English       USA             NaN        NaN      2004.0
# 4913  English       USA             NaN        NaN      1995.0
# 4914  English    Canada             NaN        NaN      2013.0
# 4915  English       USA           TV-14        NaN         NaN
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 0                     368.0        5.7          2.35                    0
# 1                     436.0        5.4          1.85                   47
# 2                     288.0        4.1          1.85                   42
# 3                     418.0        6.4          2.35                  663
# 4                       0.0        7.7          1.66                  246
# ...                     ...        ...           ...                  ...
# 4911                  512.0        4.6          1.85                    0
# 4912                   20.0        6.1           NaN                   22
# 4913                  194.0        6.4           NaN                   20
# 4914                  470.0        7.7           NaN                   84
# 4915                  593.0        7.5         16.00                32000
#
# [4916 rows x 28 columns]

# %%
# Y recordemos que podemos encadenar las operaciones anteriores para escribir todo en una sola
# línea de código

# Lectura
df = pd.read_csv('peliculas.csv')

# Encadenar operaciones: ordenar y reiniciar índice
df = df.sort_values(['gross', 'budget']).reset_index(drop = True)
df
# Out:
#       color          director_name  num_critic_for_reviews  duration  \
# 0     Color    Ekachai Uekrongtham                    66.0      96.0
# 1     Color           Frank Whaley                     9.0      96.0
# 2     Color  Brian Trenchard-Smith                     8.0      88.0
# 3     Color         Ian Fitzgibbon                    54.0      88.0
# 4     Color            Ricki Stern                    11.0     106.0
# ...     ...                    ...                     ...       ...
# 4911  Color          Marcus Nispel                    43.0      91.0
# 4912  Color           Tadeo Garcia                     NaN      84.0
# 4913  Color        Ash Baron-Cohen                    10.0      98.0
# 4914  Color            Scott Smith                     1.0      87.0
# 4915  Color                    NaN                    43.0      43.0
#
#       director_facebook_likes  actor_3_facebook_likes       actor_2_name  \
# 0                         3.0                   305.0         Mike Dopud
# 1                       436.0                     4.0       Frank Whaley
# 2                        53.0                   176.0   Mariel Hemingway
# 3                        11.0                   415.0      Brendan Coyle
# 4                        15.0                     0.0   Evelyn Jefferson
# ...                       ...                     ...                ...
# 4911                    158.0                   265.0    Brittany Curran
# 4912                      5.0                    12.0     Michael Cortez
# 4913                      3.0                   152.0  Stanley B. Herman
# 4914                      2.0                   318.0      Daphne Zuniga
# 4915                      NaN                   319.0      Valorie Curry
#
#       actor_1_facebook_likes   gross  \
# 0                     2000.0   162.0
# 1                      474.0   703.0
# 2                      563.0   721.0
# 3                     1000.0   828.0
# 4                        2.0  1111.0
# ...                      ...     ...
# 4911                   630.0     NaN
# 4912                    21.0     NaN
# 4913                   789.0     NaN
# 4914                   637.0     NaN
# 4915                   841.0     NaN
#
#                                           genres  ... num_user_for_reviews  \
# 0                          Action|Crime|Thriller  ...                 38.0
# 1                                   Comedy|Drama  ...                 21.0
# 2                                   Action|Drama  ...                 12.0
# 3     Action|Comedy|Crime|Drama|Romance|Thriller  ...                 31.0
# 4                              Crime|Documentary  ...                 10.0
# ...                                          ...  ...                  ...
# 4911                     Horror|Mystery|Thriller  ...                 33.0
# 4912                                       Drama  ...                  3.0
# 4913                                 Crime|Drama  ...                 14.0
# 4914                                Comedy|Drama  ...                  6.0
# 4915                Crime|Drama|Mystery|Thriller  ...                359.0
#
#      language   country  content_rating     budget  title_year  \
# 0     English  Thailand               R  9000000.0      2014.0
# 1     English       USA               R  1500000.0      2001.0
# 2     English   Germany               R  1000000.0      2006.0
# 3     English   Ireland               R        NaN      2009.0
# 4     English       USA           PG-13   200000.0      2006.0
# ...       ...       ...             ...        ...         ...
# 4911  English       USA               R        NaN      2015.0
# 4912  English       USA             NaN        NaN      2004.0
# 4913  English       USA             NaN        NaN      1995.0
# 4914  English    Canada             NaN        NaN      2013.0
# 4915  English       USA           TV-14        NaN         NaN
#
#      actor_2_facebook_likes imdb_score  aspect_ratio movie_facebook_likes
# 0                     368.0        5.7          2.35                    0
# 1                     436.0        5.4          1.85                   47
# 2                     288.0        4.1          1.85                   42
# 3                     418.0        6.4          2.35                  663
# 4                       0.0        7.7          1.66                  246
# ...                     ...        ...           ...                  ...
# 4911                  512.0        4.6          1.85                    0
# 4912                   20.0        6.1           NaN                   22
# 4913                  194.0        6.4           NaN                   20
# 4914                  470.0        7.7           NaN                   84
# 4915                  593.0        7.5         16.00                32000
#
# [4916 rows x 28 columns]

# %% [markdown]
# ## 4. Ejemplo práctico
#
# Usando las ideas anteriores, y algo de herramientas de programación de Python, podemos indexar el *DataFrame* de manera más sofisticada.
#
# Por ejemplo, supongamos que nos interesa codificar en el índice la siguiente información:
#
# - Primer apellido del Director
# - Año de lanzamiento
#
# Así por ejemplo, si el director es "Gore Verbinski" y el año de lanzamiento es 2007, entonces el índice debería ser "Verbinski-2007".
#
# Veamos cómo lograr esto:

# %%
# Primero creemos una serie que contenga el apellido de cada director
# NOTA: ESTAMOS ASUMIENDO QUE CADA DIRECTOR ESTÁ ESCRITO COMO NOMBRE + APELLIDO
serie_apellidos = df['director_name'].str.split().str[1]
serie_apellidos
# Out:
# 0           Uekrongtham
# 1                Whaley
# 2       Trenchard-Smith
# 3            Fitzgibbon
# 4                 Stern
#              ...
# 4911             Nispel
# 4912             Garcia
# 4913        Baron-Cohen
# 4914              Smith
# 4915                NaN
# Name: director_name, Length: 4916, dtype: object

# %%
# Y extraigamos la serie con el año de lanzamiento
serie_years = df['title_year'].astype('str')
serie_years
# Out:
# 0       2014.0
# 1       2001.0
# 2       2006.0
# 3       2009.0
# 4       2006.0
#          ...
# 4911    2015.0
# 4912    2004.0
# 4913    1995.0
# 4914    2013.0
# 4915       nan
# Name: title_year, Length: 4916, dtype: object

# %% [markdown]
# Vemos que los años originalmente están en formato *float* así que al convertirlos a *str* se agregan decimales. Para evitar esto podemos usar una conversión a *int* antes de la conversión a *str*:

# %%
# Conversión a "int" antes de la conversión a "str"
serie_years = df['title_year'].astype('int').astype('str')
serie_years
# Out:
# ---------------------------------------------------------------------------
# IntCastingNaNError                        Traceback (most recent call last)
# Cell In[12], line 2
#       1 # Conversión a "int" antes de la conversión a "str"
# ----> 2 serie_years = df['title_year'].astype('int').astype('str')
#       3 serie_years
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\generic.py:6643, in NDFrame.astype(self, dtype, copy, errors)
#    6637     results = [
#    6638         ser.astype(dtype, copy=copy, errors=errors) for _, ser in self.items()
#    6639     ]
#    6641 else:
#    6642     # else, only a single dtype is given
# -> 6643     new_data = self._mgr.astype(dtype=dtype, copy=copy, errors=errors)
#    6644     res = self._constructor_from_mgr(new_data, axes=new_data.axes)
#    6645     return res.__finalize__(self, method="astype")
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\internals\managers.py:430, in BaseBlockManager.astype(self, dtype, copy, errors)
#     427 elif using_copy_on_write():
#     428     copy = False
# --> 430 return self.apply(
#     431     "astype",
#     432     dtype=dtype,
#     433     copy=copy,
#     434     errors=errors,
#     435     using_cow=using_copy_on_write(),
#     436 )
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\internals\managers.py:363, in BaseBlockManager.apply(self, f, align_keys, **kwargs)
#     361         applied = b.apply(f, **kwargs)
#     362     else:
# --> 363         applied = getattr(b, f)(**kwargs)
#     364     result_blocks = extend_blocks(applied, result_blocks)
#     366 out = type(self).from_blocks(result_blocks, self.axes)
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\internals\blocks.py:758, in Block.astype(self, dtype, copy, errors, using_cow, squeeze)
#     755         raise ValueError("Can not squeeze with more than one column.")
#     756     values = values[0, :]  # type: ignore[call-overload]
# --> 758 new_values = astype_array_safe(values, dtype, copy=copy, errors=errors)
#     760 new_values = maybe_coerce_values(new_values)
#     762 refs = None
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\dtypes\astype.py:237, in astype_array_safe(values, dtype, copy, errors)
#     234     dtype = dtype.numpy_dtype
#     236 try:
# --> 237     new_values = astype_array(values, dtype, copy=copy)
#     238 except (ValueError, TypeError):
#     239     # e.g. _astype_nansafe can fail on object-dtype of strings
#     240     #  trying to convert to float
#     241     if errors == "ignore":
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\dtypes\astype.py:182, in astype_array(values, dtype, copy)
#     179     values = values.astype(dtype, copy=copy)
#     181 else:
# --> 182     values = _astype_nansafe(values, dtype, copy=copy)
#     184 # in pandas we don't store numpy str dtypes, so convert to object
#     185 if isinstance(dtype, np.dtype) and issubclass(values.dtype.type, str):
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\dtypes\astype.py:101, in _astype_nansafe(arr, dtype, copy, skipna)
#      96     return lib.ensure_string_array(
#      97         arr, skipna=skipna, convert_na_value=False
#      98     ).reshape(shape)
#     100 elif np.issubdtype(arr.dtype, np.floating) and dtype.kind in "iu":
# --> 101     return _astype_float_to_int_nansafe(arr, dtype, copy)
#     103 elif arr.dtype == object:
#     104     # if we have a datetime/timedelta array of objects
#     105     # then coerce to datetime64[ns] and use DatetimeArray.astype
#     107     if lib.is_np_dtype(dtype, "M"):
#
# File c:\Users\ASUS TUF\.conda\envs\proyecto_machin_learning\Lib\site-packages\pandas\core\dtypes\astype.py:145, in _astype_float_to_int_nansafe(values, dtype, copy)
#     141 """
#     142 astype with a check preventing converting NaN to an meaningless integer value.
#     143 """
#     144 if not np.isfinite(values).all():
# --> 145     raise IntCastingNaNError(
#     146         "Cannot convert non-finite values (NA or inf) to integer"
#     147     )
#     148 if dtype.kind == "u":
#     149     # GH#45151
#     150     if not (values >= 0).all():
#
# IntCastingNaNError: Cannot convert non-finite values (NA or inf) to integer

# %% [markdown]
# Pero en este caso ocurre un error que nos indica que en la serie hay datos tipo *NaN* que no se pueden convertir a enteros.
#
# Así que antes de todo esto debemos eliminar los *NaN* del *DataFrame*:

# %%
# Remover NaN
df = df.dropna()

# Serie con los apellidos
serie_apellidos = df['director_name'].str.split().str[1]

# Y ahora sí la serie con los años (entero y luego string):
serie_years = df['title_year'].astype('int').astype('str')
serie_years
# Out:
# 0       2014
# 1       2001
# 2       2006
# 4       2006
# 5       2012
#         ...
# 4049    2008
# 4050    2012
# 4051    2015
# 4052    1997
# 4053    2009
# Name: title_year, Length: 3654, dtype: object

# %% [markdown]
# ¡Perfecto! Ahora unamos las dos series agregando un guión en la mitad:

# %%
indice = serie_apellidos + '-' + serie_years
indice
# Out:
# 0           Uekrongtham-2014
# 1                Whaley-2001
# 2       Trenchard-Smith-2006
# 4                 Stern-2006
# 5                 Craig-2012
#                 ...
# 4049              Nolan-2008
# 4050             Whedon-2012
# 4051          Trevorrow-2015
# 4052            Cameron-1997
# 4053            Cameron-2009
# Length: 3654, dtype: object

# %%
# Y finalmente fijemos esta serie como nuevo índice del DataFrame
df = df.set_index(indice)
df
# Out:
#                       color          director_name  num_critic_for_reviews  \
# Uekrongtham-2014      Color    Ekachai Uekrongtham                    66.0
# Whaley-2001           Color           Frank Whaley                     9.0
# Trenchard-Smith-2006  Color  Brian Trenchard-Smith                     8.0
# Stern-2006            Color            Ricki Stern                    11.0
# Craig-2012            Color        Alex Craig Mann                    29.0
# ...                     ...                    ...                     ...
# Nolan-2008            Color      Christopher Nolan                   645.0
# Whedon-2012           Color            Joss Whedon                   703.0
# Trevorrow-2015        Color        Colin Trevorrow                   644.0
# Cameron-1997          Color          James Cameron                   315.0
# Cameron-2009          Color          James Cameron                   723.0
#
#                       duration  director_facebook_likes  \
# Uekrongtham-2014          96.0                      3.0
# Whaley-2001               96.0                    436.0
# Trenchard-Smith-2006      88.0                     53.0
# Stern-2006               106.0                     15.0
# Craig-2012                87.0                     38.0
# ...                        ...                      ...
# Nolan-2008               152.0                  22000.0
# Whedon-2012              173.0                      0.0
# Trevorrow-2015           124.0                    365.0
# Cameron-1997             194.0                      0.0
# Cameron-2009             178.0                      0.0
#
#                       actor_3_facebook_likes       actor_2_name  \
# Uekrongtham-2014                       305.0         Mike Dopud
# Whaley-2001                              4.0       Frank Whaley
# Trenchard-Smith-2006                   176.0   Mariel Hemingway
# Stern-2006                               0.0   Evelyn Jefferson
# Craig-2012                             445.0   Christa B. Allen
# ...                                      ...                ...
# Nolan-2008                           11000.0       Heath Ledger
# Whedon-2012                          19000.0  Robert Downey Jr.
# Trevorrow-2015                        1000.0         Judy Greer
# Cameron-1997                           794.0       Kate Winslet
# Cameron-2009                           855.0   Joel David Moore
#
#                       actor_1_facebook_likes        gross  \
# Uekrongtham-2014                      2000.0        162.0
# Whaley-2001                            474.0        703.0
# Trenchard-Smith-2006                   563.0        721.0
# Stern-2006                               2.0       1111.0
# Craig-2012                             552.0       1332.0
# ...                                      ...          ...
# Nolan-2008                           23000.0  533316061.0
# Whedon-2012                          26000.0  623279547.0
# Trevorrow-2015                        3000.0  652177271.0
# Cameron-1997                         29000.0  658672302.0
# Cameron-2009                          1000.0  760505847.0
#
#                                                 genres  ...  \
# Uekrongtham-2014                 Action|Crime|Thriller  ...
# Whaley-2001                               Comedy|Drama  ...
# Trenchard-Smith-2006                      Action|Drama  ...
# Stern-2006                           Crime|Documentary  ...
# Craig-2012                               Comedy|Horror  ...
# ...                                                ...  ...
# Nolan-2008                 Action|Crime|Drama|Thriller  ...
# Whedon-2012                    Action|Adventure|Sci-Fi  ...
# Trevorrow-2015        Action|Adventure|Sci-Fi|Thriller  ...
# Cameron-1997                             Drama|Romance  ...
# Cameron-2009           Action|Adventure|Fantasy|Sci-Fi  ...
#
#                      num_user_for_reviews language   country  content_rating  \
# Uekrongtham-2014                     38.0  English  Thailand               R
# Whaley-2001                          21.0  English       USA               R
# Trenchard-Smith-2006                 12.0  English   Germany               R
# Stern-2006                           10.0  English       USA           PG-13
# Craig-2012                           20.0  English       USA       Not Rated
# ...                                   ...      ...       ...             ...
# Nolan-2008                         4667.0  English       USA           PG-13
# Whedon-2012                        1722.0  English       USA           PG-13
# Trevorrow-2015                     1290.0  English       USA           PG-13
# Cameron-1997                       2528.0  English       USA           PG-13
# Cameron-2009                       3054.0  English       USA           PG-13
#
#                            budget  title_year actor_2_facebook_likes  \
# Uekrongtham-2014        9000000.0      2014.0                  368.0
# Whaley-2001             1500000.0      2001.0                  436.0
# Trenchard-Smith-2006    1000000.0      2006.0                  288.0
# Stern-2006               200000.0      2006.0                    0.0
# Craig-2012               500000.0      2012.0                  533.0
# ...                           ...         ...                    ...
# Nolan-2008            185000000.0      2008.0                13000.0
# Whedon-2012           220000000.0      2012.0                21000.0
# Trevorrow-2015        150000000.0      2015.0                 2000.0
# Cameron-1997          200000000.0      1997.0                14000.0
# Cameron-2009          237000000.0      2009.0                  936.0
#
#                      imdb_score  aspect_ratio movie_facebook_likes
# Uekrongtham-2014            5.7          2.35                    0
# Whaley-2001                 5.4          1.85                   47
# Trenchard-Smith-2006        4.1          1.85                   42
# Stern-2006                  7.7          1.66                  246
# Craig-2012                  4.6          2.35                  898
# ...                         ...           ...                  ...
# Nolan-2008                  9.0          2.35                37000
# Whedon-2012                 8.1          1.85               123000
# Trevorrow-2015              7.0          2.00               150000
# Cameron-1997                7.7          2.35                26000
# Cameron-2009                7.9          1.78                33000
#
# [3654 rows x 28 columns]
